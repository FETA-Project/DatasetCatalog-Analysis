# %%
import sys
# Import NDVM modules to load pickled data
sys.path.append('/home/dosoukup/Dataset/drift-katoda-v2/katoda-tools/ndvm/modules')
sys.path.append('/home/dosoukup/Dataset/drift-katoda-v2/katoda-tools/ndvm')
import os
import pickle
import metric1, metric2, metric3
import json
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import auc
import matplotlib.cm as cm
import pandas as pd

# %%
REPORT_NAME = "metrics/report-dataset-1755324484"

# %% [markdown]
# # General Report

# %%
with open(REPORT_NAME+'.csv', 'r') as file:
    basic = json.load(file)
pprint(basic)
# Out:
# {'Analyzed Samples': {'09fc80b6.de.ioam.de': 1,
#                       '100006765.collect.igodigital.com': 1,
#                       '100006765.recs.igodigital.com': 1,
#                       '10025174.metrics.convertexperiments.com': 1,
#                       '10025174.track.convertexperiments.com': 1,
#                       '10play.com.au': 1,
#                       '116vod-adaptive.akamaized.net': 1,
#                       '117108242.intellimizeio.com': 2,
#                       '137vod-adaptive.akamaized.net': 1,
#                       '142vod-adaptive.akamaized.net': 1,
#                       '147-229-13-93_s-2-16-2-74_ts-1631103523-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-2-16-2-74_ts-1631108672-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-2-16-2-74_ts-1631109501-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-92-123-194-107_ts-1631100617-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-92-123-194-107_ts-1631104502-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-92-123-194-107_ts-1631107519-clienttons-s.akamaihd.net': 1,
#                       '150vod-adaptive.akamaized.net': 1,
#                       '156vod-adaptive.akamaized.net': 1,
#                       '1737ad58.akstat.io': 1,
#                       '17rg073sukbm1lmjk9jrehb643-wpengine.netdna-ssl.com': 3,
#                       '183vod-adaptive.akamaized.net': 1,
#                       '198vod-adaptive.akamaized.net': 1,
#                       '1boidr1j8wt01itylm7cszo5r8-wpengine.netdna-ssl.com': 6,
#                       '1gkys61108am2vvslv1ayriu-wpengine.netdna-ssl.com': 4,
#                       '20gvk91ksw9w3d0jm942v9hq-wpengine.netdna-ssl.com': 5,
#                       '241wzf2qsry91sfos32l0c5v-wpengine.netdna-ssl.com': 6,
#                       '275110.selcdn.ru': 4,
#                       '2e2gxjd936-dsn.algolia.net': 1,
#                       '2xj3ep1sacqvsluiw1w0g438-wpengine.netdna-ssl.com': 6,
#                       '32vod-adaptive.akamaized.net': 1,
#                       '34vod-adaptive.akamaized.net': 1,
#                       '3m.mediav.com': 3,
#                       '3tu97y2w9w35k69i31phftc4-wpengine.netdna-ssl.com': 3,
#                       '3y5x73a532if8hm233q2pd4f-wpengine.netdna-ssl.com': 6,
#                       '3yq5q42rw3z48qnbj46yehrx-wpengine.netdna-ssl.com': 6,
#                       '4.adsco.re': 2,
#                       '42xtjqm0qj0382ac91ye9exr-wpengine.netdna-ssl.com': 5,
#                       '4bqtf234d34a2gxuu749ctvy-wpengine.netdna-ssl.com': 6,
#                       '4erff29jo03b8uhp4b94vxhq-wpengine.netdna-ssl.com': 4,
#                       '4fb24926e1b14814a38269d503981dd3-7aa2ea4f53f1.cdn.forter.com': 1,
#                       '51e907dda41fa8746f42-af6f3e566f76c863f4f14237bf5b9b4b.ssl.cf5.rackcdn.com': 5,
#                       '52vod-adaptive.akamaized.net': 1,
#                       '56vod-adaptive.akamaized.net': 1,
#                       '684dd308.akstat.io': 1,
#                       '684dd30c.akstat.io': 3,
#                       '684dd30d.akstat.io': 2,
#                       '686eb519.akstat.io': 1,
#                       '6d0059750d294e659ace6d5dc44e775a-09866830beaa.cdn.forter.com': 5,
#                       '6z1x4vph2b-dsn.algolia.net': 2,
#                       '7tvandalucia.es': 6,
#                       '805089.smushcdn.com': 2,
#                       '858475.smushcdn.com': 6,
#                       '8c11ebd904100d.rogersmedia.com': 1,
#                       '95vod-adaptive.akamaized.net': 1,
#                       '9xzxv1eo7572295fo1ebb5x1-wpengine.netdna-ssl.com': 7,
#                       'a.ad.gt': 1,
#                       'a.config.skype.com': 1,
#                       'a.kapanlagi.com': 4,
#                       'a.vidoomy.com': 1,
#                       'a1-static.comparably.com': 2,
#                       'a1.awin1.com': 1,
#                       'a2-static.comparably.com': 5,
#                       'a2.adform.net': 1,
#                       'a248.e.akamai.net': 1,
#                       'a3-static.comparably.com': 3,
#                       'a4-static.comparably.com': 1,
#                       'a4p.adpartner.pro': 2,
#                       'aa.agkn.com': 6,
#                       'aax-us-east.amazon-adsystem.com': 2,
#                       'aax.amazon-adsystem.com': 1,
#                       'ab91379d.de.ioam.de': 1,
#                       'abrtp1-cdn.marketo.com': 1,
#                       'abtw.disqus.com': 2,
#                       'accord.aegworldwide.com': 1,
#                       'account.asmodee.net': 1,
#                       'account.edrawsoft.com': 1,
#                       'account.redbull.com': 1,
#                       'accounts.ea.com': 1,
#                       'accounts.wondershare.com': 1,
#                       'acdn.adnxs.com': 13,
#                       'actorsfund.org': 1,
#                       'ad.360yield.com': 3,
#                       'ad.admitad.com': 1,
#                       'ad.adriver.ru': 2,
#                       'ad.crwdcntrl.net': 2,
#                       'ad.foodlion.com': 1,
#                       'ada.baidu.com': 2,
#                       'addsearch.com': 1,
#                       'adea.informz.net': 1,
#                       'adplayer.pro': 2,
#                       'ads.allaccess.com.ph': 2,
#                       'ads.pubmatic.com': 12,
#                       'ads.servenobid.com': 1,
#                       'ads.stickyadstv.com': 8,
#                       'ads.vidoomy.com': 1,
#                       'ads.yieldmo.com': 2,
#                       'adsco.re': 1,
#                       'adserver.juicyads.com': 1,
#                       'adserver.kl-youniverse.com': 1,
#                       'advert.sledui.net': 2,
#                       'adx.adform.net': 16,
#                       'adx.dable.io': 2,
#                       'ae01.alicdn.com': 3,
#                       'aerilon.graphql.aspire-ebm.com': 2,
#                       'af-110.com': 2,
#                       'afcs.dellcdn.com': 5,
#                       'affordableartfair.com': 1,
#                       'affprism.baidu.com': 3,
#                       'agences.banquepopulaire.fr': 1,
#                       'aifanfan.baidu.com': 2,
#                       'aipam.ru': 1,
#                       'aka.ms': 1,
#                       'aktrack.pubmatic.com': 1,
#                       'aliexpress.ru': 1,
#                       'allaurhost.ru': 1,
#                       'alpixtrack.com': 6,
#                       'am-match.taboola.com': 1,
#                       'am-vid-events.taboola.com': 1,
#                       'amateurphotographer.co.uk': 1,
#                       'amplify.outbrain.com': 2,
#                       'ams1-ib.adnxs.com': 4,
#                       'an.yandex.ru': 5,
#                       'analytics-eu.clickdimensions.com': 2,
#                       'analytics-udg.netdna-ssl.com': 1,
#                       'analytics.ad.daum.net': 2,
#                       'analytics.cloud.coveo.com': 1,
#                       'analytics.datarobot.com': 1,
#                       'analytics.sem-track.com': 2,
#                       'analytics.shareaholic.com': 3,
#                       'analytics.ticketmaster.com.mx': 1,
#                       'analytics.webpushr.com': 3,
#                       'analytics.yinxiang.com': 3,
#                       'andaluciainformacion.es': 1,
#                       'andromeda.yandy.com': 2,
#                       'api-az.online.pro': 1,
#                       'api-iam.intercom.io': 4,
#                       'api-next.barks.jp': 5,
#                       'api.amplitude.com': 5,
#                       'api.aws.parking.godaddy.com': 4,
#                       'api.baikalsr.ru': 1,
#                       'api.blackcrow.ai': 1,
#                       'api.cofactordigital.com': 2,
#                       'api.composer.nprstations.org': 6,
#                       'api.conrad.com': 5,
#                       'api.convertkit.com': 2,
#                       'api.curator.io': 4,
#                       'api.dfrobot.com': 1,
#                       'api.drivetribe.com': 3,
#                       'api.footprintcalculator.org': 1,
#                       'api.getblueshift.com': 1,
#                       'api.getcandid.com': 1,
#                       'api.helpx.net': 6,
#                       'api.intellimize.co': 2,
#                       'api.luigisbox.com': 1,
#                       'api.mediego.com': 1,
#                       'api.meritpages.com': 2,
#                       'api.mps.ford.com': 1,
#                       'api.msn.com': 56,
#                       'api.mywed.com': 1,
#                       'api.openweathermap.org': 1,
#                       'api.readmetro.com': 2,
#                       'api.replyco.com': 2,
#                       'api.sail-personalize.com': 1,
#                       'api.segment.io': 3,
#                       'api.tagstream.com': 1,
#                       'api.trstplse.com': 1,
#                       'api.usehero.com': 1,
#                       'api.userback.io': 1,
#                       'api.userway.org': 2,
#                       'api.viafoura.co': 3,
#                       'api.visii.com': 3,
#                       'api.wnyc.org': 4,
#                       'apm.oupprodelk.pubfactory.com': 1,
#                       'aport.ru': 1,
#                       'app.comagic.ru': 1,
#                       'app.hushly.com': 1,
#                       'app.omniconvert.com': 2,
#                       'app.pressengine.net': 1,
#                       'appd-geo.geo.t-mobile.com': 1,
#                       'appharbor.com': 1,
#                       'appointlet.com': 1,
#                       'apps.mypurecloud.com': 1,
#                       'appual.disqus.com': 1,
#                       'aptnnews-ca.disqus.com': 1,
#                       'ar.cienradios.com': 1,
#                       'arc.msn.com': 26,
#                       'archivists.org': 1,
#                       'arlnow.disqus.com': 1,
#                       'arms-retcode.aliyuncs.com': 6,
#                       'array608.prod.do.dsp.mp.microsoft.com': 16,
#                       'articulate-online.com': 1,
#                       'as-sec.casalemedia.com': 14,
#                       'assets-eu-01.kc-usercontent.com': 6,
#                       'assets-s3-us-east-1.ceros.com': 2,
#                       'assets.alicdn.com': 1,
#                       'assets.hearstapps.com': 4,
#                       'assets.publika.md': 5,
#                       'assets.rebelmouse.io': 4,
#                       'assets.rootrez.com': 1,
#                       'assets.sanebox.com': 4,
#                       'assets.sitescdn.net': 2,
#                       'assets.yandycdn.com': 2,
#                       'assp.org': 1,
#                       'astrologia.nl': 1,
#                       'async-px-eu.dynamicyield.com': 4,
#                       'async-px.dynamicyield.com': 10,
#                       'aufp.io': 1,
#                       'auth.frontstream.com': 2,
#                       'autoupdate.geo.opera.com': 2,
#                       'avatar.mama.cn': 2,
#                       'avatars.mds.yandex.net': 5,
#                       'avurer.com': 1,
#                       'az.pl': 1,
#                       'b.clarity.ms': 3,
#                       'b.marfeel.com': 1,
#                       'b.triptease.io': 1,
#                       'b0.thejournal.ie': 5,
#                       'b133.s240.meetrics.net': 1,
#                       'b2c.insticator.com': 1,
#                       'b3.mookie1.com': 1,
#                       'b92f7f53.de.ioam.de': 1,
#                       'backl.ink': 1,
#                       'banner.org.ua': 1,
#                       'banners.adfox.ru': 2,
#                       'barnesfoundation.imgix.net': 3,
#                       'barra.brasil.gov.br': 2,
#                       'bat.bing.com': 37,
#                       'bbfc.co.uk': 1,
#                       'bcbolt446c5271-a.akamaihd.net': 5,
#                       'bcboltamc-a.akamaihd.net': 2,
#                       'bcp.crwdcntrl.net': 12,
#                       'beacon.krxd.net': 4,
#                       'beacon.riskified.com': 1,
#                       'befirstcdn.com': 1,
#                       'beoecomapim.bang-olufsen.com': 1,
#                       'bestunion.queue-it.net': 1,
#                       'bf68167wlh.bf.dynatrace.com': 1,
#                       'bfrss.org.uk': 1,
#                       'bi.im-g.pl': 6,
#                       'biddingforgood.com': 1,
#                       'bilder-a.akamaihd.net': 1,
#                       'biv.gazeta.pl': 1,
#                       'biz.icxo.com': 2,
#                       'blinky.nemui.org': 12,
#                       'bmw-welt.com': 1,
#                       'bngpt.com': 2,
#                       'boerseonline.brn-ag.de': 1,
#                       'bonjovi.com': 1,
#                       'booking.motel-one.com': 1,
#                       'bookmate.com': 2,
#                       'boomerang.dell.com': 2,
#                       'bootstrap.api.drift.com': 4,
#                       'bootstrap.smartsuppchat.com': 1,
#                       'bp-prod.cloudimg.io': 4,
#                       'bpi.rtactivate.com': 1,
#                       'bq.com': 1,
#                       'brands.kmsmep.com': 1,
#                       'bravewords.disqus.com': 1,
#                       'breaking.energylivenews.com': 1,
#                       'breastcancernow.org': 1,
#                       'browser.sentry-cdn.com': 7,
#                       'bs.nakanohito.jp': 2,
#                       'bs.serving-sys.com': 2,
#                       'btlr.sharethrough.com': 7,
#                       'bttrack.com': 2,
#                       'bus.tutu.ru': 1,
#                       'bwtsrv.com': 2,
#                       'c.bing.com': 5,
#                       'c.clarity.ms': 5,
#                       'c.clicktale.net': 8,
#                       'c.contentsquare.net': 1,
#                       'c.deadlinefunnel.com': 1,
#                       'c.dun.163.com': 1,
#                       'c.evidon.com': 21,
#                       'c.go-mpulse.net': 10,
#                       'c.mobilegeeks.de': 6,
#                       'c.riskified.com': 1,
#                       'c.webengage.com': 2,
#                       'c057b0e5.de.ioam.de': 1,
#                       'c1.adform.net': 2,
#                       'c3.avaamo.com': 1,
#                       'c3021603219a4fcea87d9f4a38b6e188.js.ubembed.com': 1,
#                       'c5.adalyser.com': 1,
#                       'ca-eu.cookie-script.com': 1,
#                       'cache.lovethispic.com': 6,
#                       'cachewp.fling.com': 5,
#                       'cagle.com': 1,
#                       'cagle.disqus.com': 1,
#                       'caleres-app.quantummetric.com': 1,
#                       'caleres-sync.quantummetric.com': 1,
#                       'calltracking.ru': 1,
#                       'canon.de': 1,
#                       'care.org.rw': 1,
#                       'careerfoundry.com': 1,
#                       'caribbeanfever.com': 1,
#                       'cartodb-libs.global.ssl.fastly.net': 1,
#                       'catholic.org.au': 2,
#                       'cbe.capturehighered.net': 1,
#                       'cbjs.baidu.com': 2,
#                       'cc.calltracking.ru': 1,
#                       'cc.swiftype.com': 3,
#                       'ccgw.oncehub.com': 1,
#                       'cd.fkw.com': 1,
#                       'cd809dda-f588-4363-951e-e383f3fb6f7e.rlets.com': 1,
#                       'cdh.faisys.com': 6,
#                       'cdn-akamai.mookie1.com': 2,
#                       'cdn-publish-filemanager.homestyler.com': 3,
#                       'cdn-s2s.buysellads.net': 1,
#                       'cdn-sic.33across.com': 1,
#                       'cdn-static.freeart.com': 3,
#                       'cdn.admitad-connect.com': 1,
#                       'cdn.adnxs-simple.com': 2,
#                       'cdn.adnxs.com': 2,
#                       'cdn.advertserve.com': 4,
#                       'cdn.bootcdn.net': 3,
#                       'cdn.callrail.com': 2,
#                       'cdn.comsol.com': 7,
#                       'cdn.contentstack.io': 1,
#                       'cdn.embedly.com': 1,
#                       'cdn.engine.addroplet.com': 1,
#                       'cdn.euromoneyapi.com': 3,
#                       'cdn.filestackcontent.com': 6,
#                       'cdn.flashtalking.com': 2,
#                       'cdn.krxd.net': 6,
#                       'cdn.mookie1.com': 4,
#                       'cdn.mouseflow.com': 5,
#                       'cdn.oncehub.com': 6,
#                       'cdn.onthe.io': 1,
#                       'cdn.petametrics.com': 2,
#                       'cdn.playerserve.com': 1,
#                       'cdn.polyfill.io': 21,
#                       'cdn.pool.st-hatena.com': 1,
#                       'cdn.ravenjs.com': 1,
#                       'cdn.relap.io': 6,
#                       'cdn.revive-adserver.net': 1,
#                       'cdn.smartclip-services.com': 1,
#                       'cdn.speedcurve.com': 1,
#                       'cdn.static-fra.de': 1,
#                       'cdn.trackjs.com': 1,
#                       'cdn.tuoitre.vn': 4,
#                       'cdn.tynt.com': 2,
#                       'cdn.viglink.com': 3,
#                       'cdn.vox-cdn.com': 24,
#                       'cdn.webpushr.com': 1,
#                       'cdn.weltwoche-daily.ch': 6,
#                       'cdn.yottaa.com': 2,
#                       'cdn.zopim.com': 1,
#                       'cdn0.forter.com': 7,
#                       'cdn1-gae-ssl-default.akamaized.net': 1,
#                       'cdn1.affirm.com': 1,
#                       'cdn1.lockerdomecdn.com': 2,
#                       'cdn1.readspeaker.com': 4,
#                       'cdn2.lockerdomecdn.com': 1,
#                       'cdn2.vox-cdn.com': 1,
#                       'cdn3.forter.com': 2,
#                       'cdn3.optimizely.com': 3,
#                       'cdn3.vox-cdn.com': 2,
#                       'cdn4.buysellads.net': 3,
#                       'cdngeneral.rentcafe.com': 2,
#                       'cdns.eu1.gigya.com': 2,
#                       'cdns.gigya.com': 4,
#                       'cdns.us1.gigya.com': 1,
#                       'cds.taboola.com': 7,
#                       'cefic.org': 1,
#                       'ceh.ac.uk': 1,
#                       'celebitchy.com': 1,
#                       'centerforpolitics.org': 6,
#                       'centro.pixel.ad': 1,
#                       'ceo.icxo.com': 4,
#                       'cfo.icxo.com': 2,
#                       'chainnews.com': 1,
#                       'channelstelevision.disqus.com': 1,
#                       'charlottenc.gov': 6,
#                       'chatbot-preprod.bostonwebdevteam.com': 2,
#                       'checkin.purechat.com': 1,
#                       'checkup02.biz': 1,
#                       'chethemes.com': 5,
#                       'childrensmiraclenetworkhospitals.org': 1,
#                       'chimpstatic.com': 11,
#                       'chinabaike.com': 2,
#                       'chipin.disqus.com': 1,
#                       'choicehotels.tt.omtrdc.net': 1,
#                       'chron.disqus.com': 2,
#                       'churchleaders-eszuskq0bptlfh8awbb.stackpathdns.com': 6,
#                       'churchmilitant.disqus.com': 2,
#                       'cinvestav.mx': 1,
#                       'circulobellasartes.com': 1,
#                       'cisp.cachefly.net': 6,
#                       'ckmap.mediav.com': 4,
#                       'cko.icxo.com': 2,
#                       'classic.avantlink.com': 1,
#                       'cleverbridge.com': 1,
#                       'clickio.mgr.consensu.org': 1,
#                       'clickiocdn.com': 1,
#                       'clickserv.basis.net': 1,
#                       'clickserv.sitescout.com': 1,
#                       'client.teamviewer.com': 6,
#                       'clients2.google.com': 1,
#                       'climbing.com': 1,
#                       'cllctr.roistat.com': 1,
#                       'cloud.roistat.com': 2,
#                       'cloud.typography.com': 16,
#                       'cm.adform.net': 2,
#                       'cm.everesttech.net': 17,
#                       'cm.miaozhen.atm.youku.com': 4,
#                       'cm.p.altergeo.ru': 1,
#                       'cm.pos.baidu.com': 4,
#                       'cms.analytics.yahoo.com': 2,
#                       'cms.tanx.com': 2,
#                       'cnobi.jp': 2,
#                       'cns-angular-content-prod-1.freetls.fastly.net': 5,
#                       'cnt.sputnik.ru': 1,
#                       'cnzz.mmstat.com': 2,
#                       'code.tidio.co': 1,
#                       'cognito-identity.eu-central-1.amazonaws.com': 1,
#                       'cognito-identity.eu-west-1.amazonaws.com': 1,
#                       'cognito-identity.us-east-1.amazonaws.com': 1,
#                       'cognito-identity.us-west-2.amazonaws.com': 1,
#                       'collect-ap-southeast-2.tealiumiq.com': 2,
#                       'collect-eu-central-1.tealiumiq.com': 2,
#                       'collect.ptengine.jp': 2,
#                       'collect.tealiumiq.com': 1,
#                       'collector.leaddyno.com': 3,
#                       'concierge.tripla.ai': 2,
#                       'confiant-integrations.freetls.fastly.net': 1,
#                       'confiant-integrations.global.ssl.fastly.net': 14,
#                       'config.edge.skype.com': 2,
#                       'connect-metrics-collector.s-onetag.com': 4,
#                       'connect.ok.ru': 2,
#                       'consumer.krxd.net': 5,
#                       'content-getcandid.netdna-ssl.com': 1,
#                       'content-studio-teasers-server.inventory.schibsted.io': 1,
#                       'content.atomz.com': 2,
#                       'conv-tm.everesttech.net': 1,
#                       'conv.tubemogul.com': 1,
#                       'core.conversant.mgr.consensu.org': 2,
#                       'corel.zendesk.com': 1,
#                       'counter.rambler.ru': 1,
#                       'counter.web.money': 1,
#                       'counter.yadro.ru': 15,
#                       'cp601.prod.do.dsp.mp.microsoft.com': 1,
#                       'cpro.baidu.com': 2,
#                       'creativeforceteam.matomo.cloud': 2,
#                       'cs.admanmedia.com': 4,
#                       'cs.emxdgt.com': 1,
#                       'cs.liiift.io': 3,
#                       'cs.lkqd.net': 4,
#                       'cs.nakanohito.jp': 2,
#                       'csiaorg.com': 1,
#                       'css.biddingforgood.com': 4,
#                       'css.yatracdn.com': 1,
#                       'cssdeck.com': 6,
#                       'cstaticdun.126.net': 2,
#                       'cuentosquesanan.cl': 6,
#                       'current.org': 1,
#                       'cv.gunosy.com': 2,
#                       'cvs-app.quantummetric.com': 1,
#                       'cvs-sync.quantummetric.com': 1,
#                       'cyclingindustry.news': 6,
#                       'czdfw1kuw9n20zm0l7pmfb1a-wpengine.netdna-ssl.com': 6,
#                       'czso.cz': 1,
#                       'cztt.ru': 1,
#                       'd.adroll.com': 6,
#                       'd.socdm.com': 3,
#                       'd1.faiusr.com': 4,
#                       'd12040be07df4dadacdd55db1b1ef3d9.js.ubembed.com': 1,
#                       'd2ccommon.wmg-gardens.com': 1,
#                       'd2cstorage-a.akamaihd.net': 1,
#                       'd2etwuhgv16p.l4.adsco.re': 1,
#                       'd2etwuhgv16p.n4.adsco.re': 1,
#                       'd2etwuhgv16p.s4.adsco.re': 2,
#                       'd54hsn8ou0.execute-api.eu-central-1.amazonaws.com': 1,
#                       'da.qiyukf.com': 2,
#                       'dainese.com': 1,
#                       'daisho.firebaseio.com': 1,
#                       'dan.org': 1,
#                       'dash.getsitecontrol.com': 2,
#                       'data.cdnbasket.net': 2,
#                       'data2.gosquared.com': 1,
#                       'datacloud.tealiumiq.com': 1,
#                       'datareport.fkw.com': 2,
#                       'datarobot.com': 1,
#                       'db0y8smio0.execute-api.us-east-2.amazonaws.com': 1,
#                       'dbzproperty-a.akamaihd.net': 1,
#                       'dbzstatic-a.akamaihd.net': 5,
#                       'dc.oracleinfinity.io': 4,
#                       'dc.services.visualstudio.com': 5,
#                       'dc462dd4-2b05-4f26-bb67-beeeffbc3313.akamaized.net': 5,
#                       'dcd12547fac74c3cb90d3307a66b8089.apm.eu-west-1.aws.cloud.es.io': 1,
#                       'dday-it.disqus.com': 6,
#                       'dday.imgix.net': 6,
#                       'de.tynt.com': 3,
#                       'delivery.clickonometrics.pl': 1,
#                       'delivery.r2b2.cz': 2,
#                       'demo.joomlashine.com': 2,
#                       'dentistryiq.com': 1,
#                       'desktopindia.com': 1,
#                       'developers.kakao.com': 2,
#                       'df83e96a84d8529ac3a1-b14d7eeab70e892e89289d791c854243.ssl.cf2.rackcdn.com': 3,
#                       'digest.icxo.com': 2,
#                       'digi2.fujisan.co.jp': 6,
#                       'digsdigs.com': 1,
#                       'dinhduongchobe.org': 1,
#                       'direct.dy-api.eu': 1,
#                       'disqus.com': 6,
#                       'distillery.wistia.com': 10,
#                       'diversalertnetwork.org': 1,
#                       'diyanet.gov.tr': 6,
#                       'diydrones.com': 1,
#                       'djbooth.net': 1,
#                       'dl.dropboxusercontent.com': 1,
#                       'dmg.digitaltarget.ru': 3,
#                       'dmp.adform.net': 3,
#                       'drf.com': 1,
#                       'driftt.imgix.net': 2,
#                       'drivetribe.imgix.net': 6,
#                       'drop.dontstopthismusics.com': 2,
#                       'ds-aksb-a.akamaihd.net': 5,
#                       'dsp.adfarm1.adition.com': 1,
#                       'dsp.adkernel.com': 1,
#                       'dsum-sec.casalemedia.com': 1,
#                       'dt.adsafeprotected.com': 19,
#                       'dulovic.tech': 1,
#                       'dup.baidustatic.com': 3,
#                       'e-10353.adzerk.net': 1,
#                       'e-commerce.ning.com': 1,
#                       'e.issuu.com': 2,
#                       'e.so.com': 2,
#                       'e3.adpushup.com': 1,
#                       'eb2.3lift.com': 6,
#                       'eclick.baidu.com': 6,
#                       'ecs.office.com': 2,
#                       'edge.qiwi.com': 2,
#                       'edge.quantserve.com': 1,
#                       'edgeneric365.com': 6,
#                       'editionsladecouverte.fr': 1,
#                       'eeafj.cn': 6,
#                       'elasuntourbano.disqus.com': 1,
#                       'elink.io': 1,
#                       'embed-fastly.wistia.com': 4,
#                       'embed-ssl.wistia.com': 3,
#                       'embed.air.tv': 1,
#                       'embed.crowdriff.com': 1,
#                       'embed.runkit.com': 1,
#                       'embedr.flickr.com': 2,
#                       'embedwistia-a.akamaihd.net': 6,
#                       'energy-xprt.com': 1,
#                       'entitlement.auth.adobe.com': 1,
#                       'epnt.ebay.com': 4,
#                       'equitablegrowth.org': 1,
#                       'er.sanoma-sndp.fi': 1,
#                       'erzbistum-koeln.de': 1,
#                       'essayreview.matomo.cloud': 1,
#                       'etssp.ru': 1,
#                       'euredski.hr': 1,
#                       'event.api.drift.com': 5,
#                       'events.api.secureserver.net': 2,
#                       'events.mapbox.com': 4,
#                       'events.medicitv.fr': 1,
#                       'evoke-windowsservices-tas.msedge.net': 1,
#                       'evt.tiancity.com': 2,
#                       'evt05.tiancity.com': 3,
#                       'evvnt-api.global.ssl.fastly.net': 1,
#                       'evvnt-plugin-proxy.global.ssl.fastly.net': 1,
#                       'examguide.co.in': 6,
#                       'exchange.adtrue.com': 1,
#                       'exchange.mediavine.com': 2,
#                       'exchange.postrelease.com': 1,
#                       'extend.vimeocdn.com': 2,
#                       'f.clarity.ms': 2,
#                       'f.vimeocdn.com': 67,
#                       'f624058c3f5c8edb775a-dea6612566ec344afdf376d2faa6c82f.ssl.cf5.rackcdn.com': 1,
#                       'f6d62442117544cda62854dde2993d09-09866830beaa.cdn.forter.com': 1,
#                       'f8286a85-aa11-4825-9d0b-7707beecb206.rlets.com': 1,
#                       'faru.os.tc': 1,
#                       'fast.a.klaviyo.com': 1,
#                       'fast.fonts.net': 19,
#                       'fast.wistia.com': 14,
#                       'fast.wistia.net': 2,
#                       'fastlane.rubiconproject.com': 36,
#                       'fau-res.cloudinary.com': 6,
#                       'faves.grow.me': 1,
#                       'favicon.yandex.net': 1,
#                       'fc1.1bis.com': 1,
#                       'fcs.dellcdn.com': 1,
#                       'fdz.flashtalking.com': 2,
#                       'fe.faisco.cn': 2,
#                       'fe.faisys.com': 4,
#                       'fe2cr.update.microsoft.com': 1,
#                       'fe3cr.delivery.mp.microsoft.com': 3,
#                       'feed.surfing-waves.com': 1,
#                       'feedback.aliexpress.com': 4,
#                       'felix.data.tm-awx.com': 1,
#                       'ffatest.ffa.org': 1,
#                       'file-attente.cultura.com': 1,
#                       'file.myfontastic.com': 1,
#                       'file.tiancity.com': 1,
#                       'finance.icxo.com': 2,
#                       'firstsolar.com': 1,
#                       'floridadep.gov': 1,
#                       'fls-na.amazon.com': 1,
#                       'flv-prd-oxud8mggj93od145.imgix.net': 6,
#                       'fly.gentside.com': 1,
#                       'fol.icxo.com': 2,
#                       'fonts2u.com': 1,
#                       'foodlion.com': 6,
#                       'forms.amocrm.ru': 2,
#                       'forms.m-pages.com': 1,
#                       'forms.mailmunch.co': 2,
#                       'formulator.drf.com': 2,
#                       'forumspb.rcfiles.rcmedia.ru': 6,
#                       'fourier.taobao.com': 5,
#                       'fp.fraudmetrix.cn': 2,
#                       'fp.tongdun.net': 3,
#                       'fra1-ib.adnxs.com': 5,
#                       'freeletics.zendesk.com': 1,
#                       'freitag.ch': 1,
#                       'frog.wix.com': 5,
#                       'front.optimonk.com': 1,
#                       'fs.microsoft.com': 2,
#                       'fs23.infourok.ru': 1,
#                       'funding.webmoney.ru': 4,
#                       'funkyimg.com': 1,
#                       'fw.adsafeprotected.com': 3,
#                       'g.live.com': 3,
#                       'g2.gumgum.com': 1,
#                       'ga.tiancity.com': 2,
#                       'gahu.hit.gemius.pl': 1,
#                       'galaxyzoo.org': 1,
#                       'galv.hit.gemius.pl': 1,
#                       'gardenersworld.com': 1,
#                       'gaua.hit.gemius.pl': 1,
#                       'gdecz.hit.gemius.pl': 2,
#                       'generalgrowth.tt.omtrdc.net': 1,
#                       'gentside.com': 1,
#                       'geo.moatads.com': 2,
#                       'geo.prod.do.dsp.mp.microsoft.com': 1,
#                       'geo2.adobe.com': 1,
#                       'geoip.footprintcalculator.org': 1,
#                       'geoip.insticator.com': 1,
#                       'ghgprotocol.org': 1,
#                       'gi86r2aruy-dsn.algolia.net': 1,
#                       'gj.mmstat.com': 2,
#                       'global.oup.com': 1,
#                       'gm.mmstat.com': 2,
#                       'go.oncehub.com': 2,
#                       'go4.datarobot.com': 1,
#                       'goutong.baidu.com': 2,
#                       'grammymuseum.org': 1,
#                       'graphberry.imgix.net': 1,
#                       'grid.bidswitch.net': 4,
#                       'grow.pushpay.com': 1,
#                       'gscore.homestyler.com': 1,
#                       'gurgle.zdbb.net': 1,
#                       'h.online-metrix.net': 1,
#                       'h.waudit.cz': 1,
#                       'h7jfx4036803dkga3d6qx436-wpengine.netdna-ssl.com': 4,
#                       'hannl.imgix.net': 2,
#                       'hb.adscale.de': 10,
#                       'hb.brainlyads.com': 4,
#                       'hb.emxdgt.com': 2,
#                       'hbopenbid.pubmatic.com': 20,
#                       'hbu-files.wpmucdn.com': 6,
#                       'hdmi.org': 1,
#                       'hdrinc.com': 1,
#                       'health.icxo.com': 6,
#                       'healthengine.com.au': 2,
#                       'healthengine.imgix.net': 6,
#                       'heapanalytics.com': 3,
#                       'heimdalsecurity.com': 1,
#                       'hello.myfonts.net': 12,
#                       'helpsystems.com': 1,
#                       'helvetia.tt.omtrdc.net': 1,
#                       'hkfyg.org.hk': 6,
#                       'hm.baidu.com': 43,
#                       'holocaustremembrance.com': 6,
#                       'hondanews.com': 1,
#                       'hostenko.com': 1,
#                       'house-fastly-signed-eu-west-1-prod.brightcovecdn.com': 1,
#                       'htlb.casalemedia.com': 15,
#                       'httpbin.org': 1,
#                       'https-thedriven-io.disqus.com': 2,
#                       'hu.imgix.net': 2,
#                       'hu.nl': 1,
#                       'hztp.hotjob.cn': 4,
#                       'i.bcprm.com': 2,
#                       'i.fkw.com': 3,
#                       'i.geistm.com': 1,
#                       'i.gse.io': 3,
#                       'i.imgur.com': 5,
#                       'i.mycdn.me': 12,
#                       'i.salecycle.com': 1,
#                       'i.simpalsmedia.com': 6,
#                       'i.simpli.fi': 4,
#                       'i.smartnews-ads.com': 8,
#                       'i.socdm.com': 1,
#                       'i.viafoura.co': 2,
#                       'i.vimeocdn.com': 20,
#                       'i0.heartyhosting.com': 1,
#                       'i2.aport.ru': 1,
#                       'ia.51.la': 4,
#                       'ib.adnxs.com': 75,
#                       'ic.helixsystems.com': 2,
#                       'ic.tynt.com': 3,
#                       'ica.coop': 1,
#                       'ichef.bbci.co.uk': 1,
#                       'icnirp.org': 1,
#                       'icshop.ru.aliexpress.com': 1,
#                       'icxo.com': 6,
#                       'id.crwdcntrl.net': 5,
#                       'id.sharedid.org': 2,
#                       'id.sv.rkdms.com': 1,
#                       'identity-x.io': 12,
#                       'ids.ad.gt': 3,
#                       'ie.api.atom.nowtv.com': 1,
#                       'ied.edu.hk': 2,
#                       'ih.adscale.de': 1,
#                       'ihatewriting.net': 1,
#                       'image.biddingforgood.com': 6,
#                       'image.flaticon.com': 3,
#                       'image.politicalcartoons.com': 3,
#                       'image.tiancity.com': 6,
#                       'image2.pubmatic.com': 2,
#                       'image6.pubmatic.com': 4,
#                       'image8.pubmatic.com': 5,
#                       'images.celebitchy.com': 6,
#                       'images.dmca.com': 16,
#                       'images.edrawmax.com': 1,
#                       'images.getbento.com': 1,
#                       'images.immediate.co.uk': 1,
#                       'images.metadata.sky.com': 4,
#                       'images.snapsmedia.io': 1,
#                       'images.taikang.com': 6,
#                       'images.unsplash.com': 8,
#                       'imageservice.sky.com': 2,
#                       'img-prod-cms-rt-microsoft-com.akamaized.net': 1,
#                       'img.ak.impact-ad.jp': 1,
#                       'img.chainnews.com': 6,
#                       'img.dentistryiq.com': 1,
#                       'img.en25.com': 2,
#                       'img.fujisan.co.jp': 5,
#                       'img.militaryaerospace.com': 6,
#                       'img.sdcexec.com': 1,
#                       'img.secureserver.net': 2,
#                       'img.tradepub.com': 5,
#                       'img.vps.net': 8,
#                       'img.webmd.com': 1,
#                       'img.yandex.net': 4,
#                       'img03.en25.com': 1,
#                       'img04.en25.com': 1,
#                       'img06.en25.com': 1,
#                       'img1.tiancity.com': 3,
#                       'img1.tiancitycdn.com': 1,
#                       'img17.tiancitycdn.com': 6,
#                       'img2.tiancity.com': 1,
#                       'img2.tiancitycdn.com': 6,
#                       'img3.usefathom.com': 1,
#                       'imgdrop.imgix.net': 4,
#                       'imgs.signifyd.com': 3,
#                       'imp.i218435.net': 1,
#                       'in.getclicky.com': 4,
#                       'in.hotjar.com': 45,
#                       'increaserev.com': 1,
#                       'infotel.ca': 1,
#                       'ing-district.clicktale.net': 2,
#                       'insight.adsrvr.org': 18,
#                       'intelligenceadx.com': 1,
#                       'intermedia.com': 1,
#                       'inv-nets.admixer.net': 8,
#                       'invol.co': 2,
#                       'iona.blueconic.net': 1,
#                       'ip.mia-chat.com': 1,
#                       'ipapi.co': 2,
#                       'iphoneincanada.disqus.com': 2,
#                       'ismatlab.com': 1,
#                       'issuu.com': 4,
#                       'j5u7w17oqpo2qwv3k2m6lfh1-wpengine.netdna-ssl.com': 2,
#                       'jabil.com': 1,
#                       'jadserve.postrelease.com': 7,
#                       'jaws.pbs.org': 1,
#                       'jk.ea3w.com': 1,
#                       'jobs.assp.org': 1,
#                       'jobs.current.org': 2,
#                       'jogger.zdbb.net': 1,
#                       'johnston.grapeshot.co.uk': 1,
#                       'jojud265nia2bj9sy4ah9b61-wpengine.netdna-ssl.com': 4,
#                       'jouwpagina.nl': 3,
#                       'js-agent.newrelic.com': 48,
#                       'js-sec.indexww.com': 10,
#                       'js.alpixtrack.com': 6,
#                       'js.biddingforgood.com': 2,
#                       'js.callrail.com': 1,
#                       'js.fout.jp': 2,
#                       'js.gleam.io': 1,
#                       'js.indexww.com': 2,
#                       'js.recurly.com': 3,
#                       'js.sentry-cdn.com': 1,
#                       'k3vzn.flx10.com': 2,
#                       'kanstatic.azureedge.net': 6,
#                       'kaosenlared.net': 37,
#                       'katie.v4.omgtnc.com': 1,
#                       'kfwimg.kafan.cn': 6,
#                       'ko-fi.com': 1,
#                       'kontan.co.id': 1,
#                       'kraken.rambler.ru': 2,
#                       'kratomkoffee.com': 1,
#                       'kts.vasstycom.com': 1,
#                       'kv601.prod.do.dsp.mp.microsoft.com': 1,
#                       'kvadratshop.azureedge.net': 3,
#                       'l.evidon.com': 3,
#                       'lamayor.org': 1,
#                       'lap.hu': 5,
#                       'lasteventf-tm.everesttech.net': 1,
#                       'laurenconradonline.disqus.com': 1,
#                       'lax1-ib.adnxs-simple.com': 2,
#                       'laz-g-cdn.alicdn.com': 1,
#                       'lciapi.ninthdecimal.com': 1,
#                       'lesserspottedfootball.com': 6,
#                       'lexar.com': 1,
#                       'lib-us-1.brilliantcollector.com': 1,
#                       'lib-us-2.brilliantcollector.com': 1,
#                       'libraries.wmgartistservices.com': 1,
#                       'libraryh3lp.com': 1,
#                       'licensing.mp.microsoft.com': 2,
#                       'licindia.in': 1,
#                       'listproperty.ng': 1,
#                       'live-hdr-inc.pantheonsite.io': 1,
#                       'livebeta.publika.md': 5,
#                       'livecomments.viafoura.co': 7,
#                       'livetileedge.dsx.mp.microsoft.com': 14,
#                       'lltrck.com': 1,
#                       'loader2.fmkorea.com': 2,
#                       'loadm.exelator.com': 5,
#                       'loadus.exelator.com': 1,
#                       'localist-images.azureedge.net': 3,
#                       'log.cpex.cz': 2,
#                       'log.intellimize.co': 1,
#                       'log1.mobylog.jp': 5,
#                       'login.aliexpress.com': 1,
#                       'login.dotomi.com': 3,
#                       'login.healthengine.com.au': 4,
#                       'login.motel-one.com': 1,
#                       'login.stadtradeln.de': 3,
#                       'logs.convertexperiments.com': 1,
#                       'logs13.xiti.com': 1,
#                       'logs4.xiti.com': 1,
#                       'lp-content.cleverbridge.com': 1,
#                       'lp.connectwise.com': 1,
#                       'lpcdn.lpsnmedia.net': 1,
#                       'lpt-crm.online': 1,
#                       'ls.hit.gemius.pl': 5,
#                       'm.servedby-buysellads.com': 3,
#                       'm.stripe.com': 21,
#                       'm.trafmag.com': 2,
#                       'ma-bise.com': 1,
#                       'mab.chartbeat.com': 5,
#                       'mabping.chartbeat.net': 3,
#                       'madamasrip.disqus.com': 1,
#                       'madridiario.os.tc': 1,
#                       'manifest.prod.boltdns.net': 7,
#                       'mantodea.mantisadnetwork.com': 1,
#                       'maps.asfinag.at': 3,
#                       'mas.protecmedia.com': 4,
#                       'match.adsrvr.org': 26,
#                       'match.bnmla.com': 1,
#                       'match.new-programmatic.com': 1,
#                       'match.sharethrough.com': 2,
#                       'matchid.adfox.yandex.ru': 1,
#                       'mathid.mathtag.com': 2,
#                       'maven.blueconic.net': 1,
#                       'mb.moatads.com': 3,
#                       'mc.s11.exacttarget.com': 4,
#                       'mc.us1.list-manage.com': 1,
#                       'mc.us10.list-manage.com': 1,
#                       'mc.us18.list-manage.com': 1,
#                       'mc.us19.list-manage.com': 1,
#                       'mc.us2.list-manage.com': 2,
#                       'mc.us8.list-manage.com': 2,
#                       'media.fh-muenster.de': 6,
#                       'media.icxo.com': 2,
#                       'media.publika.md': 1,
#                       'media.sandhills.com': 1,
#                       'media.wired.com': 6,
#                       'media1.prime.md': 1,
#                       'media3.giphy.com': 1,
#                       'mediasmarts.ca': 1,
#                       'medicitv-a.imgix.net': 5,
#                       'medicitv-b.imgix.net': 2,
#                       'medicitv-c.imgix.net': 2,
#                       'meet.jit.si': 1,
#                       'megogo.net': 1,
#                       'member.tiancity.com': 2,
#                       'members.barks.jp': 2,
#                       'memorialservices.lv': 6,
#                       'mercyhealth.tt.omtrdc.net': 2,
#                       'messages.guest-experience.triptease.io': 1,
#                       'meta.alu.cn': 6,
#                       'method.ac': 6,
#                       'metoomvmt.org': 6,
#                       'metrics-sentry.cvshealth.com': 1,
#                       'metrics.api.drift.com': 4,
#                       'mia-chat.com': 1,
#                       'miao.baidu.com': 2,
#                       'militaryaerospace.com': 1,
#                       'millikin.edu': 1,
#                       'minne.com': 2,
#                       'mipcache.bdstatic.com': 2,
#                       'mobilizeamerica.imgix.net': 6,
#                       'mod.calltouch.ru': 1,
#                       'moneyforward.com': 2,
#                       'motel-one.com': 2,
#                       'mountainhardwear.com': 1,
#                       'mp.4dex.io': 1,
#                       'msedge.api.cdp.microsoft.com': 2,
#                       'mtlogin.su': 2,
#                       'mtonews.com': 1,
#                       'munchkin.marketo.net': 8,
#                       'mw.thejewishmuseum.org': 1,
#                       'my.easyname.com': 1,
#                       'my.rocknrollbride.com': 1,
#                       'mycliplister.com': 1,
#                       'mydmp.exelator.com': 2,
#                       'myfox-okta.login.go.akamai-access.com': 2,
#                       'myfox.okta.com': 4,
#                       'mygov.scot': 1,
#                       'mylanguageexchange.com': 1,
#                       'mywed.com': 1,
#                       'nan-net.jp': 2,
#                       'nari.informz.net': 1,
#                       'nebula-cdn.kampyle.com': 3,
#                       'nemours.org': 1,
#                       'neo.org': 1,
#                       'new-collect.albacross.com': 1,
#                       'nexus.dell.com': 2,
#                       'nht-2.extreme-dm.com': 1,
#                       'nixon.com': 1,
#                       'noembed.com': 6,
#                       'northcarolina.edu': 1,
#                       'northeurope-2.in.applicationinsights.azure.com': 1,
#                       'notifications.zooniverse.org': 2,
#                       'nova.collect.igodigital.com': 1,
#                       'npr-kuer.disqus.com': 1,
#                       'npr-wvpn.disqus.com': 1,
#                       'ntvcld-a.akamaihd.net': 1,
#                       'nutritiondata.self.com': 6,
#                       'nytrng.com': 1,
#                       'obs.cheqzone.com': 7,
#                       'octopus.inside.xiaoeknow.com': 2,
#                       'offers.com': 1,
#                       'og3i93vzhywk-a.akamaihd.net': 1,
#                       'olytics.as3.io': 1,
#                       'omerlo-readers-api-production.omerloclients.com': 1,
#                       'onderzoek.platformrijksoverheid.nl': 1,
#                       'oneclient.sfx.ms': 3,
#                       'onlinecasino.pokerstars.cz': 1,
#                       'onlinemedshelp.com': 12,
#                       'onsite-tag-logs.apps.nielsen.com': 2,
#                       'open.work.weixin.qq.com': 3,
#                       'openstat.net': 1,
#                       'orgmode.org': 1,
#                       'origin.extole.io': 1,
#                       'ors.cnobi.jp': 2,
#                       'otakumode.com': 1,
#                       'outrigger.com': 1,
#                       'oxford.icxo.com': 2,
#                       'p.ad.gt': 1,
#                       'p.cquotient.com': 2,
#                       'p.qiao.baidu.com': 2,
#                       'p.tvpixel.com': 1,
#                       'p2.fwpixel.com': 1,
#                       'pa.rxthdr.com': 1,
#                       'pa.solosegment.com': 1,
#                       'page.cdnbasket.net': 2,
#                       'pages-stats.rbl.ms': 2,
#                       'pages.awscloud.com': 1,
#                       'paidai-static.oss-cn-beijing.aliyuncs.com': 6,
#                       'paidai.com': 1,
#                       'paidai.oss-cn-beijing.aliyuncs.com': 5,
#                       'painacademy.img-us3.com': 1,
#                       'painacademy.net': 1,
#                       'panoptes-uploads.zooniverse.org': 2,
#                       'partner.shareaholic.com': 3,
#                       'partners.tremorhub.com': 1,
#                       'passport.tiancity.com': 3,
# ...
#                       'www.prisonstudies.org': 7,
#                       'www.profamilia.de': 6,
#                       'www.prospector.cz': 1,
#                       'www.prospin.com.br': 2,
#                       'www.proxibid.com': 6,
#                       'www.prsformusic.com': 7,
#                       'www.psoe.es': 1,
#                       'www.psychiatrist.com': 6,
#                       'www.publiceye.ch': 1,
#                       'www.publika.md': 1,
#                       'www.publimetro.com.mx': 1,
#                       'www.purestorage.com': 1,
#                       'www.pusha.se': 1,
#                       'www.qiushibaike.com': 1,
#                       'www.quakelive.com': 1,
#                       'www.radioformula.com.mx': 1,
#                       'www.railjournal.com': 1,
#                       'www.randomhouse.com': 1,
#                       'www.rds.ca': 1,
#                       'www.reachgeneric.co.uk': 1,
#                       'www.recaptcha.net': 2,
#                       'www.redandblack.com': 1,
#                       'www.redbull.com': 1,
#                       'www.redditstatic.com': 3,
#                       'www.reliable-webhosting.com': 1,
#                       'www.rentcafe.com': 1,
#                       'www.rentracks.jp': 2,
#                       'www.res-x.com': 2,
#                       'www.research.gov': 7,
#                       'www.resmed.com': 1,
#                       'www.resolutionfoundation.org': 1,
#                       'www.retail.ru': 1,
#                       'www.rijksoverheid.nl': 1,
#                       'www.rocknrollbride.com': 1,
#                       'www.rodekruis.nl': 1,
#                       'www.rollingstone.de': 1,
#                       'www.roswellpark.org': 6,
#                       'www.rsvpify.com': 1,
#                       'www.rtb123.com': 1,
#                       'www.rtd-denver.com': 1,
#                       'www.rtl2.de': 1,
#                       'www.rtvs.sk': 1,
#                       'www.rumiview.com': 1,
#                       'www.runrocknroll.com': 28,
#                       'www.sa-venues.com': 2,
#                       'www.saddleback.edu': 6,
#                       'www.saintleo.edu': 1,
#                       'www.sakha.gov.ru': 2,
#                       'www.salesmanago.pl': 5,
#                       'www.sanebox.com': 1,
#                       'www.santana.com': 1,
#                       'www.santemagazine.fr': 1,
#                       'www.sapporobeer.jp': 1,
#                       'www.sbnation.com': 8,
#                       'www.sc.pages03.net': 1,
#                       'www.scannermaster.com': 1,
#                       'www.sci.gov.in': 1,
#                       'www.sciencemuseumgroup.org.uk': 1,
#                       'www.scienceworldreport.com': 1,
#                       'www.sdcexec.com': 1,
#                       'www.sdv.fr': 1,
#                       'www.securityguided.com': 5,
#                       'www.seetickets.us': 1,
#                       'www.self.com': 1,
#                       'www.sema.org': 1,
#                       'www.semesteratsea.org': 1,
#                       'www.sentex.ca': 2,
#                       'www.shareaholic.net': 4,
#                       'www.shieldsgazette.com': 1,
#                       'www.shinola.com': 1,
#                       'www.shipai123.com': 6,
#                       'www.shochiku.co.jp': 1,
#                       'www.shopperapproved.com': 2,
#                       'www.si.com': 1,
#                       'www.sidley.com': 1,
#                       'www.silverscreenandroll.com': 1,
#                       'www.sinclair.edu': 8,
#                       'www.singstat.gov.sg': 1,
#                       'www.skatteetaten.no': 1,
#                       'www.skillsahead.net': 2,
#                       'www.skybrary.aero': 7,
#                       'www.skyhorsepublishing.com': 1,
#                       'www.slant.co': 1,
#                       'www.slbenfica.pt': 1,
#                       'www.slowfood.it': 1,
#                       'www.smartmenus.org': 6,
#                       'www.smm.cn': 2,
#                       'www.smythstoys.com': 1,
#                       'www.sobyanin.ru': 1,
#                       'www.socialintents.com': 2,
#                       'www.socialstyrelsen.se': 6,
#                       'www.solarquotes.com.au': 1,
#                       'www.solidfiles.com': 1,
#                       'www.soundcloud.com': 1,
#                       'www.soundstrue.com': 1,
#                       'www.southwestern.edu': 6,
#                       'www.spareroom.co.uk': 1,
#                       'www.sport.de': 1,
#                       'www.sportsbookreview.com': 6,
#                       'www.ssga.com': 1,
#                       'www.stadtradeln.de': 1,
#                       'www.stampa.unibocconi.it': 7,
#                       'www.statcounter.com': 3,
#                       'www.stellen-anzeiger.ch': 1,
#                       'www.stihlusa.com': 1,
#                       'www.stlmag.com': 6,
#                       'www.stunnel.org': 6,
#                       'www.stylebop.com': 1,
#                       'www.suasnews.com': 1,
#                       'www.sulzer.com': 6,
#                       'www.supermap.com': 6,
#                       'www.supersaa.fi': 1,
#                       'www.supplychain247.com': 1,
#                       'www.supremesclothingonline.com': 6,
#                       'www.surrey.ca': 1,
#                       'www.svo.aero': 6,
#                       'www.swkong.com': 6,
#                       'www.symbicortinhalers.com': 3,
#                       'www.syncfusion.com': 1,
#                       'www.t-mobile.com': 2,
#                       'www.t-mobilemoney.com': 2,
#                       'www.taikang.com': 9,
#                       'www.talkandroid.com': 1,
#                       'www.tarabrach.com': 1,
#                       'www.taylorguitars.com': 1,
#                       'www.tdsb.on.ca': 1,
#                       'www.teachervision.com': 8,
#                       'www.team-bhp.com': 1,
#                       'www.team17.com': 9,
#                       'www.techlearning.com': 1,
#                       'www.technik-museum.de': 4,
#                       'www.teenvogue.com': 1,
#                       'www.telenor.no': 6,
#                       'www.template.net': 1,
#                       'www.teplconstructions.com': 6,
#                       'www.terra.com.mx': 1,
#                       'www.thechrisyates.com': 1,
#                       'www.thedailytimes.com': 1,
#                       'www.thehotelsnetwork.com': 1,
#                       'www.thejournal.ie': 1,
#                       'www.thelineofbestfit.com': 6,
#                       'www.them.us': 1,
#                       'www.themyersbriggs.com': 1,
#                       'www.theorchard.com': 6,
#                       'www.thepostgame.com': 1,
#                       'www.thompson-morgan.com': 1,
#                       'www.thrixxx.com': 2,
#                       'www.ti.ch': 1,
#                       'www.tiancity.com': 1,
#                       'www.tickettailor.com': 1,
#                       'www.tiktok.com': 1,
#                       'www.timberlandbootsuk.org.uk': 1,
#                       'www.timetoast.com': 1,
#                       'www.tns-counter.ru': 1,
#                       'www.tnvacation.com': 1,
#                       'www.tobi.com': 7,
#                       'www.tomsguide.fr': 1,
#                       'www.toto-agency.com': 1,
#                       'www.tourism.gov.my': 6,
#                       'www.touteleurope.eu': 6,
#                       'www.towerhobbies.com': 1,
#                       'www.tradebit.com': 1,
#                       'www.tradepub.com': 6,
#                       'www.transitionsabroad.com': 6,
#                       'www.trex.com': 6,
#                       'www.tripadvisor.com': 1,
#                       'www.tsf.pt': 6,
#                       'www.tuiasi.ro': 6,
#                       'www.tuxera.com': 1,
#                       'www.tv-osaka.co.jp': 2,
#                       'www.twingotuningforum.de': 6,
#                       'www.twobirds.com': 1,
#                       'www.uai.com.br': 2,
#                       'www.ubishops.ca': 6,
#                       'www.uia.no': 6,
#                       'www.ukrinform.ru': 1,
#                       'www.umcg.nl': 6,
#                       'www.umcutrecht.nl': 2,
#                       'www.uni-luebeck.de': 6,
#                       'www.unibocconi.eu': 6,
#                       'www.unicef.it': 1,
#                       'www.unicreditgroup.eu': 1,
#                       'www.unisender.com': 1,
#                       'www.unitedrentals.com': 1,
#                       'www.unitymedia.de': 6,
#                       'www.universe.com': 1,
#                       'www.usccr.gov': 6,
#                       'www.uvnc.com': 6,
#                       'www.uwsuper.edu': 6,
#                       'www.vacheron-constantin.com': 1,
#                       'www.vanityfair.com': 1,
#                       'www.vertex42.com': 1,
#                       'www.vicetv.com': 1,
#                       'www.videostudiopro.com': 6,
#                       'www.virgin.com': 1,
#                       'www.visitbritain.org': 6,
#                       'www.visitdublin.com': 6,
#                       'www.visitflanders.com': 6,
#                       'www.visithoustontexas.com': 1,
#                       'www.visitorsdetective.com': 6,
#                       'www.visitstockholm.com': 1,
#                       'www.vogella.com': 6,
#                       'www.vogue.com': 1,
#                       'www.vrr.de': 6,
#                       'www.vrt.be': 1,
#                       'www.w3.org': 1,
#                       'www.w3schools.com': 1,
#                       'www.walkhighlands.co.uk': 1,
#                       'www.wallace.edu': 6,
#                       'www.wanttoknow.info': 1,
#                       'www.warnerbros.com': 1,
#                       'www.washjeff.edu': 1,
#                       'www.wctrib.com': 1,
#                       'www.wealthx.com': 1,
#                       'www.webnode.com': 1,
#                       'www.websaiting.ru': 1,
#                       'www.weeklytimesnow.com.au': 1,
#                       'www.weltwoche-daily.ch': 6,
#                       'www.weltwoche.ch': 6,
#                       'www.westgateresorts.com': 2,
#                       'www.whatsmydns.net': 1,
#                       'www.wheelercentre.com': 1,
#                       'www.whitworth.edu': 6,
#                       'www.who.int': 1,
#                       'www.wifr.com': 1,
#                       'www.wikipedia.org': 1,
#                       'www.wired.com': 1,
#                       'www.wireshark.org': 1,
#                       'www.wisestamp.com': 1,
#                       'www.wmf.com': 1,
#                       'www.wmg.com': 1,
#                       'www.wminewmedia.com': 2,
#                       'www.wola.org': 1,
#                       'www.womanandhome.com': 1,
#                       'www.woodcraft.com': 1,
#                       'www.workfront.com': 1,
#                       'www.worldscientific.com': 1,
#                       'www.worldsteel.org': 1,
#                       'www.worldstopexports.com': 4,
#                       'www.wqxr.org': 2,
#                       'www.wrightslaw.com': 6,
#                       'www.wufoo.com': 1,
#                       'www.wuft.org': 6,
#                       'www.wunu.edu.ua': 1,
#                       'www.wvpublic.org': 1,
#                       'www.wwf.se': 1,
#                       'www.xprt.com': 1,
#                       'www.yabiladi.com': 1,
#                       'www.yandex.ru': 1,
#                       'www.yandy.com': 1,
#                       'www.yatra.com': 1,
#                       'www.yceml.net': 2,
#                       'www.yeezyadidas.de': 1,
#                       'www.yinxiang.com': 15,
#                       'www.youredm.com': 1,
#                       'www.yoursun.com': 2,
#                       'www.youtube-nocookie.com': 3,
#                       'www.youtube.com': 195,
#                       'www.youvisit.com': 3,
#                       'www.yummly.com': 1,
#                       'www.yvr.ca': 1,
#                       'www.zedo.com': 6,
#                       'www.zenithmedia.com': 1,
#                       'www.zerochan.net': 1,
#                       'www.zikao365.com': 4,
#                       'www.zimperium.com': 1,
#                       'www.zoom.co.jp': 2,
#                       'www.zooniverse.org': 1,
#                       'www1-camra.s3.eu-west-1.amazonaws.com': 6,
#                       'www2.archivists.org': 6,
#                       'www3.smartadserver.com': 7,
#                       'www4.ti.ch': 6,
#                       'www7.nungsub.com': 1,
#                       'wwwcdn.icewarp.com': 5,
#                       'wwws.phpfox.com': 3,
#                       'wwwwwfse.cdn.triggerfish.cloud': 1,
#                       'wyborcza.biz': 1,
#                       'x.bidswitch.net': 16,
#                       'x.dlx.addthis.com': 1,
#                       'x01.aidata.io': 1,
#                       'xamrk-garage.ru': 1,
#                       'xd.adnz.co': 1,
#                       'xiaoe-tech.com': 4,
#                       'xlr8r.com': 1,
#                       'xprt.com': 1,
#                       'xxx99porn.com': 1,
#                       'xxxclubporn.com': 1,
#                       'xzeepexcrpappzpsta001.blob.core.windows.net': 6,
#                       'y.one.impact-ad.jp': 3,
#                       'yandex-dmp-sync.rutarget.ru': 1,
#                       'yandex-sync.rutarget.ru': 1,
#                       'yandex.ru': 4,
#                       'yandex.st': 2,
#                       'yastatic.net': 17,
#                       'yatra.com': 1,
#                       'ycdn.space': 1,
#                       'yeezy350.de': 1,
#                       'yeha9jhq29.kameleoon.eu': 1,
#                       'yemle.com': 1,
#                       'yinxiang.com': 1,
#                       'yjtag.yahoo.co.jp': 2,
#                       'ymbm21photography.com': 6,
#                       'yoda.unifyed.com': 2,
#                       'yoomoney.ru': 6,
#                       'youradexchange.com': 1,
#                       'yourdream-men.com': 13,
#                       'youtube.com': 1,
#                       'ysa-static.passport.yandex.ru': 1,
#                       'ysf.nosdn.127.net': 1,
#                       'yt3.ggpht.com': 112,
#                       'yuansu.bjmama.net': 2,
#                       'z-na.amazon-adsystem.com': 2,
#                       'z.moatads.com': 36,
#                       'z.omappapi.com': 3,
#                       'z4.cnzz.com': 2,
#                       'z47b66a07.webengage.co': 1,
#                       'z716800b0.webengage.co': 1,
#                       'za-ssl.effectivemeasure.net': 1,
#                       'zalywzdew6.execute-api.us-west-2.amazonaws.com': 1,
#                       'zdbb.net': 1,
#                       'zdstatic.offers.com': 1,
#                       'zdwidget3-bs.sphereup.com': 1,
#                       'zeny-sro.cz': 1,
#                       'zew.de': 1,
#                       'ziffdavis-d.openx.net': 1,
#                       'zimperium.com': 1,
#                       'zippyfrog.co': 10,
#                       'zn1wupqbzyftkeju9-keurig2.siteintercept.qualtrics.com': 1,
#                       'zn38kmxsyn4s1wiwv-caleres.siteintercept.qualtrics.com': 1,
#                       'zn3edajdvgwonv9nr-tmobilecx.siteintercept.qualtrics.com': 1,
#                       'zn3f8e6tceotw1rnn-aholddelhaize.siteintercept.qualtrics.com': 1,
#                       'zn3gccbbkzbefhqgi-redventures.siteintercept.qualtrics.com': 1,
#                       'zn3ycznnhctkdninz-som.siteintercept.qualtrics.com': 1,
#                       'zn7nj5omfyyzlxou-tmobilecx.siteintercept.qualtrics.com': 1,
#                       'zn89eyacwoagryozj-cvspbm.siteintercept.qualtrics.com': 1,
#                       'znaj.ua': 1,
#                       'zoomcorp.com': 1,
#                       'zumvu.com': 1,
#                       'zz.bdstatic.com': 6},
#  'Sampling Limit': 25000}
