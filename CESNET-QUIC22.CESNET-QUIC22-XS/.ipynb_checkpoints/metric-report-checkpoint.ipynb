# %%
import json
import yaml
from IPython.display import JSON
from pprint import pprint

# %%
with open('report-dataset-1735846462.csv', 'r') as file:
    basic = json.load(file)
pprint(basic)
# Out:
# {'Analyzed Samples': {'0': 155,
#                       '1': 140,
#                       '10': 494,
#                       '100': 35447,
#                       '11': 1523,
#                       '12': 1765,
#                       '13': 6184,
#                       '14': 7004,
#                       '15': 1565,
#                       '16': 128,
#                       '17': 20613,
#                       '18': 1029,
#                       '19': 19892,
#                       '2': 53,
#                       '20': 496,
#                       '21': 361,
#                       '22': 1105,
#                       '23': 62,
#                       '24': 193,
#                       '25': 457,
#                       '26': 7737,
#                       '27': 1962,
#                       '28': 23739,
#                       '29': 24196,
#                       '3': 1580,
#                       '30': 3876,
#                       '31': 1205,
#                       '32': 20140,
# ...

# %%
with open('metric-advanced-log-sample.json', 'r') as file:
    advanced = json.load(file)
pprint(advanced)
# Out:
# {'Analyzed Samples': {'False': 5000, 'True': 4999},
#  'Association': {'Association': 0.4251234890923732,
#                  'Max Clf Score': 0.9685969754078328,
#                  'P-value status': 'Good',
#                  'Raw AUC': 0.3813551562764921,
#                  'Raw Slope': 0.9396751714764401},
#  'Classes': 2,
#  'Date': '01/02/25',
#  'Duplicated Feature Vectors': 1,
#  'Feature List': {'autocorr': '',
#                   'av_pkt_size': '',
#                   'av_pkt_size_rev': '',
#                   'avgdelay': '',
#                   'bursts': '',
#                   'bytes': '',
#                   'bytes_ration': '',
#                   'bytes_rev': '',
#                   'fazzel': '',
#                   'is_doh': '',
#                   'maxdelay': '',
#                   'median_pkt_size': '',
#                   'median_pkt_size_rev': '',
#                   'mindelay': '',
#                   'ndSum': '',
#                   'num_pkts_ration': '',
# ...

# %%
# TODO add pickled permutation data

# %%
with open("config.yml", "r") as stream:
    cfg = yaml.safe_load(stream)
pprint(cfg)
# Out:
# {'delete_duplicated': True,
#  'delete_nan': True,
#  'delimiter': ',',
#  'metric_config': ['modules.metric1.Redundancy',
#                    'modules.metric2.Association',
#                    'modules.metric3.Similarity'],
#  'sampling_limit': 5000,
#  'verbose': 5}
