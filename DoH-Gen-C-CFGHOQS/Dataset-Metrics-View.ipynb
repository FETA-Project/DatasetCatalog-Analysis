# %%
import sys
# Import NDVM modules to load pickled data
# NOTE: Modify based on your environment
sys.path.append('/home/dosoukup/Dataset/drift-katoda-v2/katoda-tools/ndvm/modules')
sys.path.append('/home/dosoukup/Dataset/drift-katoda-v2/katoda-tools/ndvm')
import os
import pickle
import metric1, metric3, metric2x
import json
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.cm as cm
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import auc
import pandas as pd

# %%
# NOTE: Modify based on your report. By default it is enough to change the id number
REPORT_NAME = "metrics/report-dataset-1762929499"

# %% [markdown]
# # General Report

# %%
with open(REPORT_NAME+'.csv', 'r') as file:
    basic = json.load(file)
pprint(basic)
# Out:
# {'Analyzed Samples': {'0cf861243d0446f2b4ecfba565358a71.js.ubembed.com': 1,
#                       '0da83dce5f344fbf863e529a587090c6.js.ubembed.com': 1,
#                       '0f20f48d.de.ioam.de': 1,
#                       '0jlwuu42oo-flywheel.netdna-ssl.com': 4,
#                       '1.rc.xiniu.com': 6,
#                       '100021108.collect.igodigital.com': 1,
#                       '100030112.collect.igodigital.com': 1,
#                       '10959716.collect.igodigital.com': 1,
#                       '10b7b33f74584ce79f480ee868273e13-e11233f1926a.cdn.forter.com': 1,
#                       '110007893.collect.igodigital.com': 1,
#                       '117259306.intellimizeio.com': 1,
#                       '118vod-adaptive.akamaized.net': 2,
#                       '125mb.com': 8,
#                       '12m8i445l6vu3tq6u4315zj5-wpengine.netdna-ssl.com': 1,
#                       '141488.tracking.hyros.com': 1,
#                       '141488.tracking.markethero.io': 1,
#                       '147-229-13-93_s-195-113-232-72_ts-1631181583-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-195-113-232-72_ts-1631184275-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-195-113-232-72_ts-1631193909-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-195-113-232-72_ts-1631613010-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-195-113-232-72_ts-1631631229-clienttons-s.akamaihd.net': 1,
#                       '147-229-13-93_s-195-113-232-75_ts-1631615479-clienttons-s.akamaihd.net': 1,
#                       '14vod-adaptive.akamaized.net': 1,
#                       '15851f6dcbdd47579a91bc49b150def4.events.ubembed.com': 2,
#                       '15851f6dcbdd47579a91bc49b150def4.js.ubembed.com': 1,
#                       '1788794e01e843bf97e2dfc04f325fc7.events.ubembed.com': 1,
#                       '1788794e01e843bf97e2dfc04f325fc7.js.ubembed.com': 1,
#                       '178vod-adaptive.akamaized.net': 1,
#                       '179vod-adaptive.akamaized.net': 1,
#                       '1800petmeds.com': 1,
#                       '1805bd6b0033416884c70511c9030226.js.ubembed.com': 1,
#                       '183vod-adaptive.akamaized.net': 1,
#                       '1abxf1rh6g01lhm2riyrt55k-wpengine.netdna-ssl.com': 2,
#                       '1c5fd8f9.de.ioam.de': 1,
#                       '1gzigc2wpsxy2gfa3t38i362-wpengine.netdna-ssl.com': 6,
#                       '1qpfw1257v1q883uy3tvbob1-wpengine.netdna-ssl.com': 6,
#                       '2125ht9m59-dsn.algolia.net': 1,
#                       '22b375f28cb4a3978d5e-76f43cbbcaa8592c8e9d0bfe87e3817b.ssl.cf2.rackcdn.com': 6,
#                       '23261636.de.ioam.de': 1,
#                       '24dlmn2bqamt1e72kah59881-wpengine.netdna-ssl.com': 7,
#                       '24f3e184a81b4e2f8da6ce7376b81908.js.ubembed.com': 1,
#                       '29773.v.fwmrm.net': 1,
#                       '2bbgsa3qmesj4chqra8hhkbg-wpengine.netdna-ssl.com': 6,
#                       '2gqdkq4bpinp49wvci47k081-wpengine.netdna-ssl.com': 6,
#                       '2i1suz1s0n5g1i6ph4z0sw1b-wpengine.netdna-ssl.com': 9,
#                       '2puhts35rx35be1br3heq2zn-wpengine.netdna-ssl.com': 7,
#                       '31be92f6-71a7-4866-9ea1-de4a80da8566.t.ssp.hinet.net': 2,
#                       '3c93ca0a155f2a534f8e-d885401cfa0d1cfa0d30eadd160f82a9.ssl.cf1.rackcdn.com': 1,
#                       '3cfbfb0553974aafbc31-74c41e68ace2933c08ef8ba40eaa02f3.ssl.cf1.rackcdn.com': 2,
#                       '3f1c29ed877541d1a319bc5e3790e2de-21bc2c8007cb.cdn.forter.com': 1,
#                       '3f4bff44.de.ioam.de': 1,
#                       '3rdlearning.zendesk.com': 1,
#                       '4378dc7d-cad7-4dd3-b031-159cc1291369.rlets.com': 1,
#                       '46lanyw7z3s2f7x3o36znccd-wpengine.netdna-ssl.com': 6,
#                       '47d4b1ab.de.ioam.de': 1,
#                       '48hourfilm.com': 1,
#                       '514004470.collect.igodigital.com': 1,
#                       '514011888.collect.igodigital.com': 1,
#                       '5vod-adaptive.akamaized.net': 1,
#                       '6236766.collect.igodigital.com': 1,
#                       '6852bd0e.akstat.io': 1,
#                       '685d5b19.akstat.io': 1,
#                       '6b8b3d13a9a44d509b0a0abda7b645a8.js.ubembed.com': 1,
#                       '6f5295793b132e9764f4-3f2730cf5c1e4ad5dfe76e6d27af2964.ssl.cf5.rackcdn.com': 2,
#                       '7202503.collect.igodigital.com': 1,
#                       '7296325.collect.igodigital.com': 1,
#                       '735bdc68d08a4954a7db2abee7316af7.js.ubembed.com': 1,
#                       '74d5bd0b-9537-e695-058a-5c538e3f7714-rum.cdnvideo.ru': 1,
#                       '7a6cf7b28bb7433b8baf512ebf2de420.js.ubembed.com': 1,
#                       '83vod-adaptive.akamaized.net': 1,
#                       '849b588d.de.ioam.de': 1,
#                       '898e2bcb-71c4-439d-b125-481b264275cb.rlets.com': 2,
#                       '90vod-adaptive.akamaized.net': 1,
#                       '918e76e9-1708-4166-a62a-5d1d997bd974.rlets.com': 2,
#                       '96vod-adaptive.akamaized.net': 1,
#                       '9b68ea3a-84dd-413f-9a0f-92bca44285a4.rlets.com': 1,
#                       '9f53b268.de.ioam.de': 1,
#                       'a-16261128.gatorapi.com': 1,
#                       'a-84279296.ns8ds.com': 1,
#                       'a-84279296.nscontrol.com': 1,
#                       'a.ad.gt': 2,
#                       'a.disquscdn.com': 2,
#                       'a.giraff.io': 2,
#                       'a.imgvc.com': 2,
#                       'a.pourquoidocteur.fr': 1,
#                       'a.tile.openstreetmap.org': 6,
#                       'a.vidoomy.com': 2,
#                       'a2.adform.net': 1,
#                       'a2eea634e272e4d0397b-945473fc3cc5469c566cabae88ab28a4.ssl.cf1.rackcdn.com': 6,
#                       'a4c844114f6c01448a4d-8a6f208e5f85b2152fef255cbf6f01ae.ssl.cf1.rackcdn.com': 1,
#                       'a4p.adpartner.pro': 3,
#                       'aa.agkn.com': 18,
#                       'aamapi.com': 1,
#                       'aax-eu.amazon-adsystem.com': 2,
#                       'aax-us-east.amazon-adsystem.com': 3,
#                       'abcpaperwriter.com': 1,
#                       'abmp.com': 1,
#                       'abs-0.twimg.com': 4,
#                       'abs.twimg.com': 2,
#                       'accdn.lpsnmedia.net': 6,
#                       'accounts.haymarketmedia.com': 1,
#                       'accwww6.53kf.com': 1,
#                       'acdn.adnxs.com': 15,
#                       'acepi.pt': 1,
#                       'ad.360yield.com': 5,
#                       'ad.adriver.ru': 7,
#                       'ad.crwdcntrl.net': 2,
#                       'ad.holmesmind.com': 2,
#                       'ad.jp.ap.valuecommerce.com': 2,
#                       'ad.mail.ru': 5,
#                       'ada.baidu.com': 2,
#                       'adcdn.goo.ne.jp': 2,
#                       'adfox-hb-bidder.rutarget.ru': 1,
#                       'admin.cw.no': 5,
#                       'adminlte.io': 1,
#                       'admmegion.ru': 1,
#                       'ads.counciladvertising.net': 1,
#                       'ads.nextdoor.com': 5,
#                       'ads.pubmatic.com': 17,
#                       'ads.servenobid.com': 2,
#                       'ads.stickyadstv.com': 25,
#                       'ads.themoneytizer.com': 4,
#                       'ads.vidoomy.com': 2,
#                       'ads.yieldmo.com': 6,
#                       'adservices.brandcdn.com': 3,
#                       'adshop.infolinks.com': 1,
#                       'adv.drtuber.com': 1,
#                       'advertising.goldseek.com': 1,
#                       'adx-exchange.toast.com': 2,
#                       'adx.adform.net': 23,
#                       'adx.dable.io': 4,
#                       'affiliate.ria.com': 2,
#                       'affiliates.cdkeys.com': 1,
#                       'afl.prom.ua': 1,
#                       'afpnet.org': 1,
#                       'aftermarket.helpcrunch.com': 1,
#                       'ai.ocelotbot.com': 2,
#                       'aicstaging.aiproxies.com': 1,
#                       'aid.send.microad.jp': 2,
#                       'aidata-sync.rutarget.ru': 1,
#                       'aiqua-config.c.appier.net': 2,
#                       'akcdn.detik.net.id': 2,
#                       'aktrack.pubmatic.com': 2,
#                       'akutszakasz.hu': 6,
#                       'alcatrazcruises.com': 1,
#                       'alcdn.msauth.net': 1,
#                       'alexhost.com': 1,
#                       'aliyun-page.cn-hangzhou.log.aliyuncs.com': 2,
#                       'aliyun-web-tracker.cn-zhangjiakou.log.aliyuncs.com': 2,
#                       'am-0.moevideo.biz': 5,
#                       'am-assets.pl': 6,
#                       'am-match.taboola.com': 3,
#                       'am-trc-events.taboola.com': 4,
#                       'am-vid-events.taboola.com': 3,
#                       'am.adlooxtracking.com': 1,
#                       'amanda.v4.omgtnc.com': 1,
#                       'amia.org': 1,
#                       'amonas.aamulehti.fi': 1,
#                       'amp.akamaized.net': 6,
#                       'amplify.outbrain.com': 6,
#                       'ams.makersmark.com': 2,
#                       'ams1-ib.adnxs-simple.com': 4,
#                       'an.yandex.ru': 27,
#                       'anah.fr': 1,
#                       'analytics-logger.service.junctiontv.net': 2,
#                       'analytics.ad.daum.net': 4,
#                       'analytics.aimediagroup.com': 2,
#                       'analytics.clickdimensions.com': 1,
#                       'analytics.ctbuh.org': 2,
#                       'analytics.foresee.com': 1,
#                       'analytics.getshogun.com': 3,
#                       'analytics.gov.yk.ca': 2,
#                       'analytics.ikyu.com': 1,
#                       'analytics.nouvelle-aquitaine.pro': 1,
#                       'analytics.shareaholic.com': 4,
#                       'analytics.sitewit.com': 1,
#                       'analytics.theshifters.org': 1,
#                       'analytics.webads.eu': 2,
#                       'analytics.webpushr.com': 2,
#                       'anastasiathemusical.com': 1,
#                       'answersstatus.pagescdn.com': 1,
#                       'antenna.ayads.co': 1,
#                       'anymind360.com': 2,
#                       'api-cdn.amazon.com': 1,
#                       'api-iam.intercom.io': 10,
#                       'api-sa.substrate.io': 1,
#                       'api.adshop.infolinks.com': 1,
#                       'api.affirm.com': 1,
#                       'api.amplitude.com': 9,
#                       'api.aws.parking.godaddy.com': 7,
#                       'api.bazaarvoice.com': 9,
#                       'api.blink.net': 1,
#                       'api.bookscouter.com': 2,
#                       'api.chinapp.com': 1,
#                       'api.clerk.io': 1,
#                       'api.composer.nprstations.org': 3,
#                       'api.convertkit.com': 2,
#                       'api.dec.sitefinity.com': 1,
#                       'api.intellimize.co': 1,
#                       'api.ipdata.co': 1,
#                       'api.iperceptions.com': 2,
#                       'api.letro.jp': 2,
#                       'api.levelaccess.net': 1,
#                       'api.luigisbox.com': 1,
#                       'api.msn.com': 56,
#                       'api.parsely.com': 1,
#                       'api.pushowl.com': 1,
#                       'api.quantumgraph.com': 1,
#                       'api.refiner.io': 1,
#                       'api.ruliweb.com': 2,
#                       'api.sail-personalize.com': 2,
#                       'api.segment.io': 9,
#                       'api.stream-io-api.com': 2,
#                       'api.tenable.com': 1,
#                       'api.travis-ci.org': 1,
#                       'api.trustedshops.com': 1,
#                       'api.usehero.com': 1,
#                       'api.userway.org': 10,
#                       'api.uxtweak.com': 1,
#                       'api.weibo.com': 2,
#                       'api.zetaglobal.net': 1,
#                       'apiv2.popupsmart.com': 2,
#                       'apo.org.au': 1,
#                       'apogeedigital.zendesk.com': 1,
#                       'app-g.39.net': 3,
#                       'app.clickfunnels.com': 1,
#                       'app.launchdarkly.com': 2,
#                       'app.optimalworkshop.com': 1,
#                       'app.quotemedia.com': 2,
#                       'app.replain.cc': 1,
#                       'app4you.cafe24.com': 2,
#                       'appier.hitosara.com': 5,
#                       'aps.hearstnp.com': 2,
#                       'aqha.com': 1,
#                       'aqhaservices3.aqha.com': 2,
#                       'arc.msn.com': 17,
#                       'archaeological.org': 1,
#                       'as-sec.casalemedia.com': 20,
#                       'ascpqnj-oam.global.ssl.fastly.net': 1,
#                       'asset.pagefair.com': 1,
#                       'asset.pagefair.net': 1,
#                       'assets.bettyblocks.com': 1,
#                       'assets.clickfunnels.com': 1,
#                       'assets.dunelm.com': 4,
#                       'assets.euractiv.com': 2,
#                       'assets.hearstapps.com': 3,
#                       'assets.indavideo.hu': 7,
#                       'assets.rebelmouse.io': 1,
#                       'assets.sitescdn.net': 1,
#                       'assets3.cre.ma': 2,
#                       'async-px.dynamicyield.com': 9,
#                       'at-at.prd.simplisafe.com': 1,
#                       'atconnect.npo.nl': 2,
#                       'aufp.io': 2,
#                       'auth.qustodio.com': 1,
#                       'auto-cart-add.firebaseio.com': 1,
#                       'avatars.mds.yandex.net': 22,
#                       'avd.innity.net': 2,
#                       'avid.8v4lqg.net': 1,
#                       'avlsh.visilabs.net': 1,
#                       'aws-tiqets-cdn.imgix.net': 1,
#                       'awscdn.detik.net.id': 5,
#                       'awsimages.detik.net.id': 2,
#                       'ayrancimetal.com': 4,
#                       'b.aegpresents.com': 2,
#                       'b.clarity.ms': 4,
#                       'b.tile.openstreetmap.org': 4,
#                       'badges.altmetric.com': 3,
#                       'bagwmeck2nwwbnt9oyexnvolzrirn1631197151.darnuid.imrworldwide.com': 1,
#                       'banners.adfox.ru': 2,
#                       'baptisthealth.net': 6,
#                       'bastyr.edu': 1,
#                       'bat.bing.com': 84,
#                       'bc.ad.daum.net': 4,
#                       'bc7a0481fbe9fc00d2ad-d0fb4c04c27ce6b8afd3fc4f2adb93df.ssl.cf1.rackcdn.com': 1,
#                       'bcboltbde696aa-a.akamaihd.net': 2,
#                       'bcp.crwdcntrl.net': 20,
#                       'bcycle.com': 1,
#                       'beacon.krxd.net': 16,
#                       'beacon.riskified.com': 1,
#                       'belavia.by': 6,
#                       'berkeleycollege.edu': 1,
#                       'bernaunet.com': 1,
#                       'betabrand.com': 1,
#                       'bf47826akg.bf.dynatrace.com': 2,
#                       'bff81db10131243c2cd2-33f2a9aa601bdf8f374ff572418adb22.ssl.cf1.rackcdn.com': 1,
#                       'bgd1.purplepatch.online': 1,
#                       'biddr.brealtime.com': 5,
#                       'bidorbuy.co.za': 1,
#                       'biletix.com': 1,
#                       'bing.com': 1,
#                       'bjgp.org': 1,
#                       'bkmedicalcom.mpeasylink.com': 1,
#                       'bleep.com': 6,
#                       'bleep.zendesk.com': 1,
#                       'blockstack.org': 1,
#                       'blog.wilmu.edu': 3,
#                       'bluray-disc.de': 6,
#                       'booklooker.de': 1,
#                       'boot.dev.pubstack.io': 1,
#                       'bootstrap.api.drift.com': 10,
#                       'bot.percept.ai': 1,
#                       'bpi.rtactivate.com': 4,
#                       'breakthroughinitiatives.org': 1,
#                       'breville.tt.omtrdc.net': 1,
#                       'bridge.aliyun.com': 1,
#                       'browser.sentry-cdn.com': 3,
#                       'bs.nakanohito.jp': 6,
#                       'bs.serving-sys.com': 10,
#                       'btlr.sharethrough.com': 22,
#                       'bttrack.com': 4,
#                       'business.amwell.com': 1,
#                       'c.bazo.io': 3,
#                       'c.bing.com': 9,
#                       'c.clarity.ms': 10,
#                       'c.cnzz.com': 2,
#                       'c.contentsquare.net': 14,
#                       'c.evidon.com': 31,
#                       'c.flx1.com': 1,
#                       'c.go-mpulse.net': 3,
#                       'c.riskified.com': 1,
#                       'c.tile.openstreetmap.org': 4,
#                       'c.webengage.com': 1,
#                       'c1.adform.net': 2,
#                       'ca-eu.cookie-script.com': 1,
#                       'cadenaser00.epimg.net': 1,
#                       'cafe24img.poxo.com': 6,
#                       'calendar.time.ly': 1,
#                       'cam4.com': 1,
#                       'canine.org': 1,
#                       'capture.trackjs.com': 1,
#                       'castr.fabricmedia.ru': 1,
#                       'catalog.ggc.edu': 2,
#                       'catawba.edu': 6,
#                       'cc.swiftype.com': 1,
#                       'ccab.org': 1,
#                       'ccim.realmagnet.land': 1,
#                       'ccpa-service.sp-prod.net': 1,
#                       'cdkeys.zendesk.com': 1,
#                       'cdn-b.william-reed.com': 3,
#                       'cdn-pci.optimizely.com': 1,
#                       'cdn-resprivacy.pressidium.com': 8,
#                       'cdn-rtb.sape.ru': 3,
#                       'cdn-stamped-io.azureedge.net': 2,
#                       'cdn-web.tunein.com': 6,
#                       'cdn.adnxs-simple.com': 1,
#                       'cdn.adnxs.com': 1,
#                       'cdn.callibri.ru': 1,
#                       'cdn.callrail.com': 1,
#                       'cdn.calltrk.com': 3,
#                       'cdn.ckeditor.com': 2,
#                       'cdn.clerk.io': 1,
#                       'cdn.cnbcindonesia.com': 9,
#                       'cdn.contentful.com': 4,
#                       'cdn.cooladata.com': 1,
#                       'cdn.dingxiang-inc.com': 1,
#                       'cdn.embed.ly': 1,
#                       'cdn.embedly.com': 2,
#                       'cdn.evgnet.com': 1,
#                       'cdn.exmarketplace.com': 6,
#                       'cdn.experrto.io': 2,
#                       'cdn.generalcable.com': 2,
#                       'cdn.gmossp-sp.jp': 1,
#                       'cdn.imhd.io': 1,
#                       'cdn.indicative.com': 1,
#                       'cdn.karmaloopassets.com': 6,
#                       'cdn.krxd.net': 10,
#                       'cdn.linkmink.com': 1,
#                       'cdn.megadata.co.kr': 2,
#                       'cdn.mookie1.com': 2,
#                       'cdn.mouseflow.com': 3,
#                       'cdn.onthe.io': 4,
#                       'cdn.petametrics.com': 3,
#                       'cdn.polyfill.io': 9,
#                       'cdn.pushalert.co': 1,
#                       'cdn.pushpushgo.com': 1,
#                       'cdn.recognified.net': 1,
#                       'cdn.rudo.video': 2,
#                       'cdn.ruled.me': 8,
#                       'cdn.sandersondesigngroup.com': 6,
#                       'cdn.seated.com': 1,
#                       'cdn.sirdata.io': 1,
#                       'cdn.smartclip-services.com': 1,
#                       'cdn.speedcurve.com': 1,
#                       'cdn.syndication.twimg.com': 2,
#                       'cdn.teleport.media': 2,
#                       'cdn.tim.ticdn.it': 5,
#                       'cdn.trafficdok.com': 1,
#                       'cdn.ussailing.org': 7,
#                       'cdn.viglink.com': 3,
#                       'cdn.vox-cdn.com': 24,
#                       'cdn.webpushr.com': 1,
#                       'cdn.yottaa.com': 3,
#                       'cdn0.forter.com': 2,
#                       'cdn1-l-ha-e11.mdhcdn.com': 1,
#                       'cdn1-s-ha-e15.mdhcdn.com': 5,
#                       'cdn1.affirm.com': 5,
#                       'cdn1.readspeaker.com': 1,
#                       'cdn1.stamped.io': 3,
#                       'cdn1.twloha.com': 2,
#                       'cdn1.vox-cdn.com': 1,
#                       'cdn2.vox-cdn.com': 2,
#                       'cdn3.forter.com': 2,
#                       'cdn3.optimizely.com': 1,
#                       'cdnetworks.cedexis-test.com': 1,
#                       'cdnondemand.org': 1,
#                       'cdns.au1.gigya.com': 1,
#                       'cdns.eu1.gigya.com': 2,
#                       'cds.taboola.com': 3,
#                       'cebr.com': 1,
#                       'centrify.com': 1,
#                       'cfa-js.cafe24.com': 2,
#                       'cfjump.dymocks.com.au': 2,
#                       'cfjump.kkday.com': 2,
#                       'chart.rsf.ru': 16,
#                       'chat-us-east-1.stream-io-api.com': 1,
#                       'chatbot.sibur.ru': 5,
#                       'chatbot.tra.gov.ae': 1,
#                       'checkin.purechat.com': 1,
#                       'childrens.com': 2,
#                       'chimpstatic.com': 14,
#                       'chinapp.com': 1,
#                       'choices.consentframework.com': 3,
#                       'citbank.tt.omtrdc.net': 1,
#                       'citizenwatch.com': 1,
#                       'citizenwatch.ingest.z-analytics.net': 1,
#                       'citizenwatch.zendesk.com': 1,
#                       'clarium.global.ssl.fastly.net': 2,
#                       'clck.yandex.ru': 2,
#                       'clickgate08.biz': 1,
#                       'clickio.mgr.consensu.org': 1,
#                       'clickiocdn.com': 4,
#                       'client-registry.mutinycdn.com': 1,
#                       'client.getinchat.com': 1,
#                       'client.teamviewer.com': 8,
#                       'clients.sibur.com': 1,
#                       'cloud.roistat.com': 1,
#                       'cloud.tenable.com': 1,
#                       'cloud.typography.com': 12,
#                       'cm.adform.net': 1,
#                       'cm.adsafety.net': 1,
#                       'cm.e.qq.com': 2,
#                       'cm.everesttech.net': 37,
#                       'cm.p.altergeo.ru': 2,
#                       'cmcrm.zendesk.com': 1,
#                       'cms.analytics.yahoo.com': 3,
#                       'cms.getblue.io': 3,
#                       'cms32.mcdonalds.ca': 1,
#                       'cn.aliyun.com': 2,
#                       'cnib.ca': 1,
#                       'cnzz.mmstat.com': 12,
#                       'code.createjs.com': 8,
#                       'code.directadvert.ru': 1,
#                       'code.tidio.co': 2,
#                       'codesign.blog': 6,
#                       'coinmill.com': 1,
#                       'col.site24x7rum.eu': 1,
#                       'coleparmer.com': 1,
#                       'coliseum.stream.voidboost.cc': 1,
#                       'collect.mopinion.com': 2,
#                       'collect.ptengine.cn': 2,
#                       'collect.tealiumiq.com': 4,
#                       'collection.decibelinsight.net': 2,
#                       'colossusssp.com': 2,
#                       'colres.sitelabweb.com': 1,
#                       'columbustelegram.com': 1,
#                       'commercial.daznservices.com': 1,
#                       'common.sandersondesigngroup.com': 1,
#                       'concheck.adsafety.net': 1,
#                       'confiant-integrations.global.ssl.fastly.net': 20,
#                       'config1.veinteractive.com': 1,
#                       'connect-metrics-collector.s-onetag.com': 6,
#                       'connect.ok.ru': 7,
#                       'console.e-bot7.de': 1,
#                       'consumer.krxd.net': 11,
#                       'cont001.ias.global.rakuten.com': 6,
#                       'contact-api.inguest.com': 1,
#                       'content.adriver.ru': 1,
#                       'content.healthwise.net': 1,
#                       'content.inpwrd.net': 1,
#                       'content.the-saleroom.com': 6,
#                       'contextual.sirdata.io': 1,
#                       'cookie-script.com': 1,
#                       'cookiee1.veinteractive.com': 1,
#                       'cookies.bioscientifica.com': 2,
#                       'cookies.frankenpost.de': 1,
#                       'cookies.prod.tekla.com': 1,
#                       'cookiesync.mparticle.com': 1,
#                       'core.conversant.mgr.consensu.org': 2,
#                       'count-us.rudo.video': 1,
#                       'counter.rambler.ru': 7,
#                       'counter.yadro.ru': 46,
#                       'countryeconomy.com': 1,
#                       'covid.is': 1,
#                       'cp601.prod.do.dsp.mp.microsoft.com': 1,
#                       'cpa.ca': 1,
#                       'cpt.geniee.jp': 2,
#                       'cr.acecounter.com': 2,
#                       'creativebughelp.zendesk.com': 1,
#                       'creator.bimbim.com': 1,
#                       'crm.mediacategory.com': 2,
#                       'crumbs.musement.com': 1,
#                       'cs-0.moevideo.biz': 3,
#                       'cs.admanmedia.com': 3,
#                       'cs.emxdgt.com': 4,
#                       'cs.guta.com': 2,
#                       'cs.lkqd.net': 8,
#                       'cs.nakanohito.jp': 2,
#                       'ctbuh.org': 1,
#                       'cubed.lovehoney.co.uk': 1,
#                       'culturaltracking.ru': 2,
#                       'd-cache.microad.jp': 2,
#                       'd.adroll.com': 23,
#                       'd.clarity.ms': 2,
#                       'd.socdm.com': 4,
#                       'd.spokenlayer.com': 1,
#                       'd7d3cf2e81d293050033-3dfc0615b0fd7b49143049256703bfce.ssl.cf1.rackcdn.com': 1,
#                       'da404861754b37a203d4-9f368a0245dfefe361553226c1489d96.ssl.cf1.rackcdn.com': 4,
#                       'dadebaran.ir': 6,
#                       'daisho.firebaseio.com': 1,
#                       'danang.gov.vn': 6,
#                       'danskebank.com': 6,
#                       'darkpatterns.org': 1,
#                       'data.cdnbasket.net': 5,
#                       'data.giraff.io': 1,
#                       'data.gosquared.com': 3,
#                       'data.th.giraff.io': 2,
#                       'davidwolfe.disqus.com': 1,
#                       'daznplayersp-vh.akamaihd.net': 1,
#                       'db0y8smio0.execute-api.us-east-2.amazonaws.com': 1,
#                       'dc.ads.linkedin.com': 1,
#                       'dc.oracleinfinity.io': 6,
#                       'dc.services.visualstudio.com': 15,
#                       'de.squat.net': 1,
#                       'delivery.r2b2.cz': 2,
#                       'dermalogica.zendesk.com': 1,
#                       'descript.com': 1,
#                       'dev.realfarmacy.com': 1,
#                       'dev.virtualearth.net': 1,
#                       'developers.kakao.com': 2,
#                       'dff61d947971d394f2d1-ceaaaf2e19f29d0dc25b89ea50017777.ssl.cf1.rackcdn.com': 1,
#                       'dfm-redlandsdailyfacts.disqus.com': 1,
#                       'digitalfirstmedia.blueconic.net': 1,
#                       'dingo.care2.com': 2,
#                       'directline.botframework.com': 1,
#                       'display.ipaper.io': 2,
#                       'disqus.com': 1,
#                       'distillery.wistia.com': 15,
#                       'dl.dropboxusercontent.com': 2,
#                       'dmarc.org': 25,
#                       'dmg.digitaltarget.ru': 11,
#                       'dmp.adform.net': 5,
#                       'doctorsfile.jp': 2,
#                       'documentary.org': 1,
#                       'doh.opendns.com': 3037,
#                       'domainecology-common.oss-cn-shenzhen.aliyuncs.com': 6,
#                       'domainecology-pro.oss-cn-shenzhen.aliyuncs.com': 6,
#                       'doomworld.com': 1,
#                       'dqj4r0q8wb-dsn.algolia.net': 1,
#                       'dr.yandex.net': 2,
#                       'dri.es': 1,
#                       'driftt.imgix.net': 6,
#                       'drtuber.com': 1,
#                       'drtuprofet.com': 1,
#                       'ds-aksb-a.akamaihd.net': 2,
#                       'dsp.adkernel.com': 2,
#                       'dsum-sec.casalemedia.com': 8,
#                       'dt.adsafeprotected.com': 10,
#                       'dtm.bethematch.org': 2,
#                       'dtrc.veinteractive.com': 1,
#                       'dup.baidustatic.com': 3,
#                       'dynamic-media-cdn.tripadvisor.com': 6,
#                       'e.clarity.ms': 3,
#                       'e.cquotient.com': 1,
#                       'e.deployads.com': 2,
#                       'e.issuu.com': 2,
#                       'e.serverbid.com': 3,
#                       'e1.emxdgt.com': 3,
#                       'e1.extreme-dm.com': 1,
#                       'e3.adpushup.com': 2,
#                       'ea5a46487d3e432886776c94b292df0f.events.ubembed.com': 1,
#                       'ea5a46487d3e432886776c94b292df0f.js.ubembed.com': 1,
#                       'eas-fe.eskimi.com': 1,
#                       'easternrayshisha.co.uk': 1,
#                       'eb2.3lift.com': 9,
#                       'ec.emap.com': 3,
#                       'eclick.baidu.com': 2,
#                       'ecs.office.com': 1,
#                       'edge.quantserve.com': 2,
#                       'editor.fo.ru': 2,
#                       'edugramlink.com': 1,
#                       'ei.rdtcdn.com': 6,
#                       'embed-fastly.wistia.com': 9,
#                       'embedwistia-a.akamaihd.net': 6,
#                       'end.scorecardresearch.com': 2,
#                       'endpoint1.collection.eu.sumologic.com': 1,
#                       'engine.univtec.com': 2,
#                       'entitlement.auth.adobe.com': 1,
#                       'ents24.com': 1,
#                       'ents24.imgix.net': 5,
#                       'ep00.epimg.net': 1,
#                       'epnt.ebay.com': 2,
#                       'epsilon.6sense.com': 3,
#                       'er.sanoma-sndp.fi': 1,
#                       'eservice2.gkd-re.de': 6,
#                       'esputnik.com': 1,
#                       'euractiv.fr': 1,
#                       'evand.com': 1,
#                       'event.api.drift.com': 10,
#                       'event.getblue.io': 1,
#                       'event.insticator.com': 1,
#                       'events.api.boomtrain.com': 3,
#                       'events.api.secureserver.net': 4,
#                       'events.brightline.tv': 2,
#                       'events.launchdarkly.com': 1,
#                       'events.ocdn.eu': 2,
#                       'events.release.narrativ.com': 1,
#                       'events.varsitytutors.com': 2,
#                       'evoke-windowsservices-tas.msedge.net': 1,
#                       'evolution.com': 1,
#                       'eweb.ndia.org': 1,
#                       'exchange.mediavine.com': 7,
#                       'ext-strm-cogent14.strm.yandex.net': 1,
#                       'ext-strm-cogent17.strm.yandex.net': 1,
#                       'extend.vimeocdn.com': 2,
#                       'f.clarity.ms': 2,
#                       'f.vimeocdn.com': 49,
#                       'f1.media.brightcove.com': 1,
#                       'family24rx.com': 2,
#                       'fast.a.klaviyo.com': 10,
#                       'fast.appcues.com': 1,
#                       'fast.fonts.net': 22,
#                       'fast.wistia.com': 34,
#                       'fast.wistia.net': 8,
#                       'fastlane.rubiconproject.com': 30,
#                       'fastly-a9fast-com.global.ssl.fastly.net': 2,
#                       'fastozo.com': 1,
#                       'faves.grow.me': 2,
#                       'favicon.yandex.net': 5,
#                       'fe-apiproxy.musement.com': 1,
#                       'fe3cr.delivery.mp.microsoft.com': 1,
#                       'fecs.console.aliyun.com': 1,
#                       'feedback.adrecover.com': 1,
#                       'ferry.nyc': 2,
#                       'files.catbox.moe': 2,
#                       'fjmu.edu.cn': 6,
#                       'flask.nextdoor.com': 7,
#                       'flatpanelshd.disqus.com': 5,
#                       'fltrp.com': 2,
#                       'fo.ru': 6,
#                       'font.visma.com': 6,
#                       'fontlibrary.org': 3,
#                       'formacion.miriadax.net': 1,
#                       'forms.mailmunch.co': 1,
#                       'fortlewis-search.clients.us.funnelback.com': 2,
#                       'fr.euractiv.eu': 1,
#                       'francerent.com': 1,
#                       'frankenpost.de': 1,
#                       'frankenpost.weekli.de': 1,
#                       'froala.com': 1,
#                       'frog.wix.com': 2,
#                       'fulcrum-antenna.imhd.io': 2,
#                       'fw.adsafeprotected.com': 3,
#                       'fy8plebn34-dsn.algolia.net': 1,
#                       'g.live.com': 1,
#                       'g1-bidder.adtech.housing.com': 1,
#                       'g2.gumgum.com': 18,
#                       'g9u7p6f6.ssl.hwcdn.net': 1,
#                       'ga.clearbit.com': 2,
#                       'gahu.hit.gemius.pl': 3,
#                       'galderma.com': 1,
#                       'gardnerweb.blueconic.net': 1,
#                       'gatr.hit.gemius.pl': 1,
#                       'gaua.hit.gemius.pl': 1,
#                       'gdc.indeed.com': 1,
#                       'gdecz.hit.gemius.pl': 1,
#                       'gdtcgi.53kf.com': 2,
#                       'geek.ghost.io': 1,
#                       'genieedmp.com': 2,
#                       'geo.ipify.org': 1,
#                       'geo.moatads.com': 5,
#                       'geo.prod.do.dsp.mp.microsoft.com': 1,
#                       'geoapi.eclabs.io': 1,
#                       'geoip.nbcnews.com': 2,
#                       'geolocation.daznservices.com': 2,
#                       'get.bolt.com': 1,
#                       'getbento.imgix.net': 1,
#                       'gfintegrity.org': 1,
#                       'gfp.veta.naver.com': 1,
#                       'gizmo.rakuten.tv': 2,
#                       'gleam.io': 3,
#                       'global.corusappservices.com': 1,
#                       'gm.mmstat.com': 2,
#                       'go.flx1.com': 4,
#                       'go.integralads.com': 1,
#                       'go.ontraport.net': 2,
#                       'go.sevenrooms.com': 1,
#                       'goldseek.com': 1,
#                       'goldstar.com': 1,
#                       'gosmonitor.ru': 1,
#                       'gotie.tunein.com': 2,
#                       'grandeurhillsgroup.com': 6,
#                       'graphics.afpforum.com': 1,
#                       'graphql.contentful.com': 1,
#                       'gratka.pl': 1,
#                       'gravity-software.com': 2,
#                       'greenhomeguide.com': 1,
#                       'grey.com': 1,
#                       'grid.bidswitch.net': 1,
#                       'gthu.hit.gemius.pl': 1,
#                       'guardianngr.disqus.com': 1,
#                       'guide.loyalhealth.com': 1,
#                       'guidecdn.loyalhealth.com': 1,
#                       'gurgle.techbargains.com': 1,
#                       'gurgle.zdbb.net': 1,
#                       'gurgle.ziffdavis.com': 1,
#                       'gw.oribi.io': 3,
#                       'h-da.de': 6,
#                       'h.online-metrix.net': 1,
#                       'hackensackmeridianhealth.org': 1,
#                       'harborside.blueconic.net': 1,
#                       'hb.adscale.de': 10,
#                       'hb.brainlyads.com': 2,
#                       'hb.emxdgt.com': 10,
#                       'hb.gsspcln.jp': 3,
#                       'hbopenbid.pubmatic.com': 26,
#                       'healthguidance.org': 1,
#                       'heapanalytics.com': 5,
#                       'heidelbergcement.com': 1,
#                       'hello.myfonts.net': 20,
#                       'heyuguys.com': 1,
#                       'hitchinnomads.cc': 1,
#                       'hm.baidu.com': 33,
#                       'hoepli.it': 1,
#                       'hornblowergroup.tfaforms.net': 1,
#                       'house-fastly-signed-eu-west-1-prod.brightcovecdn.com': 1,
#                       'housingworks.org': 1,
#                       'hqs3.cnzz.com': 1,
#                       'hqs6.cnzz.com': 1,
#                       'htlb.casalemedia.com': 28,
#                       'httpbin.org': 1,
#                       'https-mymonster-esportsclub-de.disqus.com': 1,
#                       'hzs11.cnzz.com': 1,
#                       'hzs2.cnzz.com': 2,
#                       'i.bcprm.com': 2,
#                       'i.bigmir.net': 3,
#                       'i.businessinsider.com': 1,
#                       'i.e-planning.net': 1,
#                       'i.gse.io': 6,
#                       'i.imgur.com': 14,
#                       'i.insider.com': 1,
#                       'i.mycdn.me': 12,
#                       'i.salecycle.com': 2,
#                       'i.scdn.co': 4,
#                       'i.simpli.fi': 5,
#                       'i.smartnews-ads.com': 2,
#                       'i.vimeocdn.com': 18,
#                       'i1.ruliweb.com': 2,
#                       'i2.ruliweb.com': 2,
#                       'i3.ruliweb.com': 4,
#                       'i78.fastpic.org': 1,
#                       'i80.fastpic.org': 2,
#                       'ib.adnxs.com': 123,
#                       'ic.tynt.com': 1,
#                       'icdn.2cda.pl': 6,
#                       'ice.360yield.com': 6,
#                       'icon.cnzz.com': 1,
#                       'id.crwdcntrl.net': 1,
#                       'id.sharedid.org': 4,
#                       'id.sv.rkdms.com': 2,
#                       'identity.mparticle.com': 2,
#                       'idge.staticworld.net': 1,
#                       'idm.hit.gemius.pl': 1,
#                       'ids.ad.gt': 5,
#                       'ih.adscale.de': 1,
#                       'iirexhibitionslimite.tt.omtrdc.net': 1,
#                       'il-trc-events.taboola.com': 15,
#                       'image.39.net': 6,
#                       'image.politicalcartoons.com': 1,
#                       'image.ruliweb.com': 2,
#                       'image2.pubmatic.com': 12,
#                       'image6.pubmatic.com': 11,
#                       'image8.pubmatic.com': 6,
#                       'imageban.ru': 6,
#                       'images.booklooker.de': 6,
#                       'images.detik.com': 4,
#                       'images.dmca.com': 6,
#                       'images.drive.ru': 6,
#                       'images.getbento.com': 3,
#                       'images.goldseek.com': 1,
#                       'images.musement.com': 2,
#                       'images.prismic.io': 6,
#                       'images.shrinktheweb.com': 3,
#                       'images.smulweb.nl': 6,
#                       'images.swm.digital': 1,
#                       'images.ua.prom.st': 6,
#                       'images.unsplash.com': 2,
#                       'imagescdn.dealercarsearch.com': 4,
#                       'imaginecup.com': 1,
#                       'imaginecup.microsoft.com': 1,
#                       'imemc.org': 1,
#                       'img-c.drive.ru': 6,
#                       'img.automationworld.com': 2,
#                       'img.echosting.cafe24.com': 1,
#                       'img.en25.com': 2,
#                       'img.radioparadise.com': 9,
#                       'img.ruliweb.com': 5,
#                       'img.secureserver.net': 1,
#                       'img.vladtv.ru': 4,
#                       'img03.en25.com': 5,
#                       'img04.en25.com': 3,
#                       'img06.en25.com': 2,
#                       'img118.imagetwist.com': 1,
#                       'img119.imagetwist.com': 2,
#                       'img165.imagetwist.com': 2,
#                       'img250.imagetwist.com': 1,
#                       'img3.usefathom.com': 1,
#                       'img300.imagetwist.com': 2,
#                       'img33.imagetwist.com': 4,
#                       'img350.imagetwist.com': 3,
#                       'img69.imagetwist.com': 1,
#                       'imstore.bet365affiliates.com': 2,
#                       'in.getclicky.com': 10,
#                       'in.hotjar.com': 78,
#                       'indavideo.hu': 1,
#                       'indexadhu.hit.gemius.pl': 2,
#                       'indexhu.adocean.pl': 1,
#                       'info.heap.io': 3,
#                       'info.rsf.ru': 3,
#                       'info.tenable.com': 1,
#                       'info.weather.yandex.net': 1,
#                       'ingest.make.rvapps.io': 4,
#                       'ingestion.contentinsights.com': 1,
#                       'inova.org': 1,
#                       'insight.adsrvr.org': 64,
#                       'intersc.igaming-service.io': 2,
#                       'intl.rakuten-static.com': 4,
#                       'inv-nets.admixer.net': 4,
#                       'ip-api.igaming-service.io': 3,
#                       'ip.mia-chat.com': 3,
#                       'ipfind.co': 1,
#                       'issuu.com': 1,
#                       'ivpress.com': 1,
#                       'j-friends.jp': 2,
#                       'jadserve.postrelease.com': 10,
#                       'jisc.ac.uk': 1,
#                       'jnxm2.com': 1,
#                       'jogger.zdbb.net': 1,
#                       'johnhancockfinancial.tt.omtrdc.net': 1,
#                       'jpeg.org': 6,
#                       'js-sec.indexww.com': 20,
#                       'js.cookieless-data.com': 2,
#                       'js.gleam.io': 2,
#                       'js.monitor.azure.com': 1,
#                       'js.ptengine.cn': 1,
#                       'js.recurly.com': 2,
#                       'js.sddan.com': 1,
#                       'jssdkcdns.mparticle.com': 2,
#                       'jssdks.mparticle.com': 3,
#                       'jstracer.yandex.ru': 5,
#                       'jukebox.pathfactory.com': 3,
#                       'jumbe.zaius.com': 1,
#                       'k-tai.watch.impress.co.jp': 2,
#                       'k.p-n.io': 2,
#                       'kavo.com': 1,
#                       'kinesis.us-east-1.amazonaws.com': 1,
#                       'kkday.com': 2,
#                       'klgtu.ru': 6,
#                       'kraken.rambler.ru': 4,
#                       'kv601.prod.do.dsp.mp.microsoft.com': 1,
#                       'l.evidon.com': 22,
#                       'l3apq3bncl82o596k2d1ydn1-wpengine.netdna-ssl.com': 6,
#                       'l3lqjjpjse-flywheel.netdna-ssl.com': 3,
#                       'landen.imgix.net': 2,
#                       'lanxess.com': 1,
#                       'lauramercier.com': 1,
#                       'lb.apicit.net': 1,
#                       'lb13.s400.meetrics.net': 2,
#                       'lcinternational.tt.omtrdc.net': 1,
#                       'lcs.naver.com': 1,
#                       'learn.org': 1,
#                       'legalandgeneral.tt.omtrdc.net': 1,
#                       'letro.jp': 2,
#                       'li.org': 1,
#                       'lib-us-2.brilliantcollector.com': 2,
#                       'libsynpro.com': 1,
#                       'licensing.mp.microsoft.com': 2,
#                       'life360.com': 1,
#                       'lifehappens.org': 1,
#                       'likemore-go.imgsmail.ru': 2,
#                       'lilithimage.lilithcdn.com': 2,
#                       'linuxworld.com': 1,
#                       'live-kgi-verdict-network.pantheonsite.io': 2,
#                       'live.4-tell.net': 1,
#                       'live.cnbcindonesia.com': 2,
#                       'livehelp.tgdd.vn': 2,
#                       'livetileedge.dsx.mp.microsoft.com': 14,
#                       'livewebtutors.com': 2,
#                       'llntrack.messe-duesseldorf.de': 1,
#                       'lltrck.com': 2,
#                       'lmunet.edu': 1,
#                       'loadeu.exelator.com': 3,
#                       'loadm.exelator.com': 8,
#                       'loadus.exelator.com': 1,
#                       'localist-images.azureedge.net': 5,
#                       'localmotors.com': 6,
#                       'log.cpex.cz': 2,
#                       'log.intellimize.co': 3,
#                       'log.letro.jp': 3,
#                       'log.mmstat.com': 1,
#                       'logi11.xiti.com': 1,
#                       'login.dotomi.com': 2,
#                       'login.mediafort.ru': 5,
#                       'logs.xiti.com': 1,
#                       'logs1242.xiti.com': 1,
#                       'logs1406.xiti.com': 1,
#                       'logs1411.xiti.com': 1,
#                       'logs1412.xiti.com': 2,
#                       'loyalty.yotpo.com': 1,
#                       'lpcdn.lpsnmedia.net': 3,
#                       'lptag.liveperson.net': 3,
#                       'ls.hit.gemius.pl': 10,
#                       'lsc.gov': 1,
#                       'lvs.truehits.in.th': 1,
#                       'm.giraff.io': 1,
#                       'm.servedby-buysellads.com': 2,
#                       'm.stripe.com': 19,
#                       'm.stylenanda.com': 4,
#                       'm.trafmag.com': 2,
#                       'm1.fluidreview.com': 1,
#                       'mab.chartbeat.com': 12,
#                       'mabping.chartbeat.net': 4,
#                       'macro.market': 6,
#                       'magazineviewer.innovadatabase.com': 1,
#                       'mail-dev.santu.com': 1,
#                       'mailing.effectiveprofiles.com': 1,
#                       'mainehealth.zendesk.com': 1,
#                       'malwaretech2.disqus.com': 1,
#                       'mamashelter.com': 1,
#                       'manifest.prod.boltdns.net': 5,
#                       'mantodea.mantisadnetwork.com': 2,
#                       'marketo.clearbit.com': 1,
#                       'masschallenge.org': 1,
#                       'match.adsrvr.org': 55,
#                       'match.bnmla.com': 2,
#                       'matchid.adfox.yandex.ru': 2,
#                       'mathid.mathtag.com': 3,
#                       'mb.moatads.com': 7,
#                       'mc.us1.list-manage.com': 4,
#                       'mc.us14.list-manage.com': 1,
#                       'mc.us15.list-manage.com': 1,
#                       'mc.us16.list-manage.com': 1,
#                       'mc.us2.list-manage.com': 1,
#                       'mc.us9.list-manage.com': 2,
#                       'me-twalton.secure-cdn20.accesso.com': 1,
#                       'me.ioam.de': 1,
#                       'media-1obl-ru.storage.yandexcloud.net': 6,
#                       'media-cldnry.s-nbcnews.com': 3,
#                       'media.giphy.com': 4,
#                       'media.glenfiddich.com': 6,
#                       'media.graphcms.com': 1,
#                       'media.imi.chat': 2,
#                       'media.kaspersky.com': 1,
#                       'media.onlineprnews.com': 6,
#                       'media1.fdncms.com': 6,
#                       'media2.fdncms.com': 6,
#                       'mediabluk.cnr.cn': 1,
#                       'medias.lavie.fr': 6,
#                       'medicineassistancetool.org': 1,
#                       'mem.gfx.ms': 1,
#                       'mergerecords.com': 1,
# ...
#                       'www.riddle.com': 2,
#                       'www.ringling.org': 6,
#                       'www.rmmagazine.com': 1,
#                       'www.rnengage.com': 6,
#                       'www.robotics.org': 1,
#                       'www.rpgmakerweb.com': 1,
#                       'www.rtb123.com': 1,
#                       'www.rts.ch': 1,
#                       'www.ruliweb.com': 2,
#                       'www.rumiview.com': 6,
#                       'www.ruptly.tv': 1,
#                       'www.rws.com': 1,
#                       'www.sabc.co.za': 6,
#                       'www.saltwire.com': 1,
#                       'www.savethechildren.es': 6,
#                       'www.savethechildren.it': 6,
#                       'www.sbnation.com': 8,
#                       'www.sc.pages01.net': 1,
#                       'www.sc.pages02.net': 1,
#                       'www.sc.pages03.net': 1,
#                       'www.sc.pages08.net': 1,
#                       'www.scamax.ru': 2,
#                       'www.schoolofrock.com': 2,
#                       'www.scicorn.com': 1,
#                       'www.scie.org.uk': 6,
#                       'www.sciencesocieties.org': 1,
#                       'www.sda.cn': 1,
#                       'www.searchanise.com': 2,
#                       'www.shareaholic.net': 4,
#                       'www.ship.sh': 10,
#                       'www.shopfactory.com': 6,
#                       'www.sibur.ru': 6,
#                       'www.similarsite.net': 2,
#                       'www.singapoker.org': 1,
#                       'www.sinodaily.com': 2,
#                       'www.site24x7.com': 1,
#                       'www.sitiosenparaguay.com': 6,
#                       'www.sixnationsrugby.com': 1,
#                       'www.sjwoe.com': 1,
#                       'www.skadden.com': 1,
#                       'www.skaut.cz': 1,
#                       'www.skinceuticals.com': 1,
#                       'www.skinstore.com': 1,
#                       'www.skole.hr': 6,
#                       'www.skorpions-welt.at': 1,
#                       'www.skyscrapercenter.com': 2,
#                       'www.slayer.net': 2,
#                       'www.slidedeck.com': 1,
#                       'www.slothtechtv.com': 1,
#                       'www.smallgreentree.net': 1,
#                       'www.smart-energy.com': 1,
#                       'www.smartadserver.com': 7,
#                       'www.smava.de': 1,
#                       'www.snapengage.com': 3,
#                       'www.snapfitness.com': 7,
#                       'www.softwareone.com': 1,
#                       'www.sony.es': 1,
#                       'www.sootoday.com': 1,
#                       'www.sordum.org': 1,
#                       'www.soundcraft.com': 1,
#                       'www.soundhound.com': 1,
#                       'www.spacedaily.com': 10,
#                       'www.spacewar.com': 2,
#                       'www.speurders.nl': 1,
#                       'www.spicejet.com': 1,
#                       'www.spr.ru': 6,
#                       'www.spxdaily.com': 10,
#                       'www.standards.org.au': 2,
#                       'www.starhit.ru': 1,
#                       'www.statcounter.com': 6,
#                       'www.static.ferrero.com': 6,
#                       'www.statsperform.com': 1,
#                       'www.stilyoapps.com': 2,
#                       'www.stonemountainpark.com': 1,
#                       'www.stophateforprofit.org': 1,
#                       'www.stormbornlegend.de': 6,
#                       'www.storyblocks.com': 1,
#                       'www.storygize.net': 1,
#                       'www.strategies.fr': 1,
#                       'www.streamate.com': 1,
#                       'www.stromkult.com': 1,
#                       'www.strongtie.com': 1,
#                       'www.sudo.ws': 6,
#                       'www.summerhamster.com': 1,
#                       'www.sustainweb.org': 6,
#                       'www.swarmapp.com': 1,
#                       'www.swccd.edu': 1,
#                       'www.swd.com': 1,
#                       'www.sylvanlearning.com': 6,
#                       'www.tag4arm.com': 1,
#                       'www.talkable.com': 2,
#                       'www.tamgrt.com': 1,
#                       'www.tarrantcounty.com': 6,
#                       'www.tasty-guide.gr': 1,
#                       'www.td.org': 1,
#                       'www.tealdit.com': 1,
#                       'www.teamsnap.com': 1,
#                       'www.techradar.com': 1,
#                       'www.tekla.com': 1,
#                       'www.telerik.com': 6,
#                       'www.telstra.com': 4,
#                       'www.telstra.com.au': 1,
#                       'www.temenos.com': 1,
#                       'www.tenable.com': 1,
#                       'www.termedia.pl': 6,
#                       'www.termsfeed.com': 1,
#                       'www.thameswater.co.uk': 1,
#                       'www.the-saleroom.com': 1,
#                       'www.thebestideasforkids.com': 1,
#                       'www.thecaterer.com': 1,
#                       'www.theconstructionindex.co.uk': 1,
#                       'www.thecookierookie.com': 1,
#                       'www.thedailynewsonline.com': 1,
#                       'www.thedailystar.com': 1,
#                       'www.thedialogue.org': 1,
#                       'www.thefreesite.com': 1,
#                       'www.thegioididong.com': 3,
#                       'www.theholidayspot.com': 6,
#                       'www.themoviedb.org': 1,
#                       'www.theoceanrace.com': 2,
#                       'www.thepeterboroughexaminer.com': 1,
#                       'www.thepetitionsite.com': 1,
#                       'www.thetoc.gr': 1,
#                       'www.thinkbroadband.com': 1,
#                       'www.tim.it': 1,
#                       'www.timescapeusa.com': 1,
#                       'www.timesherald.com': 1,
#                       'www.tkaraoke.com': 1,
#                       'www.tkmaxx.com': 3,
#                       'www.tmdn.org': 7,
#                       'www.tns-counter.ru': 5,
#                       'www.tokyocreative.com': 1,
#                       'www.top-clanek.cz': 1,
#                       'www.top50-solar.de': 1,
#                       'www.totalassignmenthelp.com': 7,
#                       'www.touhou.cc': 2,
#                       'www.tpososyal.com': 1,
#                       'www.tracemyip.org': 1,
#                       'www.traeger.com': 1,
#                       'www.tripadvisor.co.uk': 1,
#                       'www.tripadvisor.com.ar': 1,
#                       'www.trust-guard.com': 2,
#                       'www.trustedsite.com': 1,
#                       'www.trustguard.com': 1,
#                       'www.twenty20.com': 1,
#                       'www.twitch.tv': 1,
#                       'www.tyan.com': 30,
#                       'www.ua-football.com': 1,
#                       'www.ulb.be': 6,
#                       'www.ultimatecarpage.com': 6,
#                       'www.umso.com': 1,
#                       'www.unicredit.it': 2,
#                       'www.uniformlaws.org': 1,
#                       'www.unilia.ac.mw': 1,
#                       'www.unitedhealthgroup.com': 15,
#                       'www.univ-orleans.fr': 6,
#                       'www.uofmhealth.org': 1,
#                       'www.upsellit.com': 2,
#                       'www.uqd.io': 1,
#                       'www.uradni-list.si': 6,
#                       'www.uromivoice.com': 5,
#                       'www.usab.com': 1,
#                       'www.usdairy.com': 6,
#                       'www.ussailing.org': 1,
#                       'www.utcluj.ro': 6,
#                       'www.uttyler.edu': 1,
#                       'www.uws.ac.uk': 1,
#                       'www.varsitytutors.com': 1,
#                       'www.vegasinsider.com': 6,
#                       'www.verdict.co.uk': 7,
#                       'www.videoblocks.com': 1,
#                       'www.vimeo.com': 3,
#                       'www.visiblebody.com': 1,
#                       'www.visitcornwall.com': 47,
#                       'www.visitseoul.net': 1,
#                       'www.visittuscany.com': 6,
#                       'www.viziteurope.ru': 6,
#                       'www.vizzit.se': 2,
#                       'www.vmcdn.ca': 6,
#                       'www.voanoticias.com': 1,
#                       'www.vodafone.nl': 1,
#                       'www.vseinstrumenti.ru': 1,
#                       'www.vsrf.ru': 1,
#                       'www.vtb.ru': 6,
#                       'www.vtb24.ru': 1,
#                       'www.w3.org': 1,
#                       'www.walletpop.com': 1,
#                       'www.walsh.edu': 6,
#                       'www.waz.de': 1,
#                       'www.wdio.com': 6,
#                       'www.webmoney.ru': 2,
#                       'www.websitealive3.com': 1,
#                       'www.websmultimedia.com': 2,
#                       'www.webulousthemes.com': 1,
#                       'www.webzdarma.cz': 1,
#                       'www.weirdal.com': 1,
#                       'www.wetlands.org': 1,
#                       'www.wetv.com': 1,
#                       'www.wheretowatch.com': 1,
#                       'www.wilmu.edu': 6,
#                       'www.windtre.it': 1,
#                       'www.windycitygridiron.com': 1,
#                       'www.wlfi.com': 4,
#                       'www.womenwriters.net': 2,
#                       'www.woopra.com': 5,
#                       'www.wordhippo.com': 1,
#                       'www.wordonfire.org': 1,
#                       'www.workitdaily.com': 1,
#                       'www.worldarchitecturefestival.com': 1,
#                       'www.worldtimeapi.org': 1,
#                       'www.wp.pl': 1,
#                       'www.writing.com': 6,
#                       'www.wshu.org': 6,
#                       'www.wyomingnewsnow.tv': 1,
#                       'www.xquartz.org': 1,
#                       'www.ya-roditel.ru': 1,
#                       'www.yahoo.com': 1,
#                       'www.ymg-ssz.jp': 2,
#                       'www.ymobile.jp': 1,
#                       'www.yourhormones.info': 1,
#                       'www.youtube-nocookie.com': 5,
#                       'www.youtube.com': 185,
#                       'www.youvisit.com': 3,
#                       'www.zdnet.com': 1,
#                       'www.zergnet.com': 2,
#                       'www.ziffdavis.com': 1,
#                       'www.zoimas.com': 4,
#                       'www1.pictures.zimbio.com': 1,
#                       'www1.ussailing.org': 4,
#                       'www2.branch.io': 1,
#                       'www2.raymarine.eu': 2,
#                       'www3.clustrmaps.com': 1,
#                       'www4.smartadserver.com': 1,
#                       'www5c1.53kf.com': 2,
#                       'www6.53kf.com': 7,
#                       'www8.smartadserver.com': 4,
#                       'x.bidswitch.net': 24,
#                       'x.clearbitjs.com': 1,
#                       'x.dlx.addthis.com': 4,
#                       'x01.aidata.io': 10,
#                       'x78251kcpll2l2t9e46kf96a-wpengine.netdna-ssl.com': 6,
#                       'x818.com': 3,
#                       'xedo.me': 1,
#                       'xeeboo.io': 1,
#                       'xfs1.snadx.com': 2,
#                       'xhamsterlive.com': 1,
#                       'xiecomm.paymetric.com': 1,
#                       'xiniu.com': 6,
#                       'xn--80afcdbalict6afooklqi5o.xn--p1ai': 6,
#                       'xxxhdvideo.site': 6,
#                       'xxxporn989.com': 1,
#                       'xxxpornzeed.com': 1,
#                       'y6jn8c31nzudazwz7jjtuvycowndhkbzzg6c3ftp9e1b77398a93690eam1.e.aa.online-metrix.net': 1,
#                       'yahoo.com': 1,
#                       'yahoovod.hs.llnwd.net': 6,
#                       'yandex-dmp-sync.rutarget.ru': 9,
#                       'yandex-sync.rutarget.ru': 9,
#                       'yandex.ru': 15,
#                       'yandex.st': 1,
#                       'yastatic.net': 67,
#                       'ybar-a38ek5ohvjreport.wc.yahoodns.net': 1,
#                       'ybar-a5bl7e33yzreport.wc.yahoodns.net': 1,
#                       'ybar-ady544xaa6report.wc.yahoodns.net': 1,
#                       'ybar-aipbtx2nwlreport.wc.yahoodns.net': 1,
#                       'ybar-apgjwdvksureport.wc.yahoodns.net': 1,
#                       'ybar-awq68zh8urreport.wc.yahoodns.net': 1,
#                       'ybar-b7ztediui1report.wc.yahoodns.net': 1,
#                       'ybar-bgstvki77dreport.wc.yahoodns.net': 1,
#                       'ybar-bhwq7pphi8report.wc.yahoodns.net': 1,
#                       'ybar-bia9v4qskqreport.wc.yahoodns.net': 1,
#                       'ybar-bloc6lane9report.wc.yahoodns.net': 1,
#                       'ybar-bpfafg496zreport.wc.yahoodns.net': 1,
#                       'ybar-c5t3iqajv1report.wc.yahoodns.net': 1,
#                       'ybar-c6jm61uppbreport.wc.yahoodns.net': 1,
#                       'ybar-c6u4eldxtmreport.wc.yahoodns.net': 1,
#                       'ybar-cp926cqfoureport.wc.yahoodns.net': 1,
#                       'ybar-cpsesczym5report.wc.yahoodns.net': 1,
#                       'ybar-csazv2wqdmreport.wc.yahoodns.net': 1,
#                       'ybar-mcdn-report.wc.yahoodns.net': 4,
#                       'yellgh.com': 1,
#                       'yhb.p.otm-r.com': 1,
#                       'yjtag.yahoo.co.jp': 10,
#                       'ymg-ssz.jp': 2,
#                       'yokak.gov.tr': 1,
#                       'yoomoney.ru': 6,
#                       'youradexchange.com': 1,
#                       'yourbrideglobal.com': 1,
#                       'youtu.be': 6,
#                       'youtubeembedcode.com': 1,
#                       'ysa-static.passport.yandex.ru': 12,
#                       'yt3.ggpht.com': 89,
#                       'ytro.news': 2,
#                       'ytv.com': 1,
#                       'yui-s.yahooapis.com': 3,
#                       'yukon.ca': 1,
#                       'yxhstwzjbu.info': 1,
#                       'z-in.amazon-adsystem.com': 2,
#                       'z-na.amazon-adsystem.com': 4,
#                       'z.cdn.trafficdok.com': 5,
#                       'z.moatads.com': 65,
#                       'z.omappapi.com': 9,
#                       'z12.cnzz.com': 4,
#                       'z1photorankmedia-a.akamaihd.net': 9,
#                       'z2.cnzz.com': 2,
#                       'z2photorankmedia-a.akamaihd.net': 7,
#                       'z3.cnzz.com': 2,
#                       'z3photorankmedia-a.akamaihd.net': 8,
#                       'z7.cnzz.com': 2,
#                       'z716801b3.webengage.co': 1,
#                       'za-ssl.effectivemeasure.net': 1,
#                       'zalywzdew6.execute-api.us-west-2.amazonaws.com': 1,
#                       'zameen4u.com': 2,
#                       'zapishemvse.ru': 1,
#                       'zdbb.net': 1,
#                       'zeco.spxl.socy.es': 1,
#                       'zem.outbrainimg.com': 1,
#                       'zerowastehome.com': 1,
#                       'zhuzao.com': 6,
#                       'ziffdavis-d.openx.net': 1,
#                       'zithromaxazitromycin.com': 1,
#                       'zn03xx8ouv2nng2wd-covidh8jgkvbf8c6q9.siteintercept.qualtrics.com': 1,
#                       'zn780vxspp4zyl7dr-citcx.siteintercept.qualtrics.com': 1,
#                       'zn78lrdnt2il4mjwr-thirtyonegifts.siteintercept.qualtrics.com': 1,
#                       'zn9mgrpmbirhwifvc-singuser98edbb5b.siteintercept.qualtrics.com': 1,
#                       'znapisami.pl': 1,
#                       'zner7mgseuyurx4rk-wesco.siteintercept.qualtrics.com': 1,
#                       'zoimas.com': 1,
#                       'zoldsziv.hu': 6,
#                       'zom.vn': 1,
#                       'zsck.jjxw.cn': 2,
#                       'zsildenafil.com': 1,
#                       'zz.bdstatic.com': 4},
#  'Sampling Limit': 10000}

# %% [markdown]
# # Metric 1

# %%
with open(REPORT_NAME+"-metric1/metric1.obj", "rb") as f:
    metric1 = pickle.load(f)

# %%
metric1.ds_redundancy

# %%
data = metric1.redundancy_metadata

# %%
plt.figure(figsize=(10, 6))

for item in data:
    for name, values in item.items():
        x_values = sorted(values.keys())
        y_values = []
        for x in x_values:
            # Calculate the average of the last values (assuming each list has 5 values)
            avg_y = np.mean([v[0] for v in values[x]])
            y_values.append(avg_y)
        plt.plot(x_values, y_values, label=name)

plt.xlabel("X Axis Values")
plt.ylabel("Average of Last Values")
plt.title("Plot of Data")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Metric 2x

# %%
# Load the Pickled Metric Object
try:
    pickle_path = os.path.join(f'{REPORT_NAME}-metric2', 'metric2x.obj')
    with open(pickle_path, 'rb') as f:
        metric2_obj = pickle.load(f)
    print("✅ Successfully loaded pickled metric2 object!")
    print(f"   - Classifiers used: {list(metric2_obj.classifiers.keys())}")
    print(f"   - Permutation percentages: {metric2_obj.permutation_percentages}")
    
except FileNotFoundError:
    print(f"❌ Error: Could not find the pickle file at {pickle_path}")
except Exception as e:
    print(f"❌ An error occurred while loading the pickle file: {e}")

# %%
final_scores = metric2_obj.get_score()

# %%
# Display P-Values and Final Scores

print("="*30)
print("      P-Value Table")
print("="*30)

# Create a clean pandas DataFrame for the p-values
p_value_df = pd.DataFrame(
    data=metric2_obj.p_values,
    index=metric2_obj.classifiers.keys(),
    columns=metric2_obj.permutation_percentages
)
print(p_value_df)

print("\n" + "="*30)
print("      Final Score Summary")
print("="*30)

# The final results are already calculated and stored in the object
final_scores = metric2_obj.get_score()
for key, value in final_scores.items():
    if key != "P-value table":
        print(f"{key+':':<20} {value}")

# %%
# Visualize Individual Permutations with Polyfit Trend Line 

print("Generating plot for individual permutation runs with polyfit trend line...")

# Extract data from the loaded object
classifier_names = list(metric2_obj.classifiers.keys())
num_classifiers = len(classifier_names)
initial_scores = metric2_obj.initial_scores[0] # This is a 1D array of the initial scores

# Prepare the plot
plt.style.use('seaborn-v0_8-whitegrid')
fig, ax = plt.subplots(figsize=(12, 8))
colors = cm.viridis(np.linspace(0, 1, num_classifiers))

# Get the mean correlations (X-axis for the polyfit)
mean_correlations = metric2_obj.correlations.mean(axis=0)

# --- Plotting each individual permutation run as a scatter point ---
for i, (name, color) in enumerate(zip(classifier_names, colors)):
    # Flatten the arrays to get a list of all correlation scores and corresponding F1-scores
    all_correlations = metric2_obj.correlations.flatten()
    all_scores_for_clf = metric2_obj.permuted_scores[:, :, i].flatten()
    
    # Use a low alpha to see point density
    ax.scatter(all_correlations, all_scores_for_clf, color=color, alpha=0.15, s=20, label=f'{name} (Individual Runs)')

# --- Overlay the polyfit trend lines and the initial score line ---
for i, (name, color) in enumerate(zip(classifier_names, colors)):
    
    # Get the mean scores for this classifier (Y-axis for the polyfit)
    mean_scores = metric2_obj.permuted_scores[:, :, i].mean(axis=0)
    
    # Calculate the polyfit line (degree 1) exactly as the module does
    slope, intercept = np.polyfit(mean_correlations, mean_scores, 1)
    
    # Create X-values for plotting the line (from lowest mean correlation to 1.0)
    x_line = np.array([np.min(mean_correlations), 1.0])
    
    # Calculate the corresponding Y-values for the line
    y_line = slope * x_line + intercept
    
    # Plot the polyfit trend line
    ax.plot(x_line, y_line, linestyle='-', color=color, linewidth=2.5, label=f'{name} (Trend Line)')
    # -----------------------------------------------------------------
    
    # --- Draw the horizontal line for the initial, non-permuted score ---
    initial_score = initial_scores[i]
    ax.axhline(y=initial_score, color=color, linestyle='--', linewidth=2, label=f'{name} (Initial Score)')
    # -------------------------------------------------------------------

# --- Formatting and Finalizing the Plot ---

# Create a clean legend
handles, labels = ax.get_legend_handles_labels()
unique_labels = dict(zip(labels, handles))
ax.legend(unique_labels.values(), unique_labels.keys(), title='Classifier', bbox_to_anchor=(1.04, 1), loc='upper left')

ax.set_title('Distribution of Permutation Results with Trend Line', fontsize=16)
ax.set_xlabel('Correlation with Original Labels', fontsize=12)
ax.set_ylabel('F1-Score (Macro)', fontsize=12)
ax.set_ylim(bottom=0)
ax.set_xlim(left=min(metric2_obj.correlations.flatten()) - 0.05, right=1.05)

# Adjust layout to make room for the legend
plt.tight_layout(rect=[0, 0, 0.85, 1]) # rect=[left, bottom, right, top]
plt.show()

# %% [markdown]
# # Metric 2 - legacy

# %%
# This is legacy visualization for the original version of Metric 2 which is now beeing obsoleted

# %%
with open(REPORT_NAME+"-metric2/metric2.obj", "rb") as f:
    metric2 = pickle.load(f)

# %%
metric2.raw_slope

# %%
metric2.print_results()

# %%
colors = cm.rainbow(np.linspace(0, 1, metric2.a[1]))

# %%
pvalues = np.zeros((metric2.a[1],len(metric2.perc)))
colors = cm.rainbow(np.linspace(0, 1, metric2.a[1]))

# plot true values as diamonds
for i, c in zip(range(metric2.a[1]),colors):
    plt.scatter(1.1+i*0.01, metric2.ev.scores.mean(axis=2)[:, i, 0], s=100, color=c, marker='d')
    
plt.legend((metric2.clfs))

# plot lines for true values
for i, c in zip(range(metric2.a[1]),colors):
    plt.plot([0, 1.1+i*0.01], [metric2.ev.scores.mean(axis=2)[:, i, 0], metric2.ev.scores.mean(axis=2)[:, i, 0]], c=c, linestyle='dashed', alpha=0.5)

# plot permutations
colors = cm.rainbow(np.linspace(0, 1, metric2.a[1]))
for j in range(len(metric2.perc)):
    for i, c in zip(range(metric2.a[1]),colors):
        ind = np.where(metric2.perm[:,j,i]<metric2.ev.scores.mean(axis=2)[:, i, 0])
        plt.scatter((metric2.corr[ind,j]), metric2.perm[ind,j,i], color="none", edgecolor=c, alpha=0.3)
        
for j in range(len(metric2.perc)):
    for i, c in zip(range(metric2.a[1]),colors):
        ind = np.where(metric2.perm[:,j,i]>=metric2.ev.scores.mean(axis=2)[:, i, 0])
        plt.scatter((metric2.corr[ind,j]), metric2.perm[ind,j,i], color=c, edgecolor="black", alpha=1)
        pvalues[i,j] = ((len(ind[0])+1)*1.0)/(metric2.nperm+1);

plt.ylabel('Performance (F1)', size=12)
plt.xlabel('Permutation Correlation', size=12)       

plt.plot([0, 1.1], [metric2.perm.min(), metric2.perm.min()], color='red', linestyle='dashed', alpha=0.5)

plt.axis([-0.05, 1.2, 0, 1.1])

plt.show()

pv = pd.DataFrame(data=pvalues, index=metric2.clfs, columns=metric2.perc)

def significant(v):
    return "font-weight: bold; color: red" if v > 0.01 else None

pv.style.applymap(significant)

# %%
names = metric2.clfs
cor = []
per = []
slopes = []
auc_scores = []

for i, c in zip(range(metric2.a[1]),colors):
    for j in range(len(metric2.perc)):
        plt.scatter(np.mean(metric2.corr[:,j]), np.mean(metric2.perm[:,j,i]), color=c, alpha=1)
    
    cor = np.mean(metric2.corr[:,:], axis=0)
    per = np.mean(metric2.perm[:,:,i], axis=0)
    
    auc_score = auc(cor,per)
    slope, intercept = np.polyfit(cor, per, 1)
    plt.plot(cor, slope*cor + intercept, color=c, linewidth=0.8)
    print(names[i], '=', slope)
    slopes = np.append(slopes, slope)
    auc_scores = np.append(auc_scores, auc_score)

plt.legend(names, prop={'size': 8})

maxind = np.argmax(abs(slopes))
maxind_auc = np.argmax(abs(auc_scores))

print('Slope:', np.max(abs(slopes)), '-', names[maxind])
print('AUC:', np.max(abs(auc_scores)), '-', names[maxind_auc])

# %% [markdown]
# # Metric 3

# %%
with open(REPORT_NAME+"-metric3/metric3.obj", "rb") as f:
    metric3 = pickle.load(f)

# %%
# The base key
next(iter(basic["Similarity"]["detail"]))

# %%
# All keys
basic["Similarity"]["detail"].keys()

# %%
# All metric 3 metadata
basic["Similarity"]["detail"]
