# %%
import sys
# Import NDVM modules to load pickled data
sys.path.append('/home/dosoukup/Dataset/drift-katoda-v2/katoda-tools/ndvm/modules')
sys.path.append('/home/dosoukup/Dataset/drift-katoda-v2/katoda-tools/ndvm')
import os
import pickle
import metric1, metric2, metric3
import json
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import auc
import matplotlib.cm as cm
import pandas as pd

# %%
REPORT_NAME = "metrics/report-dataset-1755163157"

# %% [markdown]
# # General Report

# %%
with open(REPORT_NAME+'.csv', 'r') as file:
    basic = json.load(file)
pprint(basic)
# Out:
# {'Analyzed Samples': {'0100007f2443016120024ca702458153-sp.ops.beeline.ru': 1,
#                       '0100007f3f2c0161fb04d30302f7623c-sp.ops.beeline.ru': 1,
#                       '0100007f70470161f904c50302bbea3e-sp.ops.beeline.ru': 1,
#                       '0100007fb8320161dd02d04302f59e1d-sp.ops.beeline.ru': 1,
#                       '1-im-dev.guokr.com': 3,
#                       '100003651.collect.igodigital.com': 2,
#                       '100007688.collect.igodigital.com': 2,
#                       '110005692.collect.igodigital.com': 1,
#                       '110007238.collect.igodigital.com': 1,
#                       '117351982.intellimizeio.com': 1,
#                       '144vod-adaptive.akamaized.net': 2,
#                       '147-229-8-212_s-2-16-186-51_ts-1627465442-clienttons-s.akamaihd.net': 1,
#                       '147-229-8-212_s-2-16-2-74_ts-1627603548-clienttons-s.akamaihd.net': 1,
#                       '147-229-8-212_s-2-16-2-74_ts-1627608069-clienttons-s.akamaihd.net': 1,
#                       '168695269-prod.rfksrv.com': 1,
#                       '1737ad5c.akstat.io': 1,
#                       '17track.net': 2,
#                       '189vod-adaptive.akamaized.net': 1,
#                       '1c7fab3im83f5gqiow2qqs2k-wpengine.netdna-ssl.com': 6,
#                       '1eb17132b4904a06a7e688e4ebf4ccf3.js.ubembed.com': 1,
#                       '1l-hit.mail.ru': 1,
#                       '1x1.a-mo.net': 1,
#                       '2-im-dev.guokr.com': 6,
#                       '247sports.com': 1,
#                       '274919b8d011b79b8a06ef715d137d79.azr.footprintdns.com': 1,
#                       '27c2s3mdcxk2qzutg1z8oa91-wpengine.netdna-ssl.com': 6,
#                       '2seefz3pqn34as1ys21sb7m1-wpengine.netdna-ssl.com': 6,
#                       '3-im-dev.guokr.com': 5,
#                       '364bf52c.akstat.io': 2,
#                       '3a71bc4d20dd605af84bd4c7c7ea112a.azr.footprintdns.com': 1,
#                       '3b93ec17.de.ioam.de': 1,
#                       '3ijp5i2qkzo4hq4yrxfteqh-wpengine.netdna-ssl.com': 6,
#                       '3j6x6z2bx1qq1aawwt3b6y0a-wpengine.netdna-ssl.com': 4,
#                       '3m.mediav.com': 2,
#                       '3upg5n1ajpdonqkkp34tcif1-wpengine.netdna-ssl.com': 6,
#                       '3xoo20ik68l1obvec1hg1f6f-wpengine.netdna-ssl.com': 6,
#                       '48qbc13dv397vzass1iql2a1-wpengine.netdna-ssl.com': 7,
#                       '4ag46i294nta1038p13v77x1-wpengine.netdna-ssl.com': 6,
#                       '54.newspush.eastmoney.com': 1,
#                       '5821fd968630ae4412bd-ea92488b6ed75e374970327d2aeea8fc.ssl.cf1.rackcdn.com': 1,
#                       '598d8f3cda4c5fed8f27-d10999d18a3b8ba163ad6d48476ec57a.ssl.cf5.rackcdn.com': 1,
#                       '6226985.collect.igodigital.com': 1,
#                       '684dd306.akstat.io': 1,
#                       '6852bd09.akstat.io': 1,
#                       '711a8ceb.de.ioam.de': 1,
#                       '7806dae405a845eeb6dd9142ca87e9cc.js.ubembed.com': 1,
#                       '79423.analytics.edgekey.net': 3,
#                       '81vod-adaptive.akamaized.net': 1,
#                       '848383.smushcdn.com': 2,
#                       '85e73725f5a6aef6f1498fbe662b6657.azr.footprintdns.com': 1,
#                       '8913a548621d4e7aa0633b78f9de2b08.js.ubembed.com': 1,
#                       '90vod-adaptive.akamaized.net': 1,
#                       '9932704de5fc5c8.cmccloud.com.vn': 4,
#                       '99cc42751cf140f8bbfb70d2d9f3275b.events.ubembed.com': 2,
#                       '99cc42751cf140f8bbfb70d2d9f3275b.js.ubembed.com': 1,
#                       '99vod-adaptive.akamaized.net': 1,
#                       '9b74456f2e4bcbc20970-51751c7e8fb38e7c8b474cab6c7dc602.ssl.cf5.rackcdn.com': 1,
#                       '9ioacg5nhe-dsn.algolia.net': 1,
#                       'a-38176768.ns8ds.com': 2,
#                       'a.ad.gt': 5,
#                       'a.c-dn.net': 9,
#                       'a.centrum.cz': 1,
#                       'a.disquscdn.com': 5,
#                       'a.giraff.io': 1,
#                       'a.kickstarter.com': 5,
#                       'a.mt.ru': 2,
#                       'a.zdmimg.com': 6,
#                       'a11083715786.cdn-pci.optimizely.com': 1,
#                       'a18211312077.cdn-pci.optimizely.com': 1,
#                       'a2.adform.net': 1,
#                       'a248.e.akamai.net': 1,
#                       'a2jvy22h0kr7b5-ats.iot.us-west-2.amazonaws.com': 1,
#                       'a2put.chinaz.com': 8,
#                       'a3.pubguru.net': 3,
#                       'a3533800155.cdn-pci.optimizely.com': 1,
#                       'aa.agkn.com': 8,
#                       'aamapi.com': 3,
#                       'aax-eu.amazon-adsystem.com': 6,
#                       'aax-us-east.amazon-adsystem.com': 8,
#                       'abc-app.vuemix.com': 1,
#                       'abdfd646059ff18bf8f3-fb5c65ce197413173b3e54cd0a072ad5.ssl.cf5.rackcdn.com': 3,
#                       'aboutus.com': 1,
#                       'abrtp1-cdn.marketo.com': 2,
#                       'accdn.lpsnmedia.net': 8,
#                       'accounts.2k.com': 1,
#                       'accounts.nintendo.com': 1,
#                       'accounts.sap.com': 2,
#                       'acdn.adnxs.com': 28,
#                       'acl.gov': 1,
#                       'act.ds.kakao.com': 2,
#                       'act.pcauto.com.cn': 2,
#                       'action.media6degrees.com': 7,
#                       'ad-sdk.huxiu.com': 1,
#                       'ad.360yield.com': 2,
#                       'ad.adriver.ru': 4,
#                       'ad.crwdcntrl.net': 4,
#                       'ad.jp.ap.valuecommerce.com': 1,
#                       'ad.mail.ru': 8,
#                       'ad.yicai.com': 6,
#                       'ada.baidu.com': 2,
#                       'adaware.zendesk.com': 1,
#                       'addsearch.com': 1,
#                       'adfox-hb-bidder.rutarget.ru': 1,
#                       'adlmerge.com': 5,
#                       'admin.brightcove.com': 1,
#                       'admin.qidian.qq.com': 1,
#                       'admin.qsl.net': 1,
#                       'adminplayer.sohatv.vn': 3,
#                       'adobe.tt.omtrdc.net': 3,
#                       'adobeid-na1.services.adobe.com': 1,
#                       'ads.antaranews.com': 1,
#                       'ads.environmentalleader.com': 1,
#                       'ads.news12static.com': 1,
#                       'ads.nextdoor.com': 1,
#                       'ads.nighttstand.com': 1,
#                       'ads.pubmatic.com': 37,
#                       'ads.servenobid.com': 4,
#                       'ads.yieldmo.com': 3,
#                       'adse.ximalaya.com': 2,
#                       'adserver.kl-youniverse.com': 1,
#                       'adservices.brandcdn.com': 1,
#                       'adv.r7.com': 1,
#                       'adx.adform.net': 2,
#                       'adx.com.ru': 4,
#                       'adx.dable.io': 2,
#                       'adx.yiche.com': 2,
#                       'ae01.alicdn.com': 4,
#                       'aegis.qq.com': 1,
#                       'aerlingus.com': 1,
#                       'aetna.tt.omtrdc.net': 1,
#                       'afar-production.imgix.net': 6,
#                       'afcs.dellcdn.com': 2,
#                       'affiliates.harvestright.com': 1,
#                       'affinity.serif.com': 1,
#                       'ahoy.sendgrid.com': 1,
#                       'ai.mee.nu': 1,
#                       'aiadc.realmagnet.land': 2,
#                       'aifanfan.baidu.com': 4,
#                       'airbnb.ca': 1,
#                       'airbnb.co.uk': 1,
#                       'aizhan.com': 2,
#                       'ajuntament.barcelona.cat': 2,
#                       'alerts.metroservices.io': 4,
#                       'aliexpress.ru': 1,
#                       'allaboutbirds.disqus.com': 2,
#                       'alpha.mirtesen.ru': 6,
#                       'alpixtrack.com': 1,
#                       'alt.idgesg.net': 4,
#                       'alter.com': 1,
#                       'amcdn.vn': 6,
#                       'americansocietyofcli.tt.omtrdc.net': 1,
#                       'amonas.hs.fi': 1,
#                       'amonas.is.fi': 1,
#                       'amplify.outbrain.com': 5,
#                       'amsapi.yicai.com': 6,
#                       'an.yandex.ru': 54,
#                       'ana.cngold.org': 1,
#                       'analysis.cdeledu.com': 2,
#                       'analytics-au.clickdimensions.com': 1,
#                       'analytics.ad.daum.net': 2,
#                       'analytics.clickdimensions.com': 1,
#                       'analytics.foresee.com': 5,
#                       'analytics.init.de': 2,
#                       'analytics.robinhood.com': 1,
#                       'analytics.shareaholic.com': 5,
#                       'analytics.sitewit.com': 1,
#                       'analytics.twitter.com': 81,
#                       'analytics.vodgc.net': 2,
#                       'analytics.yicai.com': 1,
#                       'analytics2.m2.ai': 2,
#                       'anchor.fm': 2,
#                       'answersstatus.pagescdn.com': 2,
#                       'answerthepublic-2-staging-herokuapp-com.global.ssl.fastly.net': 3,
#                       'answerthepublic.com': 1,
#                       'answerthepublic.global.ssl.fastly.net': 6,
#                       'antenna.ayads.co': 3,
#                       'ants.xing-events.com': 1,
#                       'aoldefense.disqus.com': 1,
#                       'api-ad-product.huxiu.com': 1,
#                       'api-iam.intercom.io': 4,
#                       'api-js.datadome.co': 2,
#                       'api-mktdev.solarwinds.com': 2,
#                       'api-na.geetest.com': 1,
#                       'api-visitor-analytics.intercom.com': 1,
#                       'api.114la.com': 3,
#                       'api.accounts.nintendo.com': 1,
#                       'api.adnsafe.org': 2,
#                       'api.advarkads.com': 5,
#                       'api.aia.org': 1,
#                       'api.altmetric.com': 6,
#                       'api.amplitude.com': 9,
#                       'api.aws.parking.godaddy.com': 1,
#                       'api.benefits.gov': 6,
#                       'api.chartbeat.com': 1,
#                       'api.chatlio.com': 1,
#                       'api.chinacourt.org': 1,
#                       'api.conversant.mgr.consensu.org': 2,
#                       'api.curator.io': 2,
#                       'api.external.plus.net': 1,
#                       'api.gogopdf.com': 1,
#                       'api.grow.me': 2,
#                       'api.growingio.com': 4,
#                       'api.hackster.io': 2,
#                       'api.intellimize.co': 2,
#                       'api.ipdata.co': 1,
#                       'api.jquery.com': 1,
#                       'api.keen.io': 2,
#                       'api.map.baidu.com': 2,
#                       'api.mediawire.in': 1,
#                       'api.meritpages.com': 1,
#                       'api.nova.foxtv.com': 2,
#                       'api.phnx.click': 5,
#                       'api.publico.pt': 2,
#                       'api.sail-personalize.com': 6,
#                       'api.sail-track.com': 3,
#                       'api.segment.io': 23,
#                       'api.smotrim.ru': 1,
#                       'api.trustpilot.com': 1,
#                       'api.u1sf.com': 1,
#                       'api.userback.io': 1,
#                       'api.userleap.com': 1,
#                       'api.userway.org': 3,
#                       'api.viafoura.co': 9,
#                       'api.vidiom.net': 1,
#                       'api.willi.krone.at': 2,
#                       'api.ww.com': 1,
#                       'api.xtremepush.com': 1,
#                       'api.zingnews.vn': 1,
#                       'apigw.jl.gov.cn': 2,
#                       'apis.247sports.com': 2,
#                       'apis.quantcast.mgr.consensu.org': 1,
#                       'apollogroupinc.tt.omtrdc.net': 1,
#                       'apolloprogram.io': 1,
#                       'app-assets1.sportngin.com': 1,
#                       'app-renderer-awsblue-prodxenial.minted.com': 10,
#                       'app-worker.visitor-analytics.io': 1,
#                       'app.easyquote.pw': 1,
#                       'app.fide.com': 6,
#                       'app.launchdarkly.com': 2,
#                       'app.npsmeter.cn': 3,
#                       'app.truconversion.com': 1,
#                       'app.yzinter.com': 6,
#                       'apps.mypurecloud.com': 1,
#                       'aps.hearstnp.com': 1,
#                       'aqyzmedia.yunaq.com': 3,
#                       'archive.org': 9,
#                       'art19.com': 1,
#                       'artdaily.cc': 6,
#                       'article-api.huxiu.com': 2,
#                       'as-sec.casalemedia.com': 19,
#                       'aspeninstitute.org': 1,
#                       'asserts.xcarimg.com': 6,
#                       'asset.pagefair.com': 2,
#                       'asset.pagefair.net': 2,
#                       'asset.xmission.com': 7,
#                       'assets-decoupled.matchesfashion.com': 6,
#                       'assets-s3-us-east-1.ceros.com': 6,
#                       'assets.247sports.com': 6,
#                       'assets.alicdn.com': 1,
#                       'assets.baden-wuerttemberg.de': 10,
#                       'assets.businessgreen.com': 6,
#                       'assets.bwbx.io': 2,
#                       'assets.crutchfieldonline.com': 6,
#                       'assets.customer.io': 3,
#                       'assets.entrepreneur.com': 1,
#                       'assets.gocomics.com': 8,
#                       'assets.growingio.com': 2,
#                       'assets.hearstapps.com': 9,
#                       'assets.incisivemedia.com': 1,
#                       'assets.lloyds.com': 6,
#                       'assets.matchesfashion.com': 3,
#                       'assets.r7.com': 6,
#                       'assets.rbl.ms': 1,
#                       'assets.rebelmouse.io': 2,
#                       'assets.sitescdn.net': 4,
#                       'assets.sk-static.com': 6,
#                       'assets.vidyard.com': 2,
#                       'assetsnffrgf-a.akamaihd.net': 7,
#                       'assoc-na.associates-amazon.com': 3,
#                       'async-px-eu.dynamicyield.com': 2,
#                       'async-px.dynamicyield.com': 4,
#                       'at.cbsi.com': 6,
#                       'at.iocnt.net': 2,
#                       'atlas1.krone.at': 1,
#                       'atrack.avplayer.com': 2,
#                       'aufp.io': 4,
#                       'ausopen.com': 1,
#                       'auth.split.io': 1,
#                       'automatad.technoratimedia.com': 1,
#                       'avatar.amuniversal.com': 1,
#                       'avatars.mds.yandex.net': 10,
#                       'avd.innity.net': 2,
#                       'aviationweek.com': 1,
#                       'azure.microsoft.com': 1,
#                       'b1-q.mafengwo.net': 5,
#                       'b2c.insticator.com': 5,
#                       'b3-q.mafengwo.net': 1,
#                       'b3eea79d.de.ioam.de': 1,
#                       'b4-q.mafengwo.net': 1,
#                       'baden-wuerttemberg.de': 1,
#                       'badge.dimensions.ai': 1,
#                       'baichuan-api.huxiu.com': 2,
#                       'bam.zendesk.com': 1,
#                       'bandcamp.com': 1,
#                       'bankofamerica.tt.omtrdc.net': 1,
#                       'banner.aismo.ru': 6,
#                       'banners.chessbase.com': 1,
#                       'baoviet.com.vn': 2,
#                       'barra.brasil.gov.br': 7,
#                       'bat.bing.com': 104,
#                       'baymard.com': 1,
#                       'bazaarvoice.com': 1,
#                       'bcp.crwdcntrl.net': 16,
#                       'bdc.us-1.evergage.com': 1,
#                       'bdc.vmwareidentity.com': 1,
#                       'bdstatics.eastmoney.com': 2,
#                       'beacon.krxd.net': 4,
#                       'beacon.riskified.com': 2,
#                       'benefits.gov': 1,
#                       'berliner-zeitung.imgix.net': 3,
#                       'betterhelp.com': 1,
#                       'bf78180lnp.bf.dynatrace.com': 1,
#                       'biddr.brealtime.com': 2,
#                       'bigstockphoto.com': 1,
#                       'birdeye.com': 1,
#                       'bj-10353.ntalker.com': 2,
#                       'blockgeeks.com': 1,
#                       'blog.hu': 3,
#                       'blog.nfb.ca': 1,
#                       'blogg.se': 1,
#                       'blogs.yu.edu': 3,
#                       'bluejeans.com': 4,
#                       'bmwofnorthamericallc.tt.omtrdc.net': 1,
#                       'bn.touristsecrets.com': 1,
#                       'bonfire.com': 1,
#                       'booktopia.kh4ffx.net': 2,
#                       'bootstrap.smartsuppchat.com': 1,
#                       'bournemouth.ac.uk': 1,
#                       'bpi.rtactivate.com': 3,
#                       'bqq.gtimg.com': 1,
#                       'brands.corsair.com': 1,
#                       'brightcombid.marphezis.com': 2,
#                       'browser.sentry-cdn.com': 7,
#                       'bs.nakanohito.jp': 1,
#                       'bs.serving-sys.com': 8,
#                       'bst1.gismeteo.ru': 1,
#                       'btlr.sharethrough.com': 20,
#                       'bundesfinanzministerium.de': 6,
#                       'bus.gov.ru': 12,
#                       'businessgreen-live.disqus.com': 1,
#                       'businessgreen.com': 1,
#                       'bwwvmukk8zeenyxffnwfgtinnpdbo1627611336.darnuid.imrworldwide.com': 1,
#                       'c.betrad.com': 3,
#                       'c.bing.com': 18,
#                       'c.clarity.ms': 20,
#                       'c.clicktale.net': 2,
#                       'c.cnzz.com': 6,
#                       'c.contentsquare.net': 6,
#                       'c.dpgmedia.net': 2,
#                       'c.dx.com': 6,
#                       'c.evidon.com': 32,
#                       'c.go-mpulse.net': 44,
#                       'c.jabmo.app': 2,
#                       'c.webengage.com': 1,
#                       'c.webtrends-optimize.com': 1,
#                       'c1.adform.net': 2,
#                       'c1323b8102e647c69d2da4fa1bacc3d2.js.ubembed.com': 1,
#                       'c184ba0e.de.ioam.de': 2,
#                       'c2.ktxlytics.io': 2,
#                       'c8e91b12.de.ioam.de': 1,
#                       'calvin.edu': 1,
#                       'camino.sandiego.edu': 1,
#                       'canadapost-postescanada.ca': 1,
#                       'capsulink.zendesk.com': 1,
#                       'capterra.com': 1,
#                       'casalemedia.com': 1,
#                       'castbox.fm': 2,
#                       'cbe.capturehighered.net': 3,
#                       'cbs.nl': 1,
#                       'cc.swiftype.com': 5,
#                       'ccpa-service.sp-prod.net': 5,
#                       'cdn-a.william-reed.com': 4,
#                       'cdn-pci.optimizely.com': 4,
#                       'cdn-production-assets-kly.akamaized.net': 1,
#                       'cdn.accounts.nintendo.com': 1,
#                       'cdn.app.sbb.ch': 6,
#                       'cdn.betrad.com': 2,
#                       'cdn.blog.hu': 6,
#                       'cdn.bootcdn.net': 12,
#                       'cdn.calltrk.com': 2,
#                       'cdn.capcom-unity.com': 2,
#                       'cdn.carbonads.com': 2,
#                       'cdn.cbs.nl': 4,
#                       'cdn.cooladata.com': 1,
#                       'cdn.defenseone.com': 4,
#                       'cdn.designcrowd.com': 6,
#                       'cdn.dvidshub.net': 1,
#                       'cdn.embed.ly': 1,
#                       'cdn.embedly.com': 4,
#                       'cdn.evgnet.com': 2,
#                       'cdn.fcmrktplace.com': 1,
#                       'cdn.filestackcontent.com': 1,
#                       'cdn.gamer-network.net': 1,
#                       'cdn.gamerch.com': 6,
#                       'cdn.getambassador.com': 1,
#                       'cdn.img.sbb.ch': 1,
#                       'cdn.innity.net': 1,
#                       'cdn.krxd.net': 8,
#                       'cdn.l-tike.com': 1,
#                       'cdn.linkmink.com': 1,
#                       'cdn.mookie1.com': 1,
#                       'cdn.mouseflow.com': 12,
#                       'cdn.oncehub.com': 1,
#                       'cdn.onthe.io': 9,
#                       'cdn.petametrics.com': 1,
#                       'cdn.polyfill.io': 24,
#                       'cdn.preezie.com': 1,
#                       'cdn.pubmatic.com': 1,
#                       'cdn.pubnub.com': 1,
#                       'cdn.pushalert.co': 1,
#                       'cdn.radiofrance.fr': 1,
#                       'cdn.ravenjs.com': 4,
#                       'cdn.relap.io': 2,
#                       'cdn.sirdata.io': 1,
#                       'cdn.smartclip-services.com': 1,
#                       'cdn.speedcurve.com': 12,
#                       'cdn.split.io': 1,
#                       'cdn.thefa.com': 6,
#                       'cdn.trackjs.com': 3,
#                       'cdn.utep.edu': 1,
#                       'cdn.vox-cdn.com': 2,
#                       'cdn.wordart.com': 1,
#                       'cdn0-production-images-kly.akamaized.net': 6,
#                       'cdn0.forter.com': 1,
#                       'cdn01.lotto-hh.de': 4,
#                       'cdn1-production-assets-kly.akamaized.net': 1,
#                       'cdn1-production-images-kly.akamaized.net': 3,
#                       'cdn1.affirm.com': 5,
#                       'cdn1.cdnme.se': 5,
#                       'cdn1.readspeaker.com': 2,
#                       'cdn2.cache.vn': 2,
#                       'cdn2.cdnme.se': 5,
#                       'cdn2.funnelenvy.com': 2,
#                       'cdn3.cdnme.se': 6,
#                       'cdn3.minted.com': 5,
#                       'cdn3.optimizely.com': 5,
#                       'cdn4.buysellads.net': 3,
#                       'cdn4.minted.com': 6,
#                       'cdnjs.atresmedia.com': 1,
#                       'cdnmon.cfigroup.com': 1,
#                       'cdns.eu1.gigya.com': 4,
#                       'cdns.gigya.com': 10,
#                       'cdns.us1.gigya.com': 5,
#                       'cdnsciencepub.com': 2,
#                       'cdprojekt.com': 1,
#                       'centro.pixel.ad': 1,
#                       'ceros.com': 1,
#                       'chadd.org': 1,
#                       'chadd.z2systems.com': 1,
#                       'chat.qidian.qq.com': 1,
#                       'chat.satis.fi': 1,
#                       'chat.snapsmedia.io': 3,
#                       'chicago.suntimes.com': 2,
#                       'chimpstatic.com': 3,
#                       'chinacourt.org': 1,
#                       'chloro.trip.com': 1,
#                       'choices.consentframework.com': 2,
#                       'chop.edu': 1,
#                       'citicorpcreditservic.tt.omtrdc.net': 1,
#                       'ckmap.mediav.com': 2,
#                       'clarium.global.ssl.fastly.net': 2,
#                       'cld.bz': 1,
#                       'clickio.mgr.consensu.org': 2,
#                       'clickiocdn.com': 3,
#                       'clickserv.basis.net': 1,
#                       'clickserv.sitescout.com': 2,
#                       'clicktotweet.zendesk.com': 1,
#                       'client-registry.mutinycdn.com': 1,
#                       'clientstream.launchdarkly.com': 1,
#                       'climatecentral.org': 1,
#                       'clip.vietnamnetjsc.vn': 6,
#                       'cloud.typography.com': 26,
#                       'cm-eu.wargaming.net': 6,
#                       'cm.everesttech.net': 66,
#                       'cm.miaozhen.atm.youku.com': 2,
#                       'cm.p.altergeo.ru': 2,
#                       'cm.pos.baidu.com': 4,
#                       'cmp.cio.com': 2,
#                       'cmp.dreamlab.pl': 3,
#                       'cmp.ekstrabladet.dk': 1,
#                       'cmp.infoworld.com': 2,
#                       'cms-media-api.r7.com': 1,
#                       'cms.analytics.yahoo.com': 2,
#                       'cms.tanx.com': 2,
#                       'cmsadmin30.convio.net': 1,
#                       'cmswire.disqus.com': 2,
#                       'cmt.ixbt.com': 1,
#                       'cmx.weightwatchers.com': 6,
#                       'cnb.cnews.ru': 6,
#                       'cnews.ru': 1,
#                       'cnzz.mmstat.com': 6,
#                       'code.createjs.com': 8,
#                       'code.nytive.com': 1,
#                       'code.tidio.co': 2,
#                       'cognito-identity.us-east-1.amazonaws.com': 2,
#                       'col.site24x7rum.com': 1,
#                       'collect.1dmp.io': 2,
#                       'collect.tealiumiq.com': 1,
#                       'collection.decibelinsight.net': 3,
#                       'collector.brandmetrics.com': 1,
#                       'columbia.com': 1,
#                       'columbiasportswear.tt.omtrdc.net': 2,
#                       'comeresaprensasl.tt.omtrdc.net': 3,
#                       'comm.cnews.ru': 2,
#                       'company.com': 1,
#                       'comptia.informz.net': 2,
#                       'conch.xiami.com': 1,
#                       'confiant-integrations.global.ssl.fastly.net': 26,
#                       'config.gorgias.io': 1,
#                       'connect-metrics-collector.s-onetag.com': 3,
#                       'connect.ok.ru': 5,
#                       'connect.sitewit.com': 1,
#                       'consent.xing-events.com': 1,
#                       'consentdeliveryfd.azurefd.net': 1,
#                       'consumer.krxd.net': 3,
#                       'content.api.news': 6,
#                       'content.eol.org': 6,
#                       'content.uplynk.com': 1,
#                       'contineljs.com': 5,
#                       'cookiesync.mparticle.com': 1,
#                       'core.conversant.mgr.consensu.org': 3,
#                       'corp-brightlocal.imgix.net': 4,
#                       'corrieredellosport.it': 1,
#                       'count.pcauto.com.cn': 2,
#                       'count.pclady.com.cn': 1,
#                       'count6.pconline.com.cn': 2,
#                       'counter.24log.ru': 4,
#                       'counter.rambler.ru': 3,
#                       'counter.yadro.ru': 42,
#                       'countub.3g.fang.com': 6,
#                       'courses.blockgeeks.com': 6,
#                       'creativereview.imgix.net': 3,
#                       'creditcards.com': 1,
#                       'cs.admanmedia.com': 6,
#                       'cs.emxdgt.com': 2,
#                       'cs.nakanohito.jp': 2,
#                       'css.labirint.ru': 6,
#                       'cstaticdun.126.net': 1,
#                       'culturaltracking.ru': 2,
#                       'customer.iad-03.braze.com': 2,
#                       'cvshealth.com': 6,
#                       'cyberleninka.ru': 6,
#                       'cyprus-mail.os.tc': 1,
#                       'cz.tommy.com': 1,
#                       'd.adroll.com': 6,
#                       'd.adroll.mgr.consensu.org': 9,
#                       'd.banner.aismo.ru': 1,
#                       'd.infeed.id': 1,
#                       'd.ssl.lfq1001.top': 1,
#                       'd0.xcar.com.cn': 2,
#                       'd2.yiche.com': 2,
#                       'd7d3cf2e81d293050033-3dfc0615b0fd7b49143049256703bfce.ssl.cf1.rackcdn.com': 3,
#                       'da.qiyukf.com': 1,
#                       'dallasobserver.com': 1,
#                       'dangerminds.disqus.com': 1,
#                       'dapulse-res.cloudinary.com': 6,
#                       'dash.getsitecontrol.com': 1,
#                       'dashboard.whoisvisiting.com': 1,
#                       'data.adsrvr.org': 1,
#                       'data.cdeledu.com': 2,
#                       'data.cdnbasket.net': 3,
#                       'data.giraff.io': 3,
#                       'data2.gosquared.com': 1,
#                       'days.pravoslavie.ru': 1,
#                       'db.thepointsguy.com': 1,
#                       'dc.ads.linkedin.com': 2,
#                       'dc.oracleinfinity.io': 1,
#                       'dc.services.visualstudio.com': 2,
#                       'de.com': 5,
#                       'de.tynt.com': 2,
#                       'de79e664308748b483ad1dcab876a8b2.events.ubembed.com': 2,
#                       'de79e664308748b483ad1dcab876a8b2.js.ubembed.com': 1,
#                       'default.salsalabs.org': 1,
#                       'delphiforums.com': 1,
#                       'dennis.blueconic.net': 1,
#                       'dennis.slgnt.eu': 1,
#                       'des.smartclip.net': 1,
#                       'designnominees.os.tc': 1,
#                       'dev.elsevier.com': 1,
#                       'dfapvmql-q.global.ssl.fastly.net': 1,
#                       'dfscdn.dfcfw.com': 4,
#                       'digital.elmercurio.com': 1,
#                       'digitalphotographyschool.disqus.com': 1,
#                       'disqus.com': 4,
#                       'distillery.wistia.com': 5,
#                       'dl.gmx.com': 2,
#                       'dmagonline.disqus.com': 1,
#                       'dmg.digitaltarget.ru': 10,
#                       'dmp.adform.net': 3,
#                       'dmp.v.fwmrm.net': 1,
#                       'doleta.gov': 1,
#                       'doppler-config.cbsivideo.com': 1,
#                       'dotnet.microsoft.com': 1,
#                       'dovepress.com': 1,
#                       'downloads.unicef.org.uk': 6,
#                       'downtoearth.org.in': 1,
#                       'dpic.imgix.net': 1,
#                       'dplayentertainmentli.tt.omtrdc.net': 1,
#                       'dr.bluehornet.com': 1,
#                       'ds-aksb-a.akamaihd.net': 3,
#                       'dsp.adfarm1.adition.com': 1,
#                       'dsum-sec.casalemedia.com': 3,
#                       'dt.adsafeprotected.com': 2,
#                       'dt.cobaltgroup.com': 1,
#                       'ducip.megafon.ru': 1,
#                       'dup.baidustatic.com': 2,
#                       'dvutvwxjfu-2.algolianet.com': 2,
#                       'dvutvwxjfu-dsn.algolia.net': 1,
#                       'dw.xcar.com.cn': 2,
#                       'dx0.xcar.com.cn': 1,
#                       'dx1.xcar.com.cn': 1,
#                       'dx2.xcar.com.cn': 1,
#                       'dyn-img.com': 1,
#                       'dynamic-media-cdn.tripadvisor.com': 18,
#                       'e-4669.adzerk.net': 1,
#                       'e.cquotient.com': 1,
#                       'e.dx.com': 3,
#                       'e.serverbid.com': 9,
#                       'e.so.com': 1,
#                       'e0c8555f94d346959cb7379b3560138c-5944d031151c.cdn.forter.com': 1,
#                       'e1.emxdgt.com': 2,
#                       'e5b3f531.de.ioam.de': 1,
#                       'e5eb388ed27646df80673f7cf1fbac24-1f8c393e7327.cdn.forter.com': 1,
#                       'e60642ba4a8859e0499c-e2ee5690958be9bdf95e879af50025cb.ssl.cf1.rackcdn.com': 2,
#                       'eaa.org': 1,
#                       'eas-fe.eskimi.com': 1,
#                       'eb2.3lift.com': 12,
#                       'ebimg.dk': 2,
#                       'ecdn.teacherspayteachers.com': 6,
#                       'edge.quantserve.com': 7,
#                       'editor.e-flux-systems.com': 1,
#                       'ejoinme.org': 6,
#                       'ekstrabladet.dk': 6,
#                       'elgato.com': 1,
#                       'embed-fastly.wistia.com': 1,
#                       'embed.air.tv': 3,
#                       'embed.gettyimages.com': 1,
#                       'embed.tempestpremium.com': 1,
#                       'embed.vietnamnettv.vn': 2,
#                       'embedwistia-a.akamaihd.net': 1,
#                       'emcharts.dfcfw.com': 1,
#                       'end.scorecardresearch.com': 1,
#                       'endurance.clarip.com': 2,
#                       'engine.adzerk.net': 2,
#                       'entitlement.auth.adobe.com': 3,
#                       'eol.org': 5,
#                       'epsilon.6sense.com': 4,
#                       'er.sanoma-sndp.fi': 2,
#                       'errors.aliyun.com': 2,
#                       'ers.baidu.com': 2,
#                       'escapist-magazine.disqus.com': 2,
#                       'escol.escardio.org': 1,
#                       'eslgaming.com': 1,
#                       'ethn.io': 2,
#                       'eu.cookie-script.com': 1,
#                       'eu.wargaming.net': 1,
#                       'event.clientgear.com': 3,
#                       'event.insticator.com': 2,
#                       'events.api.boomtrain.com': 1,
#                       'events.api.godaddy.com': 6,
#                       'events.brainpop.com': 1,
#                       'events.browsiprod.com': 4,
#                       'events.launchdarkly.com': 2,
#                       'events.ocdn.eu': 4,
#                       'everest.castbox.fm': 4,
#                       'evnt.iol.it': 2,
#                       'exchange.adtrue.com': 5,
#                       'exchange.mediavine.com': 2,
#                       'execution-euw.ci360.sas.com': 2,
#                       'experiment.com': 1,
#                       'expressionengine.com': 6,
#                       'extend.vimeocdn.com': 1,
#                       'external-api.jebbit.com': 1,
#                       'f.vimeocdn.com': 48,
#                       'famsf.org': 1,
#                       'fan.school': 1,
#                       'fast.a.klaviyo.com': 2,
#                       'fast.fonts.net': 35,
#                       'fast.wistia.com': 20,
#                       'fast.wistia.net': 5,
#                       'faves.grow.me': 2,
#                       'fcgi4.gnezdo.ru': 4,
#                       'fclog.baidu.com': 2,
#                       'fdslive.oup.com': 4,
#                       'feature-services.onehub.feature-app.io': 1,
#                       'feed.exchange.entrepreneur.com': 1,
#                       'felix.data.tm-awx.com': 8,
#                       'ffm.to': 1,
#                       'file.chinacourt.org': 1,
#                       'filearchive.cnews.ru': 6,
#                       'files.efty.com': 1,
#                       'files.mastodon.social': 5,
#                       'files.sfchronicle.com': 1,
#                       'files.xiami.com': 1,
#                       'filmfreeway.com': 1,
#                       'fiservsolution.tt.omtrdc.net': 1,
#                       'flaming.peacebanana.com': 1,
#                       'flask.nextdoor.com': 1,
#                       'flightstats.com': 1,
#                       'fls-na.amazon.com': 1,
#                       'fontlibrary.org': 1,
#                       'fonts.65twenty.com': 2,
#                       'fonts.advance.net': 3,
#                       'fonts.r7.com': 1,
#                       'forms.mailmunch.co': 1,
#                       'forum.guns.ru': 2,
#                       'forum.ixbt.com': 1,
#                       'fotografias.antena3.com': 6,
#                       'fourier.taobao.com': 4,
#                       'free-ebooks.net': 1,
#                       'frog.wix.com': 2,
#                       'front.optimonk.com': 1,
#                       'frontimg.dk': 6,
#                       'frtn.socdm.com': 1,
#                       'fsapi.gold.org': 1,
#                       'fscdn.gold.org': 1,
#                       'fstoppers.com': 1,
#                       'fubizmedia.disqus.com': 1,
#                       'fueleconomy.gov': 1,
#                       'fxgate.baidu.com': 2,
#                       'g.cn.miaozhen.com': 2,
#                       'g.yccdn.com': 4,
#                       'g1.dfcfw.com': 2,
#                       'g2.gumgum.com': 25,
#                       'gadget.open-system.fr': 1,
#                       'gahu.hit.gemius.pl': 2,
#                       'gamena.hit.gemius.pl': 2,
#                       'gamerch.com': 2,
#                       'gate.dnm.radiofrance.fr': 1,
#                       'gateway.cdeledu.com': 1,
#                       'gaua.hit.gemius.pl': 1,
#                       'gdetr.hit.gemius.pl': 2,
#                       'generalmotorscorpora.tt.omtrdc.net': 1,
#                       'geo.ipify.org': 1,
#                       'geo.moatads.com': 9,
#                       'geo2.adobe.com': 2,
#                       'geoip.insticator.com': 5,
#                       'geoloc.hurriyet.com.tr': 1,
#                       'get.mycounter.ua': 1,
#                       'get.oreilly.com': 2,
#                       'getfreshsd.os.tc': 1,
#                       'giphy.com': 1,
#                       'glamour.de': 1,
#                       'glimmer.hearstapps.com': 1,
#                       'global.nissannews.com': 2,
#                       'global.nissanstories.com': 1,
#                       'global.oup.com': 1,
#                       'globalsources.com': 2,
#                       'go.2checkout.com': 1,
#                       'go.automatad.com': 1,
#                       'golfdigest.com': 1,
#                       'gonzaga-search.clients.us.funnelback.com': 2,
#                       'goodwillintl.zendesk.com': 1,
#                       'goutong.baidu.com': 4,
#                       'gpsies.com': 1,
#                       'graph.sanook.com': 1,
#                       'graphicriver.img.customer.envatousercontent.com': 6,
#                       'graphics.afpforum.com': 1,
#                       'guardianngr.disqus.com': 1,
#                       'gui.secureserver.net': 1,
#                       'guitarcenter.tt.omtrdc.net': 2,
#                       'gw.geoedge.be': 1,
#                       'h.holder.com.ua': 2,
#                       'hammacher-ac.celebros.com': 1,
#                       'hangbangxia.com': 2,
#                       'harborside.blueconic.net': 1,
#                       'hb.brainlyads.com': 3,
#                       'hb.emxdgt.com': 9,
#                       'hbopenbid.pubmatic.com': 36,
#                       'health.gov': 1,
#                       'healthcare.utah.edu': 1,
#                       'healthunlocked.com': 2,
#                       'heapanalytics.com': 15,
#                       'hearst.blueconic.net': 1,
#                       'hello.myfonts.net': 19,
#                       'hermitagemuseum.org': 6,
#                       'hips.hearstapps.com': 7,
#                       'hit.uptrendsdata.com': 2,
#                       'hm.baidu.com': 61,
#                       'hol.evolok.net': 1,
#                       'hollywood.com': 1,
#                       'homeaffairs.inq.com': 1,
#                       'hqs7.cnzz.com': 2,
#                       'hs-marketing.imgix.net': 1,
#                       'htlb.casalemedia.com': 31,
#                       'httpbin.org': 1,
#                       'https-www-thebestworkoutplan-com.disqus.com': 1,
#                       'httpsak-a.akamaihd.net': 1,
#                       'hubspot.clearbit.com': 1,
#                       'hulkshare.com': 3,
#                       'hw-static.worldstarhiphop.com': 2,
#                       'hzs8.cnzz.com': 1,
#                       'i.17173cdn.com': 2,
#                       'i.adingo.jp': 4,
#                       'i.avoz.es': 1,
#                       'i.b2b168.com': 1,
#                       'i.bigmir.net': 3,
#                       'i.dietdoctor.com': 6,
#                       'i.holder.com.ua': 1,
#                       'i.imgur.com': 2,
#                       'i.imgvc.com': 1,
#                       'i.scdn.co': 3,
#                       'i.simpli.fi': 3,
#                       'i.smartnews-ads.com': 2,
#                       'i.viafoura.co': 4,
#                       'i.vietnamnet.vn': 2,
#                       'i.vimeocdn.com': 19,
#                       'i1.cqnews.net': 6,
#                       'i2.cqnews.net': 6,
#                       'i3.cqnews.net': 6,
#                       'i4.cqnews.net': 6,
#                       'ia2.mycliplister.com': 1,
#                       'ia801400.us.archive.org': 1,
#                       'ia801403.us.archive.org': 1,
#                       'ia801404.us.archive.org': 1,
#                       'ia801406.us.archive.org': 2,
#                       'ia801407.us.archive.org': 2,
#                       'ia801409.us.archive.org': 1,
#                       'ia801505.us.archive.org': 1,
#                       'ia801507.us.archive.org': 3,
#                       'ia801509.us.archive.org': 1,
#                       'iabusprivacy.pmc.com': 4,
#                       'ib.adnxs.com': 111,
#                       'icahn.mssm.edu': 1,
#                       'ichef.bbci.co.uk': 6,
#                       'icon.cecdc.com': 1,
#                       'icon.cnzz.com': 1,
#                       'icon.szfw.org': 1,
#                       'icon.xcar.com.cn': 3,
#                       'ict-imgs.vgcloud.vn': 6,
#                       'id.crwdcntrl.net': 3,
#                       'id.sharedid.org': 2,
#                       'id.sv.rkdms.com': 7,
#                       'id.vietnamnet.vn': 3,
#                       'idcta.api.bbc.co.uk': 1,
#                       'identity.mparticle.com': 2,
#                       'idge.staticworld.net': 2,
#                       'ids.ad.gt': 8,
#                       'igi-global.com': 1,
#                       'ignitiondeck.disqus.com': 1,
#                       'ihgsixcontinentshote.tt.omtrdc.net': 1,
#                       'ilta.auriro.net': 2,
#                       'image.bitautoimg.com': 6,
#                       'image.dhgate.com': 1,
#                       'image.p1000.co.il': 6,
#                       'image.wku.ac.kr': 12,
#                       'image2.pubmatic.com': 7,
#                       'image6.pubmatic.com': 13,
#                       'image8.pubmatic.com': 6,
#                       'imagenes.atresplayer.com': 1,
#                       'images-na.ssl-images-amazon.com': 2,
#                       'images.17173cdn.com': 1,
#                       'images.crutchfieldonline.com': 4,
#                       'images.dmca.com': 16,
#                       'images.freeimages.com': 6,
#                       'images.idgesg.net': 2,
#                       'images.liveauctioneers.com': 4,
#                       'images.static-thomann.de': 5,
#                       'images.techhive.com': 1,
#                       'images.unsplash.com': 24,
#                       'images.zeiss.com': 6,
#                       'images1.mcmaster.com': 2,
#                       'imagev2.xmcdn.com': 1,
#                       'img-prod-cms-rt-microsoft-com.akamaized.net': 3,
#                       'img.9liuda.com': 6,
#                       'img.ak.impact-ad.jp': 1,
#                       'img.antaranews.com': 1,
#                       'img.app.meitudata.com': 5,
#                       'img.aso.fr': 3,
#                       'img.cngoldres.com': 5,
#                       'img.dxcdn.com': 6,
#                       'img.easypass.cn': 1,
#                       'img.en25.com': 16,
#                       'img.funshion.com': 1,
#                       'img.hmv.co.jp': 6,
#                       'img.labirint.ru': 6,
#                       'img.mako.co.il': 6,
#                       'img.pcauto.com.cn': 6,
#                       'img.pclady.com.cn': 1,
#                       'img.pconline.com.cn': 1,
#                       'img.r7.com': 6,
#                       'img.smi2.net': 2,
#                       'img.soufunimg.com': 1,
#                       'img.the-village.ru': 6,
#                       'img.ui-portal.de': 1,
#                       'img.vietnamnetad.vn': 2,
#                       'img0.pcauto.com.cn': 14,
#                       'img0.pcbaby.com.cn': 1,
#                       'img0.pchouse.com.cn': 2,
#                       'img0.pclady.com.cn': 12,
#                       'img0.pconline.com.cn': 2,
#                       'img03.en25.com': 1,
#                       'img04.en25.com': 5,
#                       'img06.en25.com': 1,
#                       'img1-azrcdn.newser.com': 6,
#                       'img1.bitautoimg.com': 7,
#                       'img1.chinacourt.org': 6,
#                       'img1.xcarimg.com': 3,
#                       'img2-azrcdn.newser.com': 6,
#                       'img2.bitautoimg.com': 6,
#                       'img3.funshion.com': 1,
#                       'img3.labirint.ru': 1,
#                       'img3.teletype.in': 2,
#                       'img4.bitautoimg.com': 8,
#                       'img4.caijing.com.cn': 1,
#                       'img4.labirint.ru': 3,
#                       'img4.teletype.in': 1,
#                       'imgbj02.yisier.com': 1,
#                       'imgcdn.yicai.com': 6,
#                       'imgproxy3.cdnforo.com': 12,
#                       'imgproxy4.cdnforo.com': 3,
#                       'imgs.signifyd.com': 5,
#                       'imgwcs2.soufunimg.com': 4,
#                       'imis.counseling.org': 1,
#                       'in.getclicky.com': 4,
#                       'in.gov.br': 8,
#                       'in.hotjar.com': 82,
#                       'ina.schleswig-holstein.de': 1,
#                       'incisive-wrapper.kreatio.com': 2,
#                       'includemodal.global.ssl.fastly.net': 2,
#                       'indexhu.adocean.pl': 1,
#                       'inegi.org.mx': 6,
#                       'info2.magento.com': 1,
#                       'infolettres.duministeredelaculture.fr': 1,
#                       'ing-district.clicktale.net': 1,
#                       'ingest.make.rvapps.io': 9,
#                       'ingestion.contentinsights.com': 1,
#                       'insight.adsrvr.org': 59,
#                       'intercom.help': 1,
#                       'intl.startrek.com': 1,
#                       'inv-nets.admixer.net': 2,
#                       'iobs.pingan.com.cn': 4,
#                       'ioby.org': 1,
#                       'ion.fiserv.com': 2,
#                       'ip.yiche.com': 1,
#                       'ipa.247sports.com': 1,
#                       'iptrack.io': 1,
#                       'irena.org': 1,
#                       'istockphoto.6q33.net': 1,
#                       'itworld.com': 1,
#                       'ivy.pconline.com.cn': 9,
#                       'ixbt.online': 6,
#                       'j.dochase.com': 1,
#                       'jadserve.postrelease.com': 30,
#                       'javaworld.com': 1,
#                       'jcmonitor.xcar.com.cn': 1,
#                       'jmir.zendesk.com': 1,
#                       'jnxm2.com': 1,
#                       'jobvite.com': 2,
#                       'journalism.co.uk': 1,
#                       'js-agent.newrelic.com': 131,
#                       'js-na1.hs-scripts.com': 1,
#                       'js-sec.indexww.com': 39,
#                       'js.3conline.com': 1,
#                       'js.ad-spire.net': 1,
#                       'js.ad-stir.com': 2,
#                       'js.alpixtrack.com': 2,
#                       'js.app.meitudata.com': 6,
#                       'js.callrail.com': 2,
#                       'js.calltrk.com': 2,
#                       'js.cookieless-data.com': 2,
#                       'js.dxcdn.com': 6,
#                       'js.fout.jp': 1,
#                       'js.genieessp.com': 2,
#                       'js.hs-analytics.net': 28,
#                       'js.hs-scripts.com': 23,
#                       'js.hsadspixel.net': 14,
#                       'js.hscollectedforms.net': 5,
#                       'js.hsleadflows.net': 11,
#                       'js.hubspotfeedback.com': 1,
#                       'js.labirint.ru': 6,
#                       'js.live.net': 1,
#                       'js.usemessages.com': 8,
#                       'js.xcar.com.cn': 4,
#                       'jsinc.baa.bitautotech.com': 2,
#                       'json.bselivefeeds.indiatimes.com': 1,
#                       'jssdkcdns.mparticle.com': 2,
# ...
#                       'www.stsci.edu': 6,
#                       'www.styleguide.sachsen.de': 4,
#                       'www.suffolk.edu': 15,
#                       'www.sunjournal.com': 1,
#                       'www.sup.org': 6,
#                       'www.supersaa.fi': 3,
#                       'www.surfline.com': 1,
#                       'www.surfrider.org': 6,
#                       'www.surveygizmo.eu': 1,
#                       'www.swedenabroad.se': 1,
#                       'www.swift.com': 1,
#                       'www.swinburne.edu.au': 1,
#                       'www.swisspass.ch': 1,
#                       'www.sydneyoperahouse.com': 1,
#                       'www.symplicity.com': 1,
#                       'www.tabletmag.com': 1,
#                       'www.taboola.com': 1,
#                       'www.taylorfrancis.com': 1,
#                       'www.teacherspayteachers.com': 4,
#                       'www.teencounseling.com': 1,
#                       'www.telam.com.ar': 7,
#                       'www.telekom.com': 6,
#                       'www.telekom.de': 1,
#                       'www.terappeuta.com': 1,
#                       'www.the-american-interest.com': 1,
#                       'www.the-village.ru': 1,
#                       'www.theawl.com': 1,
#                       'www.thebump.com': 1,
#                       'www.thebureauinvestigates.com': 1,
#                       'www.thedrinksbusiness.com': 1,
#                       'www.thefa.com': 6,
#                       'www.thehenryford.org': 1,
#                       'www.thehollywoodgossip.com': 1,
#                       'www.thelocal.fr': 1,
#                       'www.themebanks.com': 1,
#                       'www.themediateam.net': 1,
#                       'www.themeinwp.com': 1,
#                       'www.thenest.com': 1,
#                       'www.thenewhumanitarian.org': 1,
#                       'www.theparisreview.org': 1,
#                       'www.thersa.org': 6,
#                       'www.thesimpledollar.com': 1,
#                       'www.thestate.com': 1,
#                       'www.thesun.co.uk': 1,
#                       'www.thesun.ie': 1,
#                       'www.thetimes.co.uk': 1,
#                       'www.theweek.co.uk': 1,
#                       'www.thomann.de': 1,
#                       'www.thoughtworks.com': 1,
#                       'www.ticketleap.com': 1,
#                       'www.tickets.com': 4,
#                       'www.tiffany.com': 1,
#                       'www.tintup.com': 1,
#                       'www.tns-counter.ru': 12,
#                       'www.toasttab.com': 1,
#                       'www.tokopedia.com': 1,
#                       'www.toto.com': 2,
#                       'www.tottenhamhotspur.com': 1,
#                       'www.tourismthailand.org': 5,
#                       'www.trade.gov': 1,
#                       'www.transip.nl': 4,
#                       'www.travelocity.com': 1,
#                       'www.trekbikes.com': 1,
#                       'www.trenitalia.com': 1,
#                       'www.tribpub.com': 1,
#                       'www.tribunnews.com': 1,
#                       'www.trimble.com': 6,
#                       'www.trip.com': 1,
#                       'www.tripadvisor.ca': 1,
#                       'www.tripadvisor.es': 1,
#                       'www.tripadvisor.it': 1,
#                       'www.tripadvisor.nl': 1,
#                       'www.trumba.com': 4,
#                       'www.trustradius.com': 1,
#                       'www.trvl-px.com': 1,
#                       'www.tsn.ca': 6,
#                       'www.tu-chemnitz.de': 6,
#                       'www.tudofacil.rs.gov.br': 6,
#                       'www.tugraz.at': 6,
#                       'www.tumblr.com': 3,
#                       'www.tuv.com': 1,
#                       'www.tuxfamily.org': 6,
#                       'www.twitlonger.com': 1,
#                       'www.twoday.net': 1,
#                       'www.twoo.com': 1,
#                       'www.uakron.edu': 6,
#                       'www.uc3m.es': 7,
#                       'www.uci.org': 1,
#                       'www.uciservice.com': 3,
#                       'www.uclan.ac.uk': 1,
#                       'www.ucoz.ru': 2,
#                       'www.ufba.br': 3,
#                       'www.ui.ac.id': 6,
#                       'www.ui.com': 1,
#                       'www.ukri.org': 1,
#                       'www.ulta.com': 1,
#                       'www.um.es': 6,
#                       'www.unab.edu.ar': 10,
#                       'www.unb.ca': 1,
#                       'www.uni-jena.de': 1,
#                       'www.uni.lu': 1,
#                       'www.unicef.org.uk': 1,
#                       'www.unila.ac.id': 1,
#                       'www.unisg.ch': 9,
#                       'www.univ-nantes.fr': 74,
#                       'www.unizar.es': 6,
#                       'www.uny.ac.id': 6,
#                       'www.uoa.gr': 1,
#                       'www.usd.edu': 1,
#                       'www.ushistory.org': 1,
#                       'www.usra.edu': 1,
#                       'www.ustrust.ml.bac-assets.com': 1,
#                       'www.utas.edu.au': 1,
#                       'www.utep.edu': 6,
#                       'www.utsa.edu': 11,
#                       'www.uwe.ac.uk': 6,
#                       'www.uwec.edu': 2,
#                       'www.valuewalk.com': 6,
#                       'www.valvesoftware.com': 6,
#                       'www.vangoghmuseum.nl': 1,
#                       'www.vassar.edu': 1,
#                       'www.vbulletin.com': 2,
#                       'www.veeam.com': 1,
#                       'www.vfsglobal.com': 1,
#                       'www.vg247.com': 6,
#                       'www.viamichelin.com': 2,
#                       'www.vidaenelvalle.com': 1,
#                       'www.vidyard.com': 1,
#                       'www.villanova.edu': 1,
#                       'www.visitdubai.com': 1,
#                       'www.vitra.com': 1,
#                       'www.vizzit.se': 2,
#                       'www.volkswagen.de': 1,
#                       'www.vote.org': 1,
#                       'www.vpnmentor.com': 1,
#                       'www.vrbo.com': 2,
#                       'www.vutbr.cz': 5,
#                       'www.vw.com': 1,
#                       'www.vwthemes.com': 1,
#                       'www.w3school.com.cn': 2,
#                       'www.w7.cc': 2,
#                       'www.wada-ama.org': 1,
#                       'www.wafb.com': 1,
#                       'www.waikato.ac.nz': 1,
#                       'www.walkscore.com': 1,
#                       'www.wallpaper.com': 2,
#                       'www.warc.com': 1,
#                       'www.washingtontimes.com': 1,
#                       'www.wave3.com': 1,
#                       'www.waz.de': 1,
#                       'www.webcrawler.com': 1,
#                       'www.webcrow.jp': 10,
#                       'www.webd.pl': 1,
#                       'www.webfx.com': 2,
#                       'www.webpronews.com': 1,
#                       'www.webroot.com': 6,
#                       'www.website.com': 1,
#                       'www.websitepolicies.io': 2,
#                       'www.weightwatchers.com': 1,
#                       'www.wes.org': 1,
#                       'www.westernjournal.com': 1,
#                       'www.westminster.ac.uk': 1,
#                       'www.wfla.com': 1,
#                       'www.wftv.com': 1,
#                       'www.wgrz.com': 1,
#                       'www.whistleout.com': 1,
#                       'www.who.int': 2,
#                       'www.wikia.org': 1,
#                       'www.wimp.com': 1,
#                       'www.win-rar.com': 1,
#                       'www.wine-searcher.com': 1,
#                       'www.wisconsin.edu': 7,
#                       'www.wistv.com': 1,
#                       'www.wivb.com': 1,
#                       'www.wku.ac.kr': 10,
#                       'www.wkyc.com': 1,
#                       'www.wlu.ca': 3,
#                       'www.wm.com': 2,
#                       'www.woodlandtrust.org.uk': 1,
#                       'www.woopra.com': 2,
#                       'www.wopop.com': 10,
#                       'www.worldhistory.org': 2,
#                       'www.worldpay.com': 1,
#                       'www.worldstarhiphop.com': 1,
#                       'www.wp.de': 2,
#                       'www.wp.pl': 1,
#                       'www.wpcc.io': 2,
#                       'www.wr.de': 1,
#                       'www.wright.edu': 1,
#                       'www.wwf.org.uk': 2,
#                       'www.wwlp.com': 1,
#                       'www.wwu.edu': 6,
#                       'www.wxyz.com': 4,
#                       'www.xataka.com': 1,
#                       'www.xcar.com.cn': 1,
#                       'www.ximalaya.com': 3,
#                       'www.xing-events.com': 1,
#                       'www.xing-share.com': 1,
#                       'www.xing.com': 1,
#                       'www.xml.com': 5,
#                       'www.xmu.edu.cn': 10,
#                       'www.xxlmag.com': 1,
#                       'www.yangtse.com': 1,
#                       'www.yardbarker.com': 1,
#                       'www.yellowbot.com': 3,
#                       'www.yelp.ca': 1,
#                       'www.yenisafak.com': 1,
#                       'www.yicai.com': 1,
#                       'www.yiche.com': 5,
#                       'www.ynet.co.il': 1,
#                       'www.youtube-nocookie.com': 11,
#                       'www.youtube.com': 192,
#                       'www.youvisit.com': 12,
#                       'www.yu.edu': 1,
#                       'www.yummly.com': 1,
#                       'www.zabbix.com': 1,
#                       'www.zblogcn.com': 1,
#                       'www.zdnet.de': 67,
#                       'www.zdnet.fr': 6,
#                       'www.zeiss.com': 1,
#                       'www.zinio.com': 1,
#                       'www1-cdn.sherdog.com': 1,
#                       'www1.defence.gov.au': 1,
#                       'www1.grouponcdn.com': 1,
#                       'www1.imd.org': 1,
#                       'www1.pcauto.com.cn': 4,
#                       'www1.pclady.com.cn': 6,
#                       'www1.pconline.com.cn': 5,
#                       'www1.villanova.edu': 1,
#                       'www15.smartadserver.com': 2,
#                       'www18.smartadserver.com': 1,
#                       'www2-cdn.sherdog.com': 1,
#                       'www2.grouponcdn.com': 3,
#                       'www2.ljworld.com': 1,
#                       'www2.shine.cn': 10,
#                       'www3-cdn.sherdog.com': 1,
#                       'www3.ceros.com': 1,
#                       'www3.shine.cn': 4,
#                       'www4-cdn.sherdog.com': 1,
#                       'www5.smartadserver.com': 5,
#                       'www8.smartadserver.com': 1,
#                       'wwwcdn.frost.com': 6,
#                       'wwwen.uni.lu': 7,
#                       'wwws.airfrance.fr': 1,
#                       'wwws1.names.co.uk': 1,
#                       'wwws2.names.co.uk': 1,
#                       'wwws3.names.co.uk': 4,
#                       'wxyz.com': 1,
#                       'x.bidswitch.net': 13,
#                       'x.clearbit.com': 4,
#                       'x.clearbitjs.com': 3,
#                       'x.dlx.addthis.com': 5,
#                       'x.livechatmax.com': 2,
#                       'x.tagstat.com': 6,
#                       'x.yummlystatic.com': 1,
#                       'x01.aidata.io': 5,
#                       'xcuqngbo6fzorn2ba.ay.delivery': 1,
#                       'xdcs-collector.ximalaya.com': 3,
#                       'xhamster.com': 1,
#                       'xid.i-mobile.co.jp': 1,
#                       'xing-events.com': 1,
#                       'xiph.org': 1,
#                       'xmission.com': 6,
#                       'xuypharmacyonline.com': 2,
#                       'xwktgmrs2tex9odcw3jjiuseij2w81627610235.nuid.imrworldwide.com': 1,
#                       'xyt.xinchacha.com': 1,
#                       'y.zdmimg.com': 6,
#                       'ya.ru': 1,
#                       'yads.c.yimg.jp': 4,
#                       'yads.yjtag.yahoo.co.jp': 2,
#                       'yandex.ru': 5,
#                       'yandex.st': 1,
#                       'yastatic.net': 56,
#                       'ybx.yahoo.co.jp': 4,
#                       'yellowbot.com': 1,
#                       'yelp.ca': 1,
#                       'yhb.p.otm-r.com': 1,
#                       'yield-manager.browsiprod.com': 3,
#                       'yjlive-count.east.edge.storage-yahoo.jp': 2,
#                       'yjtag.yahoo.co.jp': 6,
#                       'ynet-images1.yit.co.il': 5,
#                       'yomoblog.com': 1,
#                       'youngminds.org.uk': 2,
#                       'yourbow-d.openx.net': 2,
#                       'youtube.com': 2,
#                       'ypyh3bvkv3k4ovae717h7gqtdifkm1627480034.nuid.imrworldwide.com': 1,
#                       'ysa-static.passport.yandex.ru': 3,
#                       'yt3.ggpht.com': 75,
#                       'ytro.news': 1,
#                       'ytro.ru': 1,
#                       'z-na.amazon-adsystem.com': 5,
#                       'z-na.associates-amazon.com': 3,
#                       'z.cdn.turner.com': 1,
#                       'z.moatads.com': 79,
#                       'z.omappapi.com': 2,
#                       'z3.cnzz.com': 2,
#                       'z6.cnzz.com': 1,
#                       'z7168057d.webengage.co': 1,
#                       'z980.carthrottle.com': 1,
#                       'z9d7c4u6.rocketcdn.me': 4,
#                       'za.zalo.me': 1,
#                       'zabbix.com': 2,
#                       'zagent1544.h-cdn.com': 1,
#                       'zagent157.h-cdn.com': 1,
#                       'zagent1937.h-cdn.com': 1,
#                       'zagent812.h-cdn.com': 1,
#                       'zagent850.h-cdn.com': 1,
#                       'zaq.ne.jp': 10,
#                       'zdwidget3-bs.sphereup.com': 2,
#                       'zfwzgl.www.gov.cn': 7,
#                       'zhanzhang.toutiao.com': 1,
#                       'zhiyou.smzdm.com': 2,
#                       'zhuge.cdeledu.com': 3,
#                       'zhugejs.cdeledu.com': 2,
#                       'zingnews.vn': 1,
#                       'zinio-sjc.gravityrd-services.com': 2,
#                       'zinio.com': 1,
#                       'zio.xcar.com.cn': 2,
#                       'zithromaxes.com': 2,
#                       'zjs.zadn.vn': 4,
#                       'zn0ivwutl4pi7xjah-iggroup.siteintercept.qualtrics.com': 1,
#                       'zn0oer1xu4ljz0hyr-servicenowcx.siteintercept.qualtrics.com': 1,
#                       'zn0xleir6swszany9-canadapostdigital.siteintercept.qualtrics.com': 1,
#                       'zn1ttxdo6pi4mebp8-coursehero.siteintercept.qualtrics.com': 1,
#                       'zn3xeyguhe8idwa8d-alaskaair.siteintercept.qualtrics.com': 1,
#                       'zn5cfoezj2kv4n9ub-generalmotors.siteintercept.qualtrics.com': 1,
#                       'znaeyokp2zrxb2lop-ihg.siteintercept.qualtrics.com': 1,
#                       'znbcr1fe9iqohckzz-aetnadigital.siteintercept.qualtrics.com': 1,
#                       'zncinle8sn1tfzbu5-phoenix.siteintercept.qualtrics.com': 2,
#                       'znciu8m8jgli7q9li-gfk.siteintercept.qualtrics.com': 1,
#                       'zncv1onfo8kuflf0n-kickstarter.siteintercept.qualtrics.com': 1,
#                       'zncvwzq01bdkk1bu1-expediainc.siteintercept.qualtrics.com': 1,
#                       'zndcixisjuiwtu9mx-monotype.siteintercept.qualtrics.com': 1,
#                       'znews-photo.zadn.vn': 6,
#                       'zoloftzabs.com': 2,
#                       'zrz.co': 1,
#                       'zt2.he2d.com': 2,
#                       'zug.sbb.ch': 1,
#                       'zuyapixel.com': 1,
#                       'zz.bdstatic.com': 14,
#                       'zzw.hsmdb.com': 6},
#  'Sampling Limit': 25000}
